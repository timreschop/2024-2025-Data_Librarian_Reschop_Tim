# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np

# %%
def bibsonomy_pubs(queries):
    df = pd.DataFrame()
    for query in queries: 
        url = f"https://www.bibsonomy.org/json/search/{query}?items=1000"
        response = requests.get(url)
        
        if response.status_code == 200:  # Sicherstellen, dass die Anfrage erfolgreich ist
            data = response.json()
            if "items" in data:  # Sicherstellen, dass "items" im JSON vorhanden ist
                df_temp = pd.DataFrame.from_dict(data["items"])
                
                # Füge die Suchanfrage als Spalte hinzu
                df_temp["search_term"] = query
                
                # Filtere nur die gewünschten Spalten
                df_temp = df_temp[["id", "label", "author", "type", "date", "year", "search_term", "tags", "description", "changeDate", "url", "pub-type", "publisher"]]
                
                # Kombiniere den aktuellen DataFrame mit dem finalen DataFrame
                df = pd.concat([df, df_temp], ignore_index=True)
    return df

# Suche durchführen
df_bibsonomy = bibsonomy_pubs(["terrorism", "extremism", "islamism"])

# Ausgabe des finalen DataFrames
df_bibsonomy
# Out:
#                                                      id  \
# 0     https://www.bibsonomy.org/url/a864ce7a699f298b...
# 1     https://www.bibsonomy.org/url/5fddf40b64888908...
# 2     https://www.bibsonomy.org/url/07b5970f2929a2e1...
# 3     https://www.bibsonomy.org/url/dff53678a84d36e9...
# 4     https://www.bibsonomy.org/url/5ad307232bdcf55c...
# ...                                                 ...
# 4489  https://www.bibsonomy.org/bibtex/2ca4013002a4a...
# 4490  https://www.bibsonomy.org/bibtex/2da18cb667b6b...
# 4491  https://www.bibsonomy.org/bibtex/283d78840230a...
# 4492  https://www.bibsonomy.org/bibtex/2fb7edce6fd76...
# 4493  https://www.bibsonomy.org/bibtex/2556ca293e7d6...
#
#                                                   label  \
# 0     RAND Voices of Jihad Database (Terrorism Datab...
# 1                           FRIDE - Money and terrorism
# 2     EU Terrorism Situation & Trend Report (Te-Sat)...
# 3     Andrew Sullivan, terrorism, and the art of dis...
# 4            MILF and terrorism: Hypocrisy, lies, truth
# ...                                                 ...
# 4489  Synthesis, characterization, crystal structure...
# 4490  Mononuclear nickel(II) complexes coordinated b...
# 4491  Syntheses, crystal, molecular structures, and ...
# 4492  La città ineguale. Pratiche culturali e organi...
# 4493  Global incidence, prevalence, years lived with...
#
#                                                  author         type  \
# 0                                                   NaN     Bookmark
# 1                                                   NaN     Bookmark
# 2                                                   NaN     Bookmark
# 3                                                   NaN     Bookmark
# 4                                                   NaN     Bookmark
# ...                                                 ...          ...
# 4489  [Robabeh Alizadeh, Salma Hafezeffati, Vahid Am...  Publication
# 4490  [Hassan Hadadzadeh, Ghobad Mansouri, Ali Rezva...  Publication
# 4491  [M. Mirzaei, H. Eshtiagh-Hosseini, N. Alfi, H....  Publication
# 4492                     [ a cura di Cattedra e Memoli]  Publication
# 4493  [Alize J Ferrari, Damian Francesco Santomauro,...  Publication
#
#                      date    year search_term  \
# 0     2010-06-22 21:44:54     NaN   terrorism
# 1     2014-01-07 13:18:37     NaN   terrorism
# 2     2017-08-25 12:27:11     NaN   terrorism
# 3     2014-01-07 13:18:36     NaN   terrorism
# 4     2012-10-18 14:23:57     NaN   terrorism
# ...                   ...     ...         ...
# 4489  2017-05-10 15:29:29  {2015}    islamism
# 4490  2017-05-10 15:29:29  {2011}    islamism
# 4491  2017-05-10 15:29:29  {2011}    islamism
# 4492  2014-04-10 00:42:49    1999    islamism
# 4493  2024-04-19 11:49:43    2024    islamism
#
#                                                    tags  \
# 0     [jihadist, terrorism, speeches, extremist, jih...
# 1                                    [terrorism, money]
# 2                                       [terrorism, eu]
# 3                [islam, imperialism, terrorism, quinn]
# 4                            [Asia, terrorism, history]
# ...                                                 ...
# 4489  [Fluorescence}, Crystal, {Gold(III);, structur...
# 4490  [Polypyridyl, Magnetic, Nickel(II), {Polymorph...
# 4491  [studies;, Coordination, DFT}, acid;, Crystal,...
# 4492  [africa, latina, Pratiche, marginalità, urbani...
# 4493  [prevalence, disability, LongLIfe, LifeExpenta...
#
#                                             description           changeDate  \
# 0     This online database is a compilation of speec...  2010-06-22 21:44:54
# 1     Loretta Napoleoni (07/01/2005) "FRIDE is a Eur...  2014-10-14 15:29:31
# 2     "Europol’s annual EU Terrorism Situation and T...  2017-08-25 12:32:17
# 3     analysis of the concept of terrorism after the...  2014-10-14 15:29:29
# 4     For now, it remains an agreement to agree – a ...  2012-10-18 14:23:57
# ...                                                 ...                  ...
# 4489                                                     2017-05-10 15:29:29
# 4490                                                     2017-05-10 15:29:29
# 4491                                                     2017-05-10 15:29:29
# 4492  La città ineguale. Pratiche culturali e organi...  2014-04-10 19:37:58
# 4493                                                     2024-04-19 11:49:43
#
#                                                     url pub-type  \
# 0     http://www.rand.org/research_areas/terrorism/d...      NaN
# 1     http://www.fride.org/publication/93/money-and-...      NaN
# 2     https://www.europol.europa.eu/activities-servi...      NaN
# 3     http://www.guardian.co.uk/commentisfree/2013/m...      NaN
# 4     http://www.rappler.com/thought-leaders/14222-m...      NaN
# ...                                                 ...      ...
# 4489                                                     article
# 4490                                                     article
# 4491                                                     article
# 4492                                                        book
# 4493                                                     article
#
#                           publisher
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 4489                  SPRINGER WIEN
# 4490  PERGAMON-ELSEVIER SCIENCE LTD
# 4491     SPRINGER/PLENUM PUBLISHERS
# 4492                        Mimesis
# 4493                    Elsevier BV
#
# [4494 rows x 13 columns]

# %%
df_bibsonomy = df_bibsonomy[df_bibsonomy["type"] == "Publication"]
df_bibsonomy
# Out:
#                                                      id  \
# 1000  https://www.bibsonomy.org/bibtex/22e03edf1449f...
# 1001  https://www.bibsonomy.org/bibtex/26a182024b6db...
# 1002  https://www.bibsonomy.org/bibtex/201c2fea8172a...
# 1003  https://www.bibsonomy.org/bibtex/2273978ed4446...
# 1004  https://www.bibsonomy.org/bibtex/2adba8d1854b2...
# ...                                                 ...
# 4489  https://www.bibsonomy.org/bibtex/2ca4013002a4a...
# 4490  https://www.bibsonomy.org/bibtex/2da18cb667b6b...
# 4491  https://www.bibsonomy.org/bibtex/283d78840230a...
# 4492  https://www.bibsonomy.org/bibtex/2fb7edce6fd76...
# 4493  https://www.bibsonomy.org/bibtex/2556ca293e7d6...
#
#                                                   label  \
# 1000                                     Food Terrorism
# 1001  How does Terrorism Effect on Business and Rela...
# 1002  Money Transfer Regulation and the Fight agains...
# 1003  State terrorism in Latin America : Chile, Arge...
# 1004  The Role of Extradition Treaties in Crime Mana...
# ...                                                 ...
# 4489  Synthesis, characterization, crystal structure...
# 4490  Mononuclear nickel(II) complexes coordinated b...
# 4491  Syntheses, crystal, molecular structures, and ...
# 4492  La città ineguale. Pratiche culturali e organi...
# 4493  Global incidence, prevalence, years lived with...
#
#                                                  author         type  \
# 1000  [Matthew N. O. Sadiku | Sarhan M. Musa | Tolul...  Publication
# 1001                     [S. Raju Pooja Prof. Sidharth]  Publication
# 1002                            [Lukong Alban Bongwong]  Publication
# 1003                                    [Thomas Wright]  Publication
# 1004                      [AdishiEric OlukaNduka Lucas]  Publication
# ...                                                 ...          ...
# 4489  [Robabeh Alizadeh, Salma Hafezeffati, Vahid Am...  Publication
# 4490  [Hassan Hadadzadeh, Ghobad Mansouri, Ali Rezva...  Publication
# 4491  [M. Mirzaei, H. Eshtiagh-Hosseini, N. Alfi, H....  Publication
# 4492                     [ a cura di Cattedra e Memoli]  Publication
# 4493  [Alize J Ferrari, Damian Francesco Santomauro,...  Publication
#
#                      date    year search_term  \
# 1000  2019-07-04 12:16:18    2019   terrorism
# 1001  2018-09-11 08:26:02    2017   terrorism
# 1002  2020-10-03 11:41:39    2020   terrorism
# 1003  2015-07-23 15:15:26    2007   terrorism
# 1004  2018-09-01 12:55:37    2018   terrorism
# ...                   ...     ...         ...
# 4489  2017-05-10 15:29:29  {2015}    islamism
# 4490  2017-05-10 15:29:29  {2011}    islamism
# 4491  2017-05-10 15:29:29  {2011}    islamism
# 4492  2014-04-10 00:42:49    1999    islamism
# 4493  2024-04-19 11:49:43    2024    islamism
#
#                                                    tags  \
# 1000       [terrorism, biological, defense, food, agro]
# 1001  [Business, (IB), Terrorism, business, Internat...
# 1002    [Other, transfer, terrorism, corruption, Funds]
# 1003  [außenpolitik, usa, menschenrechte, politik, l...
# 1004  [Extradition, Crime, Terrorism, treaties, chal...
# ...                                                 ...
# 4489  [Fluorescence}, Crystal, {Gold(III);, structur...
# 4490  [Polypyridyl, Magnetic, Nickel(II), {Polymorph...
# 4491  [studies;, Coordination, DFT}, acid;, Crystal,...
# 4492  [africa, latina, Pratiche, marginalità, urbani...
# 4493  [prevalence, disability, LongLIfe, LifeExpenta...
#
#                                             description           changeDate  \
# 1000                                                     2019-07-04 12:16:18
# 1001                                                     2018-10-02 11:01:26
# 1002                                                     2020-10-03 11:41:39
# 1003  State Terrorism in Latin America: Chile, Argen...  2020-11-20 13:41:20
# 1004                                                     2018-10-02 11:01:26
# ...                                                 ...                  ...
# 4489                                                     2017-05-10 15:29:29
# 4490                                                     2017-05-10 15:29:29
# 4491                                                     2017-05-10 15:29:29
# 4492  La città ineguale. Pratiche culturali e organi...  2014-04-10 19:37:58
# 4493                                                     2024-04-19 11:49:43
#
#                                                     url pub-type  \
# 1000  https://www.ijtsrd.com/other-scientific-resear...  article
# 1001  http://www.ijtsrd.com/management/international...  article
# 1002  https://www.ijtsrd.com/other-scientific-resear...  article
# 1003  http://www.amazon.de/State-Terrorism-Latin-Ame...     book
# 1004  http://www.ijtsrd.com/humanities-and-the-arts/...  article
# ...                                                 ...      ...
# 4489                                                     article
# 4490                                                     article
# 4491                                                     article
# 4492                                                        book
# 4493                                                     article
#
#                           publisher
# 1000                            NaN
# 1001                            NaN
# 1002                            NaN
# 1003           Rowman & Littlefield
# 1004                            NaN
# ...                             ...
# 4489                  SPRINGER WIEN
# 4490  PERGAMON-ELSEVIER SCIENCE LTD
# 4491     SPRINGER/PLENUM PUBLISHERS
# 4492                        Mimesis
# 4493                    Elsevier BV
#
# [2790 rows x 13 columns]

# %%
if not pt.started():
    pt.init()
# Out:
# /tmp/ipykernel_18790/3057724015.py:1: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# /tmp/ipykernel_18790/3057724015.py:2: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# java is now started automatically with default settings. To force initialisation early, run:
# pt.java.init() # optional, forces java initialisation
#   pt.init()

# %%
#Umbenennung der Spalten zur Vorbereitung auf die Indexierung/Dokumentenrepräsentation
df_bibsonomy['docno'] = df_bibsonomy['id']
df_bibsonomy['text'] = df_bibsonomy['label']
# Out:
# /tmp/ipykernel_18790/967087675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bibsonomy['docno'] = df_bibsonomy['id']
# /tmp/ipykernel_18790/967087675.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bibsonomy['text'] = df_bibsonomy['label']

# %%
index_folder = "/home/tim/Schreibtisch/2024-25-Data_Librarian-Reschop_Tim/Modul_2-1/violence_index" #anlegen eines Speicherortes für unseres Index/Dokumentenrepräsentation

indexer = pt.DFIndexer(index_folder, overwrite=True) #DataFrameIndexer für die Indexierung auswählen und festlegen wo er gespeichert werden soll und das ein bereits bestehender Index überschrieben werden soll
index_ref = indexer.index(df_bibsonomy['text'], df_bibsonomy['docno']) #Festlegen, aus welchen Spalten des DF der Index erstellt wird

#Dieser Code erstellt einen IR-Index (Information Retrieval Index) aus dem DataFrame df_bibsonomy. 
#Die Spalte text enthält die Dokumentinhalte, die indexiert werden, und docno wird als eindeutige ID für jedes Dokument verwendet. 
#Mit diesem Index kannst du später Suchanfragen ausführen oder andere IR-Operationen mit PyTerrier durchführen.

print(f"path to our index: {index_ref.toString()}")
# Out:
# /tmp/ipykernel_18790/2736489296.py:3: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.DFIndexer(index_folder, overwrite=True) #DataFrameIndexer für die Indexierung auswählen und festlegen wo er gespeichert werden soll und das ein bereits bestehender Index überschrieben werden soll
# path to our index: /home/tim/Schreibtisch/2024-25-Data_Librarian-Reschop_Tim/Modul_2-1/violence_index/data.properties

# %%
#Index-Instanz aus der zuvor erstellten Index-Referenz (index_ref) erstellen
#pt.IndexFactory: Eine Klasse in PyTerrier, die verwendet wird, um mit Indexen zu arbeiten (z. B. erstellen, laden, verwenden).
#.of(index_ref): Diese Methode erstellt ein Indexobjekt aus der Referenz (index_ref), die auf den Speicherort des Index zeigt.
#Das zurückgegebene Objekt (index) ermöglicht es dir, auf den Index zuzugreifen und Operationen wie Suchen, Abrufen von Metadaten oder Statistiken auszuführen.

index = pt.IndexFactory.of(index_ref)

#Der zuvor erstellte Index (index_ref) ist lediglich ein Verweis auf den Speicherort des Index (normalerweise ein Ordner auf der Festplatte). 
#Mit pt.IndexFactory.of() wird dieser Verweis "geladen" und als voll funktionsfähiger Index bereitgestellt.
#Erst jetzt haben wir einen Index

# %%
print(index.getCollectionStatistics().toString())

#.toString() wird aufgerufen, um dieses Objekt in eine lesbare String-Repräsentation zu konvertieren. 
#So kannst du die Statistiken einfach ausgeben, z. B. in der Konsole oder Logs.
# Out:
# Number of documents: 2790
# Number of terms: 5195
# Number of postings: 22578
# Number of fields: 0
# Number of tokens: 23192
# Field names: []
# Positions:   false

# %%
#term -> term_id Nt Tf
#Nt: In how many documents does the term occur?
#TF (Term Frequency): How often does the term occur in total?

for kv in index.getLexicon(): #gibt eine Sammlung zurück (das Lexikon), die alle Terme und ihre zugehörigen Informationen enthält.
    print(f"{kv.getKey()} -> {kv.getValue().toString()}") #kv.getValue() liefert ein Objekt, das die Statistiken oder Informationen über den Term enthält.
                                                          #.toString() gibt eine lesbare Form aus
# Out:
# 0 -> term1709 Nt=4 TF=4 maxTF=1 @{0 0 0}
# 00 -> term2910 Nt=1 TF=1 maxTF=1 @{0 9 2}
# 03 -> term290 Nt=1 TF=1 maxTF=1 @{0 12 0}
# 1 -> term107 Nt=52 TF=60 maxTF=3 @{0 13 6}
# 10 -> term2997 Nt=8 TF=8 maxTF=1 @{0 72 2}
# 100 -> term2919 Nt=1 TF=1 maxTF=1 @{0 82 4}
# 1068 -> term4944 Nt=1 TF=1 maxTF=1 @{0 85 2}
# 11 -> term347 Nt=23 TF=23 maxTF=1 @{0 88 2}
# 11th -> term1153 Nt=2 TF=2 maxTF=1 @{0 118 2}
# 12 -> term2493 Nt=3 TF=3 maxTF=1 @{0 122 6}
# 129a -> term1991 Nt=1 TF=1 maxTF=1 @{0 130 4}
# 129b -> term1621 Nt=1 TF=1 maxTF=1 @{0 133 0}
# 12th -> term1148 Nt=1 TF=1 maxTF=1 @{0 135 4}
# 13 -> term3598 Nt=2 TF=2 maxTF=1 @{0 137 6}
# 134 -> term1671 Nt=1 TF=1 maxTF=1 @{0 143 2}
# 14 -> term2602 Nt=1 TF=1 maxTF=1 @{0 145 6}
# 1442 -> term4451 Nt=1 TF=1 maxTF=1 @{0 148 4}
# 14h -> term3616 Nt=1 TF=1 maxTF=1 @{0 151 4}
# 16 -> term2823 Nt=3 TF=3 maxTF=1 @{0 154 4}
# 167em -> term2909 Nt=1 TF=1 maxTF=1 @{0 162 0}
# 17 -> term4437 Nt=1 TF=1 maxTF=1 @{0 164 6}
# 1790 -> term2330 Nt=1 TF=1 maxTF=1 @{0 167 6}
# 1797 -> term3804 Nt=1 TF=1 maxTF=1 @{0 170 4}
# 18 -> term2814 Nt=3 TF=3 maxTF=1 @{0 173 4}
# 1825 -> term3147 Nt=1 TF=1 maxTF=1 @{0 179 6}
# 1837 -> term1905 Nt=3 TF=3 maxTF=1 @{0 182 4}
# 1842 -> term4656 Nt=1 TF=1 maxTF=1 @{0 188 2}
# 1871 -> term2571 Nt=2 TF=2 maxTF=1 @{0 191 2}
# 19 -> term1249 Nt=7 TF=7 maxTF=1 @{0 194 6}
# 1901 -> term2559 Nt=1 TF=1 maxTF=1 @{0 206 2}
# 1908 -> term3343 Nt=4 TF=4 maxTF=1 @{0 209 0}
# 1914 -> term2760 Nt=3 TF=3 maxTF=1 @{0 215 0}
# 1918 -> term1996 Nt=1 TF=1 maxTF=1 @{0 220 4}
# 1922 -> term2009 Nt=1 TF=1 maxTF=1 @{0 223 0}
# 1930 -> term4608 Nt=1 TF=1 maxTF=1 @{0 225 4}
# 1933 -> term2199 Nt=1 TF=1 maxTF=1 @{0 228 4}
# 1935 -> term4381 Nt=1 TF=1 maxTF=1 @{0 231 0}
# 1941 -> term2238 Nt=1 TF=1 maxTF=1 @{0 234 0}
# 1943 -> term77 Nt=1 TF=1 maxTF=1 @{0 236 4}
# 1944 -> term2242 Nt=1 TF=1 maxTF=1 @{0 237 6}
# 1945 -> term2198 Nt=1 TF=1 maxTF=1 @{0 240 2}
# 1946 -> term2557 Nt=1 TF=1 maxTF=1 @{0 242 6}
# 1947 -> term2974 Nt=1 TF=1 maxTF=1 @{0 245 4}
# 1950 -> term3084 Nt=3 TF=3 maxTF=1 @{0 248 2}
# 1951 -> term2502 Nt=2 TF=2 maxTF=1 @{0 255 4}
# 1957 -> term2470 Nt=1 TF=1 maxTF=1 @{0 260 0}
# 1958 -> term1208 Nt=1 TF=1 maxTF=1 @{0 262 6}
# 1959 -> term3076 Nt=2 TF=2 maxTF=1 @{0 265 0}
# 1961 -> term3144 Nt=1 TF=1 maxTF=1 @{0 269 6}
# 1963 -> term3701 Nt=1 TF=1 maxTF=1 @{0 272 4}
# 1968 -> term702 Nt=2 TF=2 maxTF=1 @{0 275 4}
# 1969 -> term1132 Nt=2 TF=2 maxTF=1 @{0 280 2}
# 1970 -> term31 Nt=7 TF=7 maxTF=1 @{0 284 6}
# 1970er -> term2143 Nt=1 TF=1 maxTF=1 @{0 297 0}
# 1972 -> term1204 Nt=2 TF=2 maxTF=1 @{0 299 4}
# 1974 -> term1131 Nt=1 TF=1 maxTF=1 @{0 304 0}
# 1975 -> term2001 Nt=1 TF=1 maxTF=1 @{0 306 2}
# 1977 -> term2243 Nt=1 TF=1 maxTF=1 @{0 308 6}
# 1978 -> term3922 Nt=2 TF=2 maxTF=1 @{0 311 2}
# 1979 -> term1206 Nt=4 TF=4 maxTF=1 @{0 315 4}
# 1980 -> term2411 Nt=2 TF=2 maxTF=1 @{0 324 6}
# 1981 -> term2000 Nt=1 TF=1 maxTF=1 @{0 330 2}
# 1982 -> term1647 Nt=1 TF=1 maxTF=1 @{0 332 6}
# 1984 -> term4472 Nt=2 TF=2 maxTF=1 @{0 335 2}
# 1985 -> term4866 Nt=1 TF=1 maxTF=1 @{0 340 2}
# 1986 -> term923 Nt=2 TF=2 maxTF=1 @{0 343 2}
# 1989 -> term4733 Nt=1 TF=1 maxTF=1 @{0 348 0}
# 1990 -> term4852 Nt=3 TF=3 maxTF=1 @{0 351 0}
# 1991 -> term2761 Nt=1 TF=1 maxTF=1 @{0 356 6}
# 1992 -> term1902 Nt=1 TF=1 maxTF=1 @{0 359 4}
# 1993 -> term1962 Nt=1 TF=1 maxTF=1 @{0 362 0}
# 1995 -> term3923 Nt=3 TF=3 maxTF=1 @{0 364 4}
# 1997 -> term696 Nt=1 TF=1 maxTF=1 @{0 370 4}
# 1998 -> term3905 Nt=1 TF=1 maxTF=1 @{0 372 6}
# 1999 -> term4471 Nt=3 TF=3 maxTF=1 @{0 375 6}
# 19th -> term3275 Nt=1 TF=1 maxTF=1 @{0 382 0}
# 1d -> term5092 Nt=1 TF=1 maxTF=1 @{0 384 6}
# 1h -> term3583 Nt=8 TF=8 maxTF=1 @{0 387 6}
# 1st -> term2176 Nt=1 TF=1 maxTF=1 @{0 400 6}
# 1t -> term3658 Nt=2 TF=2 maxTF=1 @{0 403 2}
# 1tn -> term3567 Nt=1 TF=1 maxTF=1 @{0 406 4}
# 2 -> term93 Nt=74 TF=137 maxTF=5 @{0 409 4}
# 20 -> term3268 Nt=2 TF=2 maxTF=1 @{0 477 7}
# 2000 -> term1485 Nt=1 TF=1 maxTF=1 @{0 483 1}
# 2001 -> term1129 Nt=2 TF=2 maxTF=1 @{0 485 5}
# 2002 -> term1027 Nt=5 TF=5 maxTF=1 @{0 490 1}
# 2003 -> term2596 Nt=2 TF=2 maxTF=1 @{0 499 7}
# 2004 -> term1336 Nt=2 TF=2 maxTF=1 @{0 505 3}
# 2005 -> term558 Nt=2 TF=2 maxTF=1 @{0 510 1}
# 2006 -> term3085 Nt=2 TF=2 maxTF=1 @{0 514 7}
# 2007 -> term726 Nt=1 TF=1 maxTF=1 @{0 520 1}
# 2008 -> term3495 Nt=4 TF=4 maxTF=1 @{0 522 3}
# 2009 -> term725 Nt=4 TF=4 maxTF=1 @{0 530 5}
# 2010 -> term1413 Nt=5 TF=5 maxTF=1 @{0 539 7}
# 2011 -> term3352 Nt=1 TF=1 maxTF=1 @{0 551 3}
# 2012 -> term2495 Nt=2 TF=2 maxTF=1 @{0 554 1}
# 2013 -> term1192 Nt=4 TF=5 maxTF=2 @{0 559 3}
# 2014 -> term3077 Nt=2 TF=2 maxTF=1 @{0 568 6}
# 2015 -> term857 Nt=4 TF=4 maxTF=1 @{0 573 4}
# 2016 -> term1739 Nt=2 TF=2 maxTF=1 @{0 583 2}
# 2017 -> term2815 Nt=1 TF=1 maxTF=1 @{0 588 4}
# 2018 -> term705 Nt=4 TF=4 maxTF=1 @{0 591 2}
# 2020 -> term851 Nt=5 TF=5 maxTF=1 @{0 601 0}
# 2021 -> term3269 Nt=2 TF=3 maxTF=2 @{0 611 4}
# 2022 -> term856 Nt=1 TF=1 maxTF=1 @{0 616 7}
# 2030 -> term3416 Nt=1 TF=1 maxTF=1 @{0 619 1}
# 204 -> term5193 Nt=1 TF=1 maxTF=1 @{0 621 7}
# 20th -> term2586 Nt=2 TF=2 maxTF=1 @{0 624 7}
# 21 -> term4257 Nt=1 TF=1 maxTF=1 @{0 629 7}
# 21st -> term949 Nt=6 TF=8 maxTF=2 @{0 632 7}
# 22nd -> term1408 Nt=1 TF=1 maxTF=1 @{0 643 1}
# 23 -> term2007 Nt=1 TF=1 maxTF=1 @{0 645 5}
# 26 -> term1283 Nt=2 TF=2 maxTF=1 @{0 648 1}
# 29 -> term4834 Nt=1 TF=1 maxTF=1 @{0 652 3}
# 2h -> term4045 Nt=2 TF=2 maxTF=1 @{0 655 3}
# 2so -> term4051 Nt=1 TF=1 maxTF=1 @{0 660 3}
# 3 -> term1094 Nt=26 TF=34 maxTF=4 @{0 663 3}
# 30 -> term2545 Nt=1 TF=1 maxTF=1 @{0 698 1}
# 33 -> term2751 Nt=1 TF=1 maxTF=1 @{0 700 7}
# 360 -> term1914 Nt=1 TF=1 maxTF=1 @{0 703 5}
# 371 -> term5190 Nt=1 TF=1 maxTF=1 @{0 706 1}
# 3d -> term3155 Nt=6 TF=6 maxTF=1 @{0 709 1}
# 3h -> term4044 Nt=4 TF=4 maxTF=1 @{0 721 3}
# 4 -> term2222 Nt=43 TF=56 maxTF=3 @{0 727 3}
# 41 -> term3870 Nt=1 TF=1 maxTF=1 @{0 763 2}
# 439 -> term4988 Nt=1 TF=1 maxTF=1 @{0 766 2}
# 48 -> term4806 Nt=1 TF=1 maxTF=1 @{0 769 2}
# 4h -> term3605 Nt=1 TF=1 maxTF=1 @{0 772 2}
# 4h2o -> term3604 Nt=1 TF=1 maxTF=1 @{0 775 2}
# 5 -> term616 Nt=30 TF=40 maxTF=3 @{0 778 2}
# 5h -> term4303 Nt=1 TF=1 maxTF=1 @{0 816 0}
# 5oh -> term4052 Nt=1 TF=1 maxTF=1 @{0 819 0}
# 6 -> term5020 Nt=11 TF=13 maxTF=2 @{0 822 0}
# 622 -> term4813 Nt=1 TF=1 maxTF=1 @{0 832 2}
# 646 -> term1091 Nt=1 TF=1 maxTF=1 @{0 835 2}
# 651 -> term4810 Nt=1 TF=1 maxTF=1 @{0 837 4}
# 6h -> term4305 Nt=1 TF=1 maxTF=1 @{0 840 4}
# 7 -> term4716 Nt=6 TF=6 maxTF=1 @{0 843 4}
# 70 -> term2825 Nt=1 TF=1 maxTF=1 @{0 852 4}
# 700 -> term3475 Nt=2 TF=2 maxTF=1 @{0 855 2}
# 70er -> term1397 Nt=1 TF=1 maxTF=1 @{0 860 6}
# 787 -> term3476 Nt=1 TF=1 maxTF=1 @{0 863 2}
# 8 -> term4082 Nt=3 TF=5 maxTF=2 @{0 866 2}
# 811 -> term5187 Nt=1 TF=1 maxTF=1 @{0 873 6}
# 828 -> term3805 Nt=1 TF=1 maxTF=1 @{0 876 6}
# 87 -> term4865 Nt=1 TF=1 maxTF=1 @{0 879 6}
# 8h2o -> term3866 Nt=1 TF=1 maxTF=1 @{0 882 6}
# 9 -> term374 Nt=10 TF=10 maxTF=1 @{0 885 6}
# 98 -> term1210 Nt=2 TF=2 maxTF=1 @{0 902 2}
# 99 -> term2558 Nt=3 TF=3 maxTF=1 @{0 907 4}
# ab -> term2927 Nt=5 TF=5 maxTF=1 @{0 913 2}
# abb -> term4721 Nt=1 TF=1 maxTF=1 @{0 924 4}
# abbau -> term2017 Nt=1 TF=1 maxTF=1 @{0 927 4}
# abd -> term4037 Nt=2 TF=2 maxTF=1 @{0 930 0}
# abdarraziq -> term3674 Nt=1 TF=1 maxTF=1 @{0 935 2}
# abduct -> term2863 Nt=1 TF=1 maxTF=1 @{0 938 2}
# abdul -> term3447 Nt=1 TF=1 maxTF=1 @{0 941 0}
# abdurahman -> term4395 Nt=1 TF=1 maxTF=1 @{0 944 0}
# abhandlung -> term4228 Nt=1 TF=1 maxTF=1 @{0 947 0}
# abil -> term2962 Nt=3 TF=3 maxTF=1 @{0 950 0}
# abnorm -> term1431 Nt=1 TF=1 maxTF=1 @{0 957 2}
# abort -> term2269 Nt=1 TF=1 maxTF=1 @{0 959 6}
# abrupt -> term2868 Nt=1 TF=1 maxTF=1 @{0 962 2}
# abschrecken -> term3113 Nt=1 TF=1 maxTF=1 @{0 965 0}
# absolut -> term3178 Nt=1 TF=1 maxTF=1 @{0 967 6}
# abstract -> term3300 Nt=1 TF=1 maxTF=1 @{0 970 4}
# abu -> term3820 Nt=1 TF=1 maxTF=1 @{0 973 2}
# abus -> term3281 Nt=1 TF=1 maxTF=1 @{0 976 2}
# abyei -> term1860 Nt=1 TF=1 maxTF=1 @{0 979 0}
# academ -> term3382 Nt=1 TF=1 maxTF=1 @{0 981 4}
# academi -> term898 Nt=1 TF=1 maxTF=1 @{0 984 2}
# acceler -> term2848 Nt=8 TF=8 maxTF=1 @{0 986 4}
# accelerometri -> term3159 Nt=1 TF=1 maxTF=1 @{0 999 2}
# accept -> term814 Nt=2 TF=2 maxTF=1 @{0 1002 0}
# access -> term1242 Nt=4 TF=4 maxTF=1 @{0 1007 2}
# accid -> term1930 Nt=1 TF=1 maxTF=1 @{0 1015 6}
# accident -> term1863 Nt=1 TF=1 maxTF=1 @{0 1018 2}
# accommod -> term3460 Nt=1 TF=1 maxTF=1 @{0 1020 6}
# account -> term1008 Nt=8 TF=8 maxTF=1 @{0 1023 6}
# accumul -> term251 Nt=3 TF=3 maxTF=1 @{0 1041 0}
# accuraci -> term2870 Nt=2 TF=2 maxTF=1 @{0 1047 4}
# acet -> term4041 Nt=1 TF=1 maxTF=1 @{0 1052 4}
# acetamido -> term3894 Nt=1 TF=1 maxTF=1 @{0 1055 4}
# acetaminophen -> term3950 Nt=1 TF=1 maxTF=1 @{0 1058 4}
# acetonitril -> term5061 Nt=1 TF=1 maxTF=1 @{0 1061 4}
# acetylen -> term3812 Nt=5 TF=5 maxTF=1 @{0 1064 4}
# achiev -> term3402 Nt=3 TF=3 maxTF=1 @{0 1074 2}
# acid -> term1346 Nt=11 TF=13 maxTF=2 @{0 1081 2}
# acii -> term3506 Nt=1 TF=1 maxTF=1 @{0 1097 2}
# acoust -> term870 Nt=1 TF=1 maxTF=1 @{0 1100 2}
# acquisit -> term199 Nt=2 TF=2 maxTF=1 @{0 1102 4}
# across -> term1749 Nt=7 TF=7 maxTF=1 @{0 1107 0}
# acryl -> term5071 Nt=1 TF=1 maxTF=1 @{0 1120 6}
# act -> term139 Nt=8 TF=8 maxTF=1 @{0 1123 6}
# action -> term282 Nt=11 TF=11 maxTF=1 @{0 1137 6}
# activ -> term6 Nt=49 TF=50 maxTF=2 @{0 1157 6}
# activist -> term2335 Nt=1 TF=1 maxTF=1 @{0 1218 7}
# actor -> term100 Nt=5 TF=5 maxTF=1 @{0 1221 5}
# actuat -> term3156 Nt=4 TF=4 maxTF=1 @{0 1229 3}
# ad -> term2583 Nt=6 TF=6 maxTF=1 @{0 1236 1}
# adaboost -> term1518 Nt=1 TF=1 maxTF=1 @{0 1248 7}
# adapt -> term97 Nt=26 TF=26 maxTF=1 @{0 1251 3}
# addit -> term2461 Nt=6 TF=6 maxTF=1 @{0 1288 5}
# address -> term241 Nt=7 TF=7 maxTF=1 @{0 1301 3}
# adjoin -> term2496 Nt=1 TF=1 maxTF=1 @{0 1314 1}
# adjunct -> term2565 Nt=1 TF=1 maxTF=1 @{0 1316 7}
# adjust -> term2417 Nt=4 TF=4 maxTF=1 @{0 1319 5}
# adl -> term4354 Nt=2 TF=2 maxTF=1 @{0 1328 1}
# administr -> term4349 Nt=2 TF=2 maxTF=1 @{0 1332 3}
# adolesc -> term2995 Nt=1 TF=1 maxTF=1 @{0 1336 3}
# adoleszent -> term4628 Nt=1 TF=1 maxTF=1 @{0 1339 1}
# adopt -> term988 Nt=6 TF=6 maxTF=1 @{0 1342 1}
# adr -> term4414 Nt=1 TF=1 maxTF=1 @{0 1355 1}
# adsorb -> term3610 Nt=1 TF=1 maxTF=1 @{0 1358 1}
# adsorpt -> term3579 Nt=6 TF=6 maxTF=1 @{0 1361 1}
# adult -> term2711 Nt=2 TF=2 maxTF=1 @{0 1371 1}
# advanc -> term648 Nt=8 TF=8 maxTF=1 @{0 1376 5}
# advantag -> term227 Nt=2 TF=2 maxTF=1 @{0 1391 7}
# advent -> term837 Nt=1 TF=1 maxTF=1 @{0 1396 5}
# adventur -> term2767 Nt=1 TF=1 maxTF=1 @{0 1398 7}
# adversari -> term1980 Nt=2 TF=2 maxTF=1 @{0 1401 5}
# advisori -> term4221 Nt=1 TF=1 maxTF=1 @{0 1406 7}
# aerosol -> term2734 Nt=1 TF=1 maxTF=1 @{0 1409 7}
# aev -> term2045 Nt=1 TF=1 maxTF=1 @{0 1412 5}
# affair -> term32 Nt=3 TF=3 maxTF=1 @{0 1415 1}
# affect -> term162 Nt=6 TF=6 maxTF=1 @{0 1421 1}
# affin -> term2268 Nt=1 TF=1 maxTF=1 @{0 1432 7}
# affluenc -> term1859 Nt=1 TF=1 maxTF=1 @{0 1435 3}
# afford -> term3810 Nt=1 TF=1 maxTF=1 @{0 1437 7}
# afghanistan -> term190 Nt=2 TF=2 maxTF=1 @{0 1440 7}
# afla -> term4411 Nt=1 TF=1 maxTF=1 @{0 1445 3}
# africa -> term372 Nt=9 TF=9 maxTF=1 @{0 1448 3}
# african -> term1814 Nt=1 TF=1 maxTF=1 @{0 1466 7}
# aftermath -> term1743 Nt=2 TF=2 maxTF=1 @{0 1469 3}
# ag -> term216 Nt=19 TF=19 maxTF=1 @{0 1472 5}
# agcl -> term3647 Nt=1 TF=1 maxTF=1 @{0 1503 7}
# agenc -> term570 Nt=4 TF=4 maxTF=1 @{0 1506 7}
# agenda -> term2263 Nt=1 TF=1 maxTF=1 @{0 1514 5}
# agent -> term144 Nt=21 TF=21 maxTF=1 @{0 1517 1}
# aggreg -> term2456 Nt=6 TF=6 maxTF=1 @{0 1549 1}
# aggress -> term4740 Nt=1 TF=1 maxTF=1 @{0 1560 1}
# agil -> term1808 Nt=1 TF=1 maxTF=1 @{0 1563 1}
# agreement -> term2266 Nt=2 TF=2 maxTF=1 @{0 1565 5}
# agro -> term829 Nt=1 TF=1 maxTF=1 @{0 1569 7}
# agua -> term4066 Nt=1 TF=1 maxTF=1 @{0 1572 1}
# ah -> term4453 Nt=1 TF=1 maxTF=1 @{0 1575 1}
# ahmad -> term3823 Nt=2 TF=2 maxTF=1 @{0 1578 1}
# ahror -> term3785 Nt=1 TF=1 maxTF=1 @{0 1583 3}
# ai -> term450 Nt=7 TF=8 maxTF=2 @{0 1586 3}
# aid -> term1790 Nt=2 TF=2 maxTF=1 @{0 1600 6}
# air -> term578 Nt=3 TF=3 maxTF=1 @{0 1606 0}
# aircraft -> term2926 Nt=1 TF=1 maxTF=1 @{0 1612 6}
# airflow -> term2612 Nt=2 TF=2 maxTF=1 @{0 1615 4}
# airplan -> term2023 Nt=1 TF=1 maxTF=1 @{0 1620 0}
# airport -> term1872 Nt=1 TF=1 maxTF=1 @{0 1622 4}
# akten -> term2178 Nt=1 TF=1 maxTF=1 @{0 1625 0}
# aktienm -> term3483 Nt=1 TF=1 maxTF=1 @{0 1627 4}
# aktualit -> term999 Nt=1 TF=1 maxTF=1 @{0 1630 4}
# al -> term126 Nt=48 TF=64 maxTF=5 @{0 1632 6}
# alaro -> term3091 Nt=1 TF=1 maxTF=1 @{0 1692 4}
# alaska -> term2820 Nt=1 TF=1 maxTF=1 @{0 1695 2}
# alb -> term1576 Nt=1 TF=1 maxTF=1 @{0 1698 0}
# albtraum -> term1495 Nt=1 TF=1 maxTF=1 @{0 1700 4}
# alder -> term5154 Nt=1 TF=1 maxTF=1 @{0 1703 0}
# alga -> term3212 Nt=1 TF=1 maxTF=1 @{0 1706 0}
# algarv -> term3741 Nt=1 TF=1 maxTF=1 @{0 1708 6}
# algarvio -> term4600 Nt=1 TF=1 maxTF=1 @{0 1711 6}
# algeria -> term3339 Nt=1 TF=1 maxTF=1 @{0 1714 6}
# algerien -> term3924 Nt=3 TF=3 maxTF=1 @{0 1717 4}
# algorithm -> term490 Nt=23 TF=23 maxTF=1 @{0 1723 4}
# alhambra -> term4246 Nt=1 TF=1 maxTF=1 @{0 1757 2}
# ali -> term1058 Nt=4 TF=4 maxTF=1 @{0 1760 2}
# alien -> term2276 Nt=2 TF=2 maxTF=1 @{0 1769 2}
# alish -> term3719 Nt=1 TF=1 maxTF=1 @{0 1774 4}
# alkyl -> term4291 Nt=1 TF=1 maxTF=1 @{0 1777 4}
# allah -> term3050 Nt=1 TF=1 maxTF=1 @{0 1780 4}
# allaqa -> term4901 Nt=1 TF=1 maxTF=1 @{0 1783 2}
# allein -> term2491 Nt=1 TF=1 maxTF=1 @{0 1786 2}
# allen -> term2517 Nt=1 TF=1 maxTF=1 @{0 1789 0}
# allevi -> term4652 Nt=1 TF=1 maxTF=1 @{0 1791 6}
# alli -> term1448 Nt=1 TF=1 maxTF=1 @{0 1794 6}
# allianc -> term1754 Nt=1 TF=1 maxTF=1 @{0 1797 2}
# alloc -> term233 Nt=4 TF=4 maxTF=1 @{0 1799 6}
# almond -> term3940 Nt=1 TF=2 maxTF=2 @{0 1808 4}
# alp -> term2960 Nt=1 TF=1 maxTF=1 @{0 1811 5}
# alpha -> term2532 Nt=2 TF=2 maxTF=1 @{0 1814 3}
# alpin -> term2436 Nt=1 TF=1 maxTF=1 @{0 1819 7}
# alt -> term2306 Nt=1 TF=1 maxTF=1 @{0 1822 5}
# altern -> term1231 Nt=1 TF=1 maxTF=1 @{0 1825 3}
# altmetr -> term4476 Nt=1 TF=1 maxTF=1 @{0 1827 5}
# alumina -> term4725 Nt=1 TF=1 maxTF=1 @{0 1830 5}
# aluminum -> term3897 Nt=1 TF=1 maxTF=1 @{0 1833 5}
# am -> term1731 Nt=11 TF=11 maxTF=1 @{0 1836 5}
# amanah -> term4572 Nt=1 TF=1 maxTF=1 @{0 1855 1}
# amaz -> term3640 Nt=1 TF=1 maxTF=1 @{0 1858 1}
# ambda -> term4294 Nt=1 TF=1 maxTF=1 @{0 1861 1}
# ambigu -> term700 Nt=2 TF=2 maxTF=1 @{0 1864 1}
# ambit -> term4999 Nt=1 TF=1 maxTF=1 @{0 1868 7}
# america -> term19 Nt=9 TF=9 maxTF=1 @{0 1871 7}
# american -> term309 Nt=11 TF=11 maxTF=1 @{0 1889 5}
# amerika -> term2170 Nt=1 TF=1 maxTF=1 @{0 1907 7}
# amidoalkyl -> term3861 Nt=1 TF=1 maxTF=1 @{0 1910 3}
# amino -> term4047 Nt=3 TF=3 maxTF=1 @{0 1913 3}
# aminoacridinium -> term5018 Nt=1 TF=1 maxTF=1 @{0 1919 3}
# aminobenzenethiol -> term4154 Nt=1 TF=1 maxTF=1 @{0 1922 3}
# aminobenzo -> term3947 Nt=1 TF=1 maxTF=1 @{0 1925 3}
# aminophenyl -> term4019 Nt=2 TF=2 maxTF=1 @{0 1928 3}
# aminopyrimidin -> term5128 Nt=1 TF=1 maxTF=1 @{0 1931 5}
# aminothiophenol -> term4207 Nt=1 TF=1 maxTF=1 @{0 1934 5}
# amman -> term4323 Nt=1 TF=1 maxTF=1 @{0 1937 5}
# amount -> term3854 Nt=2 TF=2 maxTF=1 @{0 1940 5}
# amplif -> term2797 Nt=1 TF=1 maxTF=1 @{0 1944 7}
# amplitud -> term3218 Nt=1 TF=1 maxTF=1 @{0 1947 5}
# ampute -> term3037 Nt=2 TF=2 maxTF=1 @{0 1950 3}
# amstetten -> term1571 Nt=1 TF=1 maxTF=1 @{0 1955 3}
# analizi -> term1256 Nt=1 TF=1 maxTF=1 @{0 1957 7}
# analog -> term2190 Nt=2 TF=2 maxTF=1 @{0 1960 1}
# analogu -> term2649 Nt=2 TF=2 maxTF=1 @{0 1964 7}
# analys -> term415 Nt=16 TF=16 maxTF=1 @{0 1969 7}
# analysen -> term1971 Nt=1 TF=1 maxTF=1 @{0 1998 1}
# analysi -> term113 Nt=171 TF=173 maxTF=2 @{0 2000 5}
# analyt -> term357 Nt=13 TF=13 maxTF=1 @{0 2165 3}
# analytisch -> term2050 Nt=2 TF=2 maxTF=1 @{0 2187 1}
# analyz -> term470 Nt=21 TF=21 maxTF=1 @{0 2192 3}
# anatomi -> term2655 Nt=2 TF=2 maxTF=1 @{0 2225 7}
# anaweg -> term2648 Nt=1 TF=1 maxTF=1 @{0 2231 1}
# anaylsi -> term4993 Nt=1 TF=1 maxTF=1 @{0 2233 7}
# anchor -> term4436 Nt=1 TF=1 maxTF=1 @{0 2236 7}
# ancient -> term4179 Nt=3 TF=3 maxTF=1 @{0 2239 7}
# andalu -> term4065 Nt=1 TF=1 maxTF=1 @{0 2246 7}
# ander -> term4787 Nt=1 TF=1 maxTF=1 @{0 2249 7}
# anger -> term678 Nt=1 TF=1 maxTF=1 @{0 2252 7}
# anglophon -> term1048 Nt=1 TF=1 maxTF=1 @{0 2255 1}
# angri -> term2812 Nt=1 TF=1 maxTF=1 @{0 2257 3}
# angst -> term2063 Nt=1 TF=1 maxTF=1 @{0 2260 1}
# angstkommunik -> term2058 Nt=1 TF=1 maxTF=1 @{0 2262 5}
# angustifolia -> term3637 Nt=1 TF=2 maxTF=2 @{0 2265 1}
# anh -> term4753 Nt=1 TF=1 maxTF=1 @{0 2268 2}
# anhand -> term3600 Nt=2 TF=2 maxTF=1 @{0 2271 2}
# anic -> term4289 Nt=1 TF=1 maxTF=1 @{0 2276 4}
# aniliden -> term4046 Nt=1 TF=1 maxTF=1 @{0 2279 4}
# anilin -> term4016 Nt=2 TF=2 maxTF=1 @{0 2282 4}
# anim -> term3993 Nt=1 TF=1 maxTF=1 @{0 2285 6}
# animos -> term1345 Nt=1 TF=1 maxTF=1 @{0 2288 6}
# anni -> term1103 Nt=1 TF=1 maxTF=1 @{0 2291 2}
# annihayah -> term4685 Nt=1 TF=1 maxTF=1 @{0 2293 4}
# annot -> term2274 Nt=6 TF=6 maxTF=1 @{0 2296 4}
# annual -> term2888 Nt=5 TF=5 maxTF=1 @{0 2309 4}
# anomali -> term2748 Nt=3 TF=3 maxTF=1 @{0 2317 4}
# anonym -> term225 Nt=4 TF=4 maxTF=1 @{0 2324 4}
# ansatz -> term2055 Nt=1 TF=1 maxTF=1 @{0 2331 6}
# answer -> term463 Nt=4 TF=4 maxTF=1 @{0 2334 2}
# ant -> term3920 Nt=1 TF=1 maxTF=1 @{0 2343 2}
# antagon -> term973 Nt=1 TF=1 maxTF=1 @{0 2346 2}
# antara -> term4900 Nt=1 TF=1 maxTF=1 @{0 2348 4}
# antenna -> term3023 Nt=1 TF=1 maxTF=1 @{0 2351 4}
# anthranil -> term5094 Nt=1 TF=1 maxTF=1 @{0 2354 2}
# anthropogen -> term2365 Nt=2 TF=2 maxTF=1 @{0 2357 2}
# anthropolog -> term3656 Nt=1 TF=1 maxTF=1 @{0 2361 6}
# anthropomorph -> term3161 Nt=1 TF=1 maxTF=1 @{0 2364 6}
# anti -> term117 Nt=37 TF=37 maxTF=1 @{0 2367 4}
# antibacteri -> term3731 Nt=6 TF=6 maxTF=1 @{0 2405 0}
# anticanc -> term3980 Nt=1 TF=1 maxTF=1 @{0 2415 2}
# anticip -> term3176 Nt=1 TF=1 maxTF=1 @{0 2418 2}
# anticipatori -> term154 Nt=1 TF=1 maxTF=1 @{0 2421 0}
# anticonvuls -> term4575 Nt=1 TF=1 maxTF=1 @{0 2422 4}
# antimicrobi -> term3862 Nt=1 TF=1 maxTF=1 @{0 2425 4}
# antiqu -> term4367 Nt=3 TF=3 maxTF=1 @{0 2428 4}
# antisemit -> term2634 Nt=2 TF=2 maxTF=1 @{0 2434 4}
# antiskid -> term2925 Nt=1 TF=1 maxTF=1 @{0 2439 4}
# antiterroreinheiten -> term2169 Nt=1 TF=1 maxTF=1 @{0 2442 2}
# antiterrorism -> term1271 Nt=2 TF=2 maxTF=1 @{0 2444 6}
# antitumor -> term5148 Nt=1 TF=1 maxTF=1 @{0 2450 0}
# antonio -> term2773 Nt=1 TF=1 maxTF=1 @{0 2453 0}
# antwort -> term2172 Nt=1 TF=1 maxTF=1 @{0 2455 6}
# anwendbarkeit -> term4562 Nt=1 TF=1 maxTF=1 @{0 2458 2}
# anwendung -> term2122 Nt=1 TF=1 maxTF=1 @{0 2461 2}
# anxieti -> term920 Nt=2 TF=2 maxTF=1 @{0 2463 6}
# aocial -> term4884 Nt=1 TF=1 maxTF=1 @{0 2468 4}
# aphor -> term4874 Nt=1 TF=1 maxTF=1 @{0 2471 4}
# apida -> term2081 Nt=1 TF=1 maxTF=1 @{0 2474 4}
# apocalyps -> term981 Nt=2 TF=3 maxTF=2 @{0 2477 0}
# apocryph -> term4328 Nt=1 TF=1 maxTF=1 @{0 2482 3}
# apolog -> term1954 Nt=1 TF=1 maxTF=1 @{0 2485 3}
# apostasi -> term3758 Nt=1 TF=1 maxTF=1 @{0 2487 7}
# app -> term499 Nt=2 TF=2 maxTF=1 @{0 2490 7}
# appl -> term4505 Nt=1 TF=1 maxTF=1 @{0 2494 5}
# appli -> term437 Nt=9 TF=9 maxTF=1 @{0 2497 5}
# applic -> term213 Nt=56 TF=58 maxTF=2 @{0 2513 5}
# approach -> term245 Nt=76 TF=78 maxTF=2 @{0 2588 3}
# approb -> term720 Nt=2 TF=2 maxTF=1 @{0 2679 3}
# approch -> term3024 Nt=1 TF=1 maxTF=1 @{0 2684 1}
# approxim -> term1795 Nt=8 TF=8 maxTF=1 @{0 2686 7}
# april -> term1154 Nt=1 TF=1 maxTF=1 @{0 2701 7}
# aptitud -> term88 Nt=2 TF=2 maxTF=1 @{0 2704 1}
# aqqa -> term4785 Nt=1 TF=1 maxTF=1 @{0 2705 7}
# aqueou -> term3853 Nt=3 TF=3 maxTF=1 @{0 2708 7}
# ar -> term3293 Nt=2 TF=2 maxTF=1 @{0 2715 5}
# arab -> term264 Nt=34 TF=35 maxTF=2 @{0 2720 7}
# arabi -> term3829 Nt=1 TF=1 maxTF=1 @{0 2766 2}
# arabia -> term497 Nt=2 TF=2 maxTF=1 @{0 2769 2}
# arabien -> term4272 Nt=1 TF=1 maxTF=1 @{0 2774 0}
# arabisch -> term4676 Nt=1 TF=1 maxTF=1 @{0 2777 0}
# arabischen -> term3795 Nt=4 TF=4 maxTF=1 @{0 2780 0}
# arafat -> term486 Nt=1 TF=1 maxTF=1 @{0 2788 2}
# arama -> term4581 Nt=1 TF=1 maxTF=1 @{0 2790 2}
# arapskih -> term3696 Nt=1 TF=1 maxTF=1 @{0 2793 2}
# arava -> term4941 Nt=1 TF=1 maxTF=1 @{0 2796 2}
# arbeit -> term1899 Nt=1 TF=1 maxTF=1 @{0 2799 2}
# arbeiten -> term1823 Nt=1 TF=1 maxTF=1 @{0 2801 6}
# arbitrari -> term2929 Nt=1 TF=1 maxTF=1 @{0 2804 2}
# archaeolog -> term4024 Nt=3 TF=3 maxTF=1 @{0 2807 0}
# archeri -> term4701 Nt=1 TF=1 maxTF=1 @{0 2814 0}
# archetyp -> term978 Nt=1 TF=1 maxTF=1 @{0 2817 0}
# architectur -> term276 Nt=16 TF=17 maxTF=2 @{0 2819 2}
# archiv -> term4295 Nt=1 TF=1 maxTF=1 @{0 2843 5}
# arctic -> term2484 Nt=2 TF=2 maxTF=1 @{0 2846 5}
# ard -> term2248 Nt=1 TF=1 maxTF=1 @{0 2851 1}
# area -> term821 Nt=7 TF=7 maxTF=1 @{0 2853 5}
# areal -> term2529 Nt=3 TF=3 maxTF=1 @{0 2867 7}
# aren -> term1928 Nt=2 TF=2 maxTF=1 @{0 2874 5}
# argentina -> term16 Nt=1 TF=1 maxTF=1 @{0 2879 5}
# argu -> term2216 Nt=1 TF=1 maxTF=1 @{0 2880 3}
# argument -> term1376 Nt=2 TF=2 maxTF=1 @{0 2882 7}
# arid -> term3260 Nt=1 TF=2 maxTF=2 @{0 2887 1}
# arima -> term4373 Nt=1 TF=1 maxTF=1 @{0 2890 0}
# aris -> term2645 Nt=2 TF=2 maxTF=1 @{0 2893 0}
# arkivoc -> term3992 Nt=1 TF=1 maxTF=1 @{0 2898 2}
# arm -> term1041 Nt=3 TF=3 maxTF=1 @{0 2901 2}
# armado -> term1562 Nt=1 TF=1 maxTF=1 @{0 2908 2}
# armata -> term1598 Nt=1 TF=1 maxTF=1 @{0 2910 6}
# armut -> term4231 Nt=1 TF=1 maxTF=1 @{0 2913 2}
# aromat -> term5167 Nt=1 TF=1 maxTF=1 @{0 2916 2}
# arrai -> term3240 Nt=1 TF=1 maxTF=1 @{0 2919 2}
# arrhythmia -> term4790 Nt=1 TF=1 maxTF=1 @{0 2922 0}
# arriv -> term3143 Nt=1 TF=1 maxTF=1 @{0 2925 0}
# art -> term868 Nt=13 TF=14 maxTF=2 @{0 2927 6}
# artefact -> term4025 Nt=1 TF=1 maxTF=1 @{0 2950 1}
# articl -> term577 Nt=3 TF=3 maxTF=1 @{0 2953 1}
# artifact -> term4659 Nt=1 TF=1 maxTF=1 @{0 2960 3}
# artifici -> term584 Nt=10 TF=10 maxTF=1 @{0 2963 3}
# artisan -> term181 Nt=1 TF=1 maxTF=1 @{0 2981 7}
# artist -> term3440 Nt=2 TF=2 maxTF=1 @{0 2983 3}
# arundinacea -> term4889 Nt=1 TF=1 maxTF=1 @{0 2988 1}
# aryl -> term3613 Nt=4 TF=6 maxTF=2 @{0 2991 1}
# arylmethylen -> term3887 Nt=1 TF=1 maxTF=1 @{0 2999 5}
# arylmethyliden -> term3965 Nt=1 TF=1 maxTF=1 @{0 3002 5}
# arylpyrrol -> term3632 Nt=1 TF=1 maxTF=1 @{0 3005 5}
# asam -> term1581 Nt=1 TF=1 maxTF=1 @{0 3008 5}
# aserbaidschan -> term4772 Nt=1 TF=1 maxTF=1 @{0 3011 1}
# ash -> term744 Nt=1 TF=1 maxTF=1 @{0 3014 1}
# asia -> term724 Nt=10 TF=10 maxTF=1 @{0 3016 3}
# asian -> term735 Nt=6 TF=6 maxTF=1 @{0 3032 5}
# aspect -> term1016 Nt=5 TF=5 maxTF=1 @{0 3045 7}
# aspekt -> term1171 Nt=4 TF=4 maxTF=1 @{0 3056 1}
# assalam -> term3503 Nt=1 TF=1 maxTF=1 @{0 3065 1}
# assang -> term1054 Nt=1 TF=1 maxTF=1 @{0 3068 1}
# assembl -> term2774 Nt=1 TF=1 maxTF=1 @{0 3070 3}
# assemblag -> term2069 Nt=1 TF=1 maxTF=1 @{0 3073 1}
# assess -> term288 Nt=44 TF=44 maxTF=1 @{0 3075 5}
# asset -> term751 Nt=3 TF=3 maxTF=1 @{0 3136 1}
# assign -> term3389 Nt=1 TF=1 maxTF=1 @{0 3143 1}
# assist -> term2804 Nt=2 TF=2 maxTF=1 @{0 3145 7}
# associ -> term739 Nt=13 TF=13 maxTF=1 @{0 3150 5}
# assum -> term2882 Nt=1 TF=1 maxTF=1 @{0 3175 7}
# assumpt -> term2954 Nt=1 TF=1 maxTF=1 @{0 3178 5}
# astronom -> term3955 Nt=1 TF=1 maxTF=1 @{0 3181 3}
# astronomi -> term3768 Nt=2 TF=2 maxTF=1 @{0 3184 3}
# asymmetr -> term4934 Nt=1 TF=1 maxTF=1 @{0 3189 5}
# asymmetri -> term2149 Nt=2 TF=2 maxTF=1 @{0 3192 5}
# asymptot -> term2277 Nt=8 TF=8 maxTF=1 @{0 3197 5}
# atd -> term2105 Nt=2 TF=2 maxTF=1 @{0 3210 7}
# athetoid -> term3249 Nt=1 TF=1 maxTF=1 @{0 3214 3}
# athetosi -> term2651 Nt=1 TF=1 maxTF=1 @{0 3217 1}
# atlant -> term2380 Nt=10 TF=10 maxTF=1 @{0 3219 7}
# atmosfear -> term2985 Nt=1 TF=1 maxTF=1 @{0 3236 1}
# atmospher -> term2650 Nt=9 TF=10 maxTF=2 @{0 3238 7}
# atom -> term3522 Nt=5 TF=5 maxTF=1 @{0 3252 0}
# attack -> term177 Nt=94 TF=94 maxTF=1 @{0 3261 0}
# attain -> term3052 Nt=1 TF=1 maxTF=1 @{0 3336 2}
# attempt -> term1317 Nt=2 TF=2 maxTF=1 @{0 3339 0}
# attent -> term659 Nt=4 TF=4 maxTF=1 @{0 3344 0}
# attenu -> term3206 Nt=1 TF=1 maxTF=1 @{0 3352 4}
# attest -> term4661 Nt=1 TF=1 maxTF=1 @{0 3355 2}
# attitud -> term883 Nt=3 TF=3 maxTF=1 @{0 3358 2}
# attract -> term1806 Nt=1 TF=1 maxTF=1 @{0 3365 6}
# attribut -> term2747 Nt=8 TF=8 maxTF=1 @{0 3368 2}
# atum -> term3743 Nt=1 TF=1 maxTF=1 @{0 3381 6}
# au -> term1272 Nt=9 TF=9 maxTF=1 @{0 3384 6}
# audienc -> term2091 Nt=2 TF=2 maxTF=1 @{0 3402 6}
# audio -> term1380 Nt=1 TF=1 maxTF=1 @{0 3408 0}
# audiovisu -> term1740 Nt=1 TF=1 maxTF=1 @{0 3410 4}
# audit -> term3665 Nt=1 TF=1 maxTF=1 @{0 3413 0}
# auf -> term1128 Nt=11 TF=11 maxTF=1 @{0 3416 0}
# aufbau -> term4781 Nt=1 TF=1 maxTF=1 @{0 3436 4}
# aufgezeigt -> term4795 Nt=1 TF=1 maxTF=1 @{0 3439 4}
# aufgrund -> term1390 Nt=1 TF=1 maxTF=1 @{0 3442 4}
# aufstieg -> term4552 Nt=1 TF=1 maxTF=1 @{0 3445 0}
# augment -> term2721 Nt=3 TF=3 maxTF=1 @{0 3448 0}
# aurat -> term5066 Nt=1 TF=1 maxTF=1 @{0 3455 0}
# ausgew -> term3486 Nt=1 TF=1 maxTF=1 @{0 3458 0}
# ausla -> term3320 Nt=1 TF=1 maxTF=1 @{0 3461 0}
# ausland -> term1623 Nt=1 TF=1 maxTF=1 @{0 3463 6}
# auslandsein -> term1940 Nt=1 TF=1 maxTF=1 @{0 3466 2}
# auslegung -> term1619 Nt=1 TF=1 maxTF=1 @{0 3468 6}
# ausnahmezustand -> term1960 Nt=1 TF=1 maxTF=1 @{0 3471 2}
# australia -> term2225 Nt=4 TF=4 maxTF=1 @{0 3473 6}
# austrian -> term4827 Nt=1 TF=1 maxTF=1 @{0 3481 0}
# auswahl -> term4596 Nt=1 TF=1 maxTF=1 @{0 3484 0}
# auswirkungen -> term1650 Nt=5 TF=5 maxTF=1 @{0 3487 0}
# author -> term101 Nt=4 TF=4 maxTF=1 @{0 3497 4}
# authorit -> term4013 Nt=1 TF=1 maxTF=1 @{0 3505 6}
# authoritarian -> term1802 Nt=1 TF=1 maxTF=1 @{0 3508 6}
# auto -> term3196 Nt=2 TF=2 maxTF=1 @{0 3511 2}
# autocrat -> term4001 Nt=1 TF=1 maxTF=1 @{0 3516 4}
# autom -> term184 Nt=5 TF=5 maxTF=1 @{0 3519 4}
# automat -> term810 Nt=13 TF=13 maxTF=1 @{0 3530 2}
# autonom -> term209 Nt=3 TF=3 maxTF=1 @{0 3552 6}
# autonomia -> term1205 Nt=1 TF=1 maxTF=1 @{0 3559 4}
# autopilot -> term3296 Nt=1 TF=1 maxTF=1 @{0 3561 6}
# autoregress -> term3185 Nt=1 TF=1 maxTF=1 @{0 3564 4}
# av -> term4264 Nt=1 TF=1 maxTF=1 @{0 3567 2}
# avail -> term2467 Nt=1 TF=1 maxTF=1 @{0 3570 2}
# averag -> term3068 Nt=3 TF=3 maxTF=1 @{0 3573 0}
# avers -> term1298 Nt=2 TF=2 maxTF=1 @{0 3579 6}
# avert -> term781 Nt=1 TF=1 maxTF=1 @{0 3583 6}
# aviat -> term2048 Nt=2 TF=2 maxTF=1 @{0 3586 0}
# avicenna -> term4036 Nt=2 TF=2 maxTF=1 @{0 3589 6}
# avocad -> term1520 Nt=1 TF=1 maxTF=1 @{0 3595 0}
# avoid -> term2378 Nt=2 TF=2 maxTF=1 @{0 3597 4}
# awar -> term1768 Nt=8 TF=8 maxTF=1 @{0 3602 4}
# award -> term4845 Nt=1 TF=1 maxTF=1 @{0 3616 4}
# axiolog -> term3902 Nt=1 TF=1 maxTF=1 @{0 3619 4}
# ayn -> term4952 Nt=1 TF=1 maxTF=1 @{0 3622 4}
# azad -> term3426 Nt=4 TF=4 maxTF=1 @{0 3625 4}
# azetanylisoindol -> term4056 Nt=1 TF=1 maxTF=1 @{0 3631 4}
# azetidinon -> term3588 Nt=5 TF=5 maxTF=1 @{0 3634 4}
# azhar -> term4577 Nt=1 TF=1 maxTF=1 @{0 3642 2}
# azo -> term3863 Nt=1 TF=1 maxTF=1 @{0 3645 2}
# ba -> term3717 Nt=2 TF=2 maxTF=1 @{0 3648 2}
# babangida -> term4706 Nt=1 TF=1 maxTF=1 @{0 3653 4}
# babur -> term4200 Nt=1 TF=1 maxTF=1 @{0 3656 4}
# baburnama -> term4202 Nt=1 TF=1 maxTF=1 @{0 3659 4}
# background -> term838 Nt=4 TF=4 maxTF=1 @{0 3662 4}
# backlash -> term61 Nt=5 TF=5 maxTF=1 @{0 3669 2}
# baclofen -> term2609 Nt=1 TF=1 maxTF=1 @{0 3677 2}
# bacterium -> term909 Nt=1 TF=1 maxTF=1 @{0 3680 0}
# baghdad -> term5070 Nt=1 TF=1 maxTF=1 @{0 3682 2}
# bakhtiar -> term4974 Nt=1 TF=1 maxTF=1 @{0 3685 2}
# balanc -> term589 Nt=4 TF=4 maxTF=1 @{0 3688 2}
# bali -> term2184 Nt=1 TF=1 maxTF=1 @{0 3695 0}
# balkan -> term1386 Nt=2 TF=2 maxTF=1 @{0 3697 4}
# banda -> term1559 Nt=1 TF=1 maxTF=1 @{0 3702 2}
# bangladesh -> term175 Nt=8 TF=8 maxTF=1 @{0 3704 6}
# bangladeshi -> term183 Nt=1 TF=1 maxTF=1 @{0 3719 4}
# bank -> term1844 Nt=43 TF=52 maxTF=3 @{0 3721 0}
# bankbetriebslehr -> term4120 Nt=1 TF=1 maxTF=1 @{0 3765 5}
# banksi -> term1319 Nt=1 TF=1 maxTF=1 @{0 3768 5}
# bantul -> term3374 Nt=2 TF=2 maxTF=1 @{0 3771 1}
# bar -> term1066 Nt=1 TF=1 maxTF=1 @{0 3775 1}
# base -> term103 Nt=151 TF=155 maxTF=2 @{0 3777 3}
# baselin -> term2353 Nt=1 TF=1 maxTF=1 @{0 3926 3}
# bashkir -> term4239 Nt=1 TF=1 maxTF=1 @{0 3929 1}
# basi -> term1116 Nt=2 TF=2 maxTF=1 @{0 3932 1}
# basin -> term2361 Nt=9 TF=9 maxTF=1 @{0 3937 1}
# basqu -> term711 Nt=1 TF=1 maxTF=1 @{0 3950 3}
# batch -> term3223 Nt=1 TF=1 maxTF=1 @{0 3952 5}
# batteri -> term2806 Nt=1 TF=1 maxTF=1 @{0 3955 3}
# battl -> term2414 Nt=1 TF=1 maxTF=1 @{0 3958 1}
# bavaria -> term2646 Nt=1 TF=1 maxTF=1 @{0 3960 7}
# bay -> term1720 Nt=1 TF=1 maxTF=1 @{0 3963 5}
# bayesian -> term187 Nt=16 TF=16 maxTF=1 @{0 3966 1}
# bazaar -> term5014 Nt=1 TF=1 maxTF=1 @{0 3990 1}
# bcke -> term1021 Nt=1 TF=1 maxTF=1 @{0 3993 1}
# bdea -> term4530 Nt=1 TF=1 maxTF=1 @{0 3995 3}
# be -> term3464 Nt=4 TF=4 maxTF=1 @{0 3998 3}
# beacon -> term4189 Nt=1 TF=1 maxTF=1 @{0 4005 5}
# beam -> term3209 Nt=2 TF=2 maxTF=1 @{0 4008 5}
# bear -> term2626 Nt=2 TF=2 maxTF=1 @{0 4013 1}
# beard -> term2117 Nt=1 TF=1 maxTF=1 @{0 4018 1}
# beati -> term1610 Nt=1 TF=1 maxTF=1 @{0 4020 5}
# beaufort -> term2821 Nt=1 TF=1 maxTF=1 @{0 4023 1}
# bedingen -> term1398 Nt=1 TF=1 maxTF=1 @{0 4025 7}
# bedrohung -> term2173 Nt=1 TF=1 maxTF=1 @{0 4028 3}
# bedrohungsszenarien -> term2018 Nt=1 TF=1 maxTF=1 @{0 4030 7}
# bee -> term2080 Nt=1 TF=1 maxTF=1 @{0 4033 3}
# begeistert -> term2724 Nt=1 TF=1 maxTF=1 @{0 4035 7}
# begin -> term4653 Nt=1 TF=1 maxTF=1 @{0 4038 5}
# begov -> term3703 Nt=1 TF=1 maxTF=1 @{0 4041 5}
# begriff -> term1826 Nt=2 TF=2 maxTF=1 @{0 4044 5}
# behandlung -> term3478 Nt=1 TF=1 maxTF=1 @{0 4049 7}
# behavior -> term483 Nt=26 TF=26 maxTF=1 @{0 4052 7}
# behaviour -> term946 Nt=7 TF=7 maxTF=1 @{0 4092 7}
# bei -> term1974 Nt=7 TF=7 maxTF=1 @{0 4106 7}
# beiden -> term4920 Nt=2 TF=2 maxTF=1 @{0 4119 5}
# beim -> term2013 Nt=1 TF=1 maxTF=1 @{0 4123 1}
# beispiel -> term2038 Nt=8 TF=8 maxTF=1 @{0 4125 5}
# beispielen -> term4595 Nt=1 TF=1 maxTF=1 @{0 4140 5}
# beitr -> term4496 Nt=3 TF=3 maxTF=1 @{0 4143 5}
# beitrag -> term2109 Nt=2 TF=2 maxTF=1 @{0 4149 1}
# beitrittsprozess -> term4551 Nt=1 TF=1 maxTF=1 @{0 4154 3}
# bek -> term1822 Nt=7 TF=7 maxTF=1 @{0 4157 3}
# beka -> term1586 Nt=2 TF=2 maxTF=1 @{0 4165 7}
# belgium -> term3092 Nt=1 TF=1 maxTF=1 @{0 4170 3}
# belief -> term2094 Nt=3 TF=3 maxTF=1 @{0 4173 1}
# belov -> term3722 Nt=1 TF=1 maxTF=1 @{0 4180 5}
# ben -> term4869 Nt=1 TF=1 maxTF=1 @{0 4183 5}
# benchmark -> term1300 Nt=3 TF=3 maxTF=1 @{0 4186 5}
# benefici -> term3945 Nt=1 TF=1 maxTF=1 @{0 4194 1}
# benefit -> term3060 Nt=1 TF=1 maxTF=1 @{0 4197 1}
# bengal -> term4520 Nt=1 TF=1 maxTF=1 @{0 4199 7}
# benign -> term1437 Nt=1 TF=1 maxTF=1 @{0 4202 7}
# bentonit -> term4502 Nt=1 TF=2 maxTF=2 @{0 4205 3}
# benzen -> term3968 Nt=5 TF=5 maxTF=1 @{0 4208 4}
# benzimidazol -> term4165 Nt=1 TF=1 maxTF=1 @{0 4217 6}
# benzo -> term3606 Nt=1 TF=1 maxTF=1 @{0 4220 6}
# benzodiazepin -> term3873 Nt=1 TF=1 maxTF=1 @{0 4223 6}
# benzothiazin -> term4018 Nt=4 TF=4 maxTF=1 @{0 4226 6}
# benzothiazol -> term4161 Nt=1 TF=1 maxTF=1 @{0 4232 0}
# benzotriazolylketen -> term3884 Nt=1 TF=1 maxTF=1 @{0 4235 0}
# benzoyl -> term3586 Nt=1 TF=1 maxTF=1 @{0 4238 0}
# benzyl -> term5149 Nt=1 TF=1 maxTF=1 @{0 4241 0}
# beogradu -> term3716 Nt=1 TF=1 maxTF=1 @{0 4244 0}
# ber -> term794 Nt=16 TF=16 maxTF=1 @{0 4247 0}
# bereinkommen -> term1824 Nt=3 TF=3 maxTF=1 @{0 4271 6}
# berenic -> term4433 Nt=1 TF=1 maxTF=1 @{0 4276 2}
# bergang -> term4211 Nt=2 TF=2 maxTF=1 @{0 4279 2}
# bergewicht -> term3105 Nt=1 TF=1 maxTF=1 @{0 4283 2}
# berichterstattung -> term4730 Nt=2 TF=2 maxTF=1 @{0 4286 0}
# berkelei -> term2799 Nt=5 TF=5 maxTF=1 @{0 4290 6}
# berlin -> term1533 Nt=3 TF=3 maxTF=1 @{0 4299 6}
# bersetzung -> term4443 Nt=1 TF=1 maxTF=1 @{0 4306 6}
# bert -> term2635 Nt=2 TF=2 maxTF=1 @{0 4309 6}
# beru -> term2179 Nt=2 TF=2 maxTF=1 @{0 4314 6}
# besatzungsverwaltung -> term2240 Nt=1 TF=1 maxTF=1 @{0 4320 0}
# beschleunigten -> term4909 Nt=1 TF=1 maxTF=1 @{0 4322 4}
# besonder -> term1828 Nt=3 TF=3 maxTF=1 @{0 4325 4}
# best -> term869 Nt=3 TF=3 maxTF=1 @{0 4332 6}
# bestandsaufnahm -> term1891 Nt=2 TF=2 maxTF=1 @{0 4339 6}
# beta -> term3628 Nt=15 TF=17 maxTF=2 @{0 4344 2}
# betrachtung -> term1957 Nt=1 TF=1 maxTF=1 @{0 4363 2}
# betwe -> term2035 Nt=1 TF=1 maxTF=1 @{0 4365 6}
# beurteilung -> term4568 Nt=1 TF=1 maxTF=1 @{0 4368 2}
# bewa -> term1848 Nt=1 TF=1 maxTF=1 @{0 4371 2}
# bewegung -> term2132 Nt=1 TF=1 maxTF=1 @{0 4373 6}
# bez -> term2049 Nt=1 TF=1 maxTF=1 @{0 4376 2}
# beziehungen -> term2089 Nt=3 TF=3 maxTF=1 @{0 4378 6}
# bi -> term1955 Nt=25 TF=26 maxTF=2 @{0 4386 2}
# bia -> term2548 Nt=3 TF=3 maxTF=1 @{0 4415 1}
# bias -> term2230 Nt=3 TF=3 maxTF=1 @{0 4422 1}
# bibl -> term3430 Nt=2 TF=2 maxTF=1 @{0 4428 7}
# bibliotek -> term3697 Nt=1 TF=1 maxTF=1 @{0 4434 3}
# bicm -> term3529 Nt=1 TF=1 maxTF=1 @{0 4437 3}
# biden -> term1056 Nt=1 TF=1 maxTF=1 @{0 4440 3}
# bidirect -> term473 Nt=1 TF=1 maxTF=1 @{0 4442 5}
# big -> term532 Nt=5 TF=5 maxTF=1 @{0 4444 5}
# bigram -> term2386 Nt=1 TF=1 maxTF=1 @{0 4454 3}
# bigru -> term658 Nt=1 TF=1 maxTF=1 @{0 4457 1}
# bih -> term1523 Nt=1 TF=1 maxTF=1 @{0 4459 3}
# bild -> term2142 Nt=1 TF=1 maxTF=1 @{0 4461 7}
# bilder -> term2127 Nt=4 TF=6 maxTF=2 @{0 4464 3}
# bildung -> term4548 Nt=1 TF=1 maxTF=1 @{0 4471 5}
# bilinear -> term1368 Nt=2 TF=2 maxTF=1 @{0 4474 5}
# bilingu -> term4844 Nt=1 TF=1 maxTF=1 @{0 4479 5}
# bin -> term1329 Nt=5 TF=6 maxTF=2 @{0 4482 5}
# binari -> term1501 Nt=1 TF=1 maxTF=1 @{0 4492 4}
# bind -> term3166 Nt=2 TF=2 maxTF=1 @{0 4495 0}
# binuclear -> term5126 Nt=1 TF=1 maxTF=1 @{0 4500 2}
# bio -> term620 Nt=3 TF=3 maxTF=1 @{0 4503 2}
# bioadsorb -> term3626 Nt=1 TF=1 maxTF=1 @{0 4509 6}
# biochem -> term1449 Nt=1 TF=1 maxTF=1 @{0 4512 6}
# biographi -> term4632 Nt=1 TF=1 maxTF=1 @{0 4515 2}
# biolog -> term313 Nt=5 TF=5 maxTF=1 @{0 4518 2}
# biomechan -> term2859 Nt=1 TF=1 maxTF=1 @{0 4528 2}
# biomed -> term621 Nt=1 TF=1 maxTF=1 @{0 4531 0}
# biometr -> term331 Nt=4 TF=4 maxTF=1 @{0 4533 0}
# bioreactor -> term3221 Nt=1 TF=1 maxTF=1 @{0 4541 6}
# biosensor -> term1251 Nt=1 TF=1 maxTF=1 @{0 4544 4}
# biota -> term1876 Nt=1 TF=1 maxTF=1 @{0 4546 6}
# bioterror -> term1110 Nt=1 TF=1 maxTF=1 @{0 4549 2}
# bipartit -> term1747 Nt=1 TF=1 maxTF=1 @{0 4551 4}
# bipyri -> term5109 Nt=1 TF=1 maxTF=1 @{0 4554 0}
# bipyridin -> term5006 Nt=12 TF=12 maxTF=1 @{0 4557 0}
# birth -> term897 Nt=1 TF=1 maxTF=1 @{0 4566 6}
# bisaquabi -> term5131 Nt=1 TF=1 maxTF=1 @{0 4569 0}
# bisbi -> term5103 Nt=1 TF=1 maxTF=1 @{0 4572 0}
# bisbromido -> term5039 Nt=1 TF=1 maxTF=1 @{0 4575 0}
# bit -> term1833 Nt=1 TF=1 maxTF=1 @{0 4578 0}
# bitcoin -> term2298 Nt=1 TF=1 maxTF=1 @{0 4580 4}
# bithiazol -> term5140 Nt=4 TF=4 maxTF=1 @{0 4583 2}
# bivari -> term2394 Nt=8 TF=8 maxTF=1 @{0 4588 0}
# black -> term2741 Nt=1 TF=1 maxTF=1 @{0 4602 6}
# blackboard -> term277 Nt=1 TF=1 maxTF=1 @{0 4605 4}
# blame -> term990 Nt=1 TF=1 maxTF=1 @{0 4607 2}
# blast -> term602 Nt=1 TF=1 maxTF=1 @{0 4609 4}
# bleed -> term4692 Nt=1 TF=1 maxTF=1 @{0 4611 4}
# bleex -> term3151 Nt=3 TF=3 maxTF=1 @{0 4614 4}
# blend -> term4744 Nt=1 TF=1 maxTF=1 @{0 4619 6}
# block -> term2696 Nt=1 TF=1 maxTF=1 @{0 4622 6}
# blockchain -> term3663 Nt=5 TF=5 maxTF=1 @{0 4625 4}
# blogger -> term3247 Nt=1 TF=1 maxTF=1 @{0 4634 6}
# blood -> term3305 Nt=2 TF=2 maxTF=1 @{0 4637 4}
# blow -> term2497 Nt=2 TF=2 maxTF=1 @{0 4642 6}
# blue -> term2689 Nt=3 TF=3 maxTF=1 @{0 4648 2}
# blueprint -> term2026 Nt=1 TF=1 maxTF=1 @{0 4655 2}
# bluetooth -> term185 Nt=1 TF=1 maxTF=1 @{0 4657 6}
# board -> term627 Nt=14 TF=14 maxTF=1 @{0 4659 2}
# bodi -> term3936 Nt=1 TF=1 maxTF=1 @{0 4681 0}
# bohemia -> term3148 Nt=1 TF=1 maxTF=1 @{0 4684 0}
# boko -> term511 Nt=2 TF=2 maxTF=1 @{0 4686 6}
# bomb -> term834 Nt=6 TF=6 maxTF=1 @{0 4690 6}
# bond -> term4682 Nt=1 TF=1 maxTF=1 @{0 4701 4}
# bongo -> term4624 Nt=1 TF=1 maxTF=1 @{0 4704 4}
# book -> term980 Nt=5 TF=6 maxTF=2 @{0 4707 4}
# bootstrap -> term2699 Nt=3 TF=3 maxTF=1 @{0 4719 3}
# border -> term2288 Nt=1 TF=1 maxTF=1 @{0 4727 1}
# borderland -> term4417 Nt=1 TF=1 maxTF=1 @{0 4729 7}
# boston -> term832 Nt=1 TF=1 maxTF=1 @{0 4732 7}
# bot -> term2802 Nt=2 TF=2 maxTF=1 @{0 4735 1}
# botan -> term3802 Nt=1 TF=1 maxTF=1 @{0 4740 1}
# botox -> term1627 Nt=1 TF=1 maxTF=1 @{0 4743 1}
# botulinum -> term2430 Nt=13 TF=13 maxTF=1 @{0 4745 5}
# bought -> term4767 Nt=1 TF=1 maxTF=1 @{0 4760 5}
# bound -> term168 Nt=11 TF=11 maxTF=1 @{0 4763 5}
# boundari -> term3227 Nt=1 TF=1 maxTF=1 @{0 4780 1}
# bp -> term775 Nt=1 TF=1 maxTF=1 @{0 4782 7}
# br -> term4479 Nt=1 TF=1 maxTF=1 @{0 4785 1}
# brace -> term2631 Nt=4 TF=4 maxTF=1 @{0 4788 1}
# bracket -> term2858 Nt=1 TF=1 maxTF=1 @{0 4796 1}
# brain -> term2642 Nt=2 TF=2 maxTF=1 @{0 4798 7}
# branch -> term4116 Nt=2 TF=2 maxTF=1 @{0 4804 1}
# brazil -> term2283 Nt=1 TF=1 maxTF=1 @{0 4809 1}
# break -> term1126 Nt=5 TF=5 maxTF=1 @{0 4811 7}
# breast -> term3981 Nt=1 TF=1 maxTF=1 @{0 4822 3}
# bridg -> term3467 Nt=2 TF=2 maxTF=1 @{0 4825 3}
# brief -> term538 Nt=2 TF=2 maxTF=1 @{0 4830 1}
# briefwechsel -> term3596 Nt=1 TF=1 maxTF=1 @{0 4833 1}
# brigad -> term1134 Nt=1 TF=1 maxTF=1 @{0 4836 1}
# bring -> term1707 Nt=1 TF=1 maxTF=1 @{0 4838 3}
# brisban -> term3069 Nt=1 TF=1 maxTF=1 @{0 4840 7}
# britain -> term2617 Nt=3 TF=3 maxTF=1 @{0 4843 5}
# britannien -> term1218 Nt=2 TF=2 maxTF=1 @{0 4850 3}
# britischen -> term561 Nt=1 TF=1 maxTF=1 @{0 4854 5}
# british -> term3094 Nt=2 TF=2 maxTF=1 @{0 4856 5}
# bromid -> term5160 Nt=1 TF=1 maxTF=1 @{0 4861 7}
# bromido -> term5040 Nt=1 TF=1 maxTF=1 @{0 4864 7}
# brook -> term3179 Nt=1 TF=1 maxTF=1 @{0 4867 7}
# brotherhood -> term4111 Nt=1 TF=1 maxTF=1 @{0 4870 5}
# brown -> term1929 Nt=3 TF=3 maxTF=1 @{0 4873 5}
# brows -> term2106 Nt=2 TF=2 maxTF=1 @{0 4880 5}
# brunei -> term4771 Nt=1 TF=1 maxTF=1 @{0 4884 1}
# buddhismu -> term4791 Nt=1 TF=1 maxTF=1 @{0 4887 1}
# buerger -> term2516 Nt=1 TF=1 maxTF=1 @{0 4890 1}
# buffer -> term3531 Nt=1 TF=1 maxTF=1 @{0 4892 7}
# bui -> term1050 Nt=1 TF=1 maxTF=1 @{0 4895 7}
# build -> term203 Nt=21 TF=21 maxTF=1 @{0 4898 1}
# bukhara -> term3456 Nt=1 TF=1 maxTF=1 @{0 4926 3}
# bulghar -> term4238 Nt=1 TF=1 maxTF=1 @{0 4929 3}
# bulk -> term86 Nt=1 TF=1 maxTF=1 @{0 4932 3}
# bundeskriminalamt -> term1976 Nt=1 TF=1 maxTF=1 @{0 4933 5}
# bundesrepublik -> term1175 Nt=5 TF=5 maxTF=1 @{0 4936 1}
# bundeswehr -> term1943 Nt=1 TF=1 maxTF=1 @{0 4946 1}
# bundeszentral -> term4546 Nt=1 TF=1 maxTF=1 @{0 4948 5}
# burbag -> term3180 Nt=1 TF=1 maxTF=1 @{0 4951 5}
# burden -> term5158 Nt=2 TF=2 maxTF=1 @{0 4954 3}
# bureau -> term861 Nt=1 TF=1 maxTF=1 @{0 4958 3}
# burkina -> term859 Nt=1 TF=1 maxTF=1 @{0 4960 5}
# burn -> term3012 Nt=2 TF=2 maxTF=1 @{0 4962 7}
# bush -> term1715 Nt=2 TF=2 maxTF=1 @{0 4968 1}
# busi -> term2 Nt=18 TF=18 maxTF=1 @{0 4973 3}
# businesscast -> term2221 Nt=1 TF=1 maxTF=1 @{0 4995 3}
# buskaschi -> term4894 Nt=1 TF=1 maxTF=1 @{0 4997 7}
# busworld -> term2192 Nt=1 TF=1 maxTF=1 @{0 5000 7}
# butanedio -> term4053 Nt=1 TF=1 maxTF=1 @{0 5003 3}
# butsalen -> term4931 Nt=1 TF=1 maxTF=1 @{0 5006 3}
# butyl -> term5062 Nt=1 TF=1 maxTF=1 @{0 5009 3}
# buxori -> term3821 Nt=1 TF=1 maxTF=1 @{0 5012 3}
# bw -> term3302 Nt=1 TF=1 maxTF=1 @{0 5015 3}
# byzantin -> term4149 Nt=5 TF=5 maxTF=1 @{0 5018 1}
# byzantina -> term4273 Nt=1 TF=1 maxTF=1 @{0 5027 5}
# bzw -> term4966 Nt=1 TF=1 maxTF=1 @{0 5030 5}
# c21 -> term2667 Nt=1 TF=1 maxTF=1 @{0 5033 5}
# ca -> term3976 Nt=1 TF=1 maxTF=1 @{0 5036 3}
# cabl -> term3322 Nt=1 TF=1 maxTF=1 @{0 5039 3}
# cadmium -> term4724 Nt=5 TF=5 maxTF=1 @{0 5042 1}
# caffein -> term5113 Nt=1 TF=1 maxTF=1 @{0 5050 3}
# calcul -> term361 Nt=2 TF=2 maxTF=1 @{0 5053 3}
# caldicott -> term1225 Nt=1 TF=1 maxTF=1 @{0 5057 7}
# california -> term2540 Nt=1 TF=1 maxTF=1 @{0 5060 1}
# caliph -> term4873 Nt=1 TF=1 maxTF=1 @{0 5062 7}
# call -> term782 Nt=3 TF=3 maxTF=1 @{0 5065 7}
# caller -> term1717 Nt=1 TF=1 maxTF=1 @{0 5073 3}
# calvinismu -> term4233 Nt=1 TF=1 maxTF=1 @{0 5075 7}
# cambridg -> term4409 Nt=1 TF=1 maxTF=1 @{0 5078 7}
# cameron -> term4971 Nt=1 TF=1 maxTF=1 @{0 5081 7}
# cameroon -> term8 Nt=2 TF=2 maxTF=1 @{0 5084 7}
# camouflag -> term1578 Nt=1 TF=1 maxTF=1 @{0 5087 5}
# camp -> term2996 Nt=1 TF=1 maxTF=1 @{0 5090 1}
# campaign -> term779 Nt=3 TF=3 maxTF=1 @{0 5092 7}
# can -> term654 Nt=7 TF=7 maxTF=1 @{0 5099 3}
# canada -> term2289 Nt=1 TF=1 maxTF=1 @{0 5114 1}
# canadian -> term2265 Nt=1 TF=1 maxTF=1 @{0 5116 7}
# cancer -> term3492 Nt=3 TF=3 maxTF=1 @{0 5119 3}
# candid -> term622 Nt=2 TF=2 maxTF=1 @{0 5125 5}
# canon -> term4039 Nt=2 TF=2 maxTF=1 @{0 5130 3}
# capabl -> term598 Nt=4 TF=4 maxTF=1 @{0 5135 5}
# capac -> term1344 Nt=2 TF=2 maxTF=1 @{0 5145 1}
# capacit -> term3239 Nt=1 TF=1 maxTF=1 @{0 5150 3}
# capit -> term1508 Nt=7 TF=7 maxTF=1 @{0 5153 1}
# capitalist -> term4150 Nt=1 TF=1 maxTF=1 @{0 5167 3}
# capitol -> term2320 Nt=1 TF=1 maxTF=1 @{0 5170 3}
# captur -> term3002 Nt=2 TF=2 maxTF=1 @{0 5173 1}
# car -> term4375 Nt=1 TF=2 maxTF=2 @{0 5178 3}
# carbamoylpyridinium -> term5144 Nt=1 TF=1 maxTF=1 @{0 5181 4}
# carbon -> term2950 Nt=7 TF=7 maxTF=1 @{0 5184 4}
# carboxamidequinolin -> term4135 Nt=1 TF=1 maxTF=1 @{0 5195 4}
# card -> term420 Nt=1 TF=1 maxTF=1 @{0 5198 4}
# cardiac -> term4877 Nt=1 TF=1 maxTF=1 @{0 5200 4}
# cardiovascular -> term3516 Nt=1 TF=1 maxTF=1 @{0 5203 4}
# care -> term2619 Nt=3 TF=3 maxTF=1 @{0 5206 4}
# career -> term4242 Nt=1 TF=2 maxTF=2 @{0 5214 0}
# caribbean -> term3146 Nt=1 TF=1 maxTF=1 @{0 5217 1}
# carolina -> term1029 Nt=1 TF=1 maxTF=1 @{0 5219 7}
# carrier -> term4759 Nt=1 TF=1 maxTF=1 @{0 5222 1}
# carter -> term1090 Nt=2 TF=2 maxTF=1 @{0 5225 1}
# cas9 -> term4344 Nt=1 TF=1 maxTF=1 @{0 5230 3}
# cascad -> term310 Nt=1 TF=1 maxTF=1 @{0 5233 3}
# case -> term67 Nt=69 TF=69 maxTF=1 @{0 5235 1}
# cashless -> term1157 Nt=4 TF=4 maxTF=1 @{0 5317 5}
# cast -> term2564 Nt=3 TF=3 maxTF=1 @{0 5325 3}
# casualti -> term585 Nt=4 TF=4 maxTF=1 @{0 5329 7}
# catalogu -> term3079 Nt=4 TF=4 maxTF=1 @{0 5337 3}
# catalonia -> term2597 Nt=1 TF=1 maxTF=1 @{0 5346 1}
# catalyst -> term3607 Nt=9 TF=9 maxTF=1 @{0 5348 7}
# catalyt -> term3850 Nt=7 TF=7 maxTF=1 @{0 5360 5}
# catalyz -> term5120 Nt=1 TF=1 maxTF=1 @{0 5371 7}
# catastroph -> term1081 Nt=2 TF=2 maxTF=1 @{0 5374 7}
# catchment -> term2435 Nt=4 TF=4 maxTF=1 @{0 5379 7}
# categor -> term493 Nt=4 TF=4 maxTF=1 @{0 5388 3}
# catena -> term5032 Nt=1 TF=1 maxTF=1 @{0 5397 5}
# cauchi -> term2314 Nt=1 TF=1 maxTF=1 @{0 5400 5}
# caus -> term492 Nt=6 TF=6 maxTF=1 @{0 5403 3}
# causado -> term1561 Nt=1 TF=1 maxTF=1 @{0 5414 1}
# causal -> term1506 Nt=4 TF=4 maxTF=1 @{0 5416 5}
# cautionari -> term2698 Nt=2 TF=2 maxTF=1 @{0 5426 1}
# caviti -> term2978 Nt=2 TF=2 maxTF=1 @{0 5431 1}
# cbrn -> term341 Nt=4 TF=4 maxTF=1 @{0 5436 1}
# cc -> term3877 Nt=2 TF=2 maxTF=1 @{0 5443 3}
# cd3oso4 -> term5142 Nt=1 TF=1 maxTF=1 @{0 5447 7}
# cdc -> term1246 Nt=1 TF=1 maxTF=1 @{0 5450 7}
# cddi -> term4930 Nt=1 TF=1 maxTF=1 @{0 5453 1}
# cdma -> term3668 Nt=1 TF=1 maxTF=1 @{0 5456 1}
# ce -> term3473 Nt=3 TF=3 maxTF=1 @{0 5459 1}
# celesti -> term3938 Nt=1 TF=1 maxTF=1 @{0 5465 3}
# cell -> term1039 Nt=9 TF=9 maxTF=1 @{0 5468 3}
# cellular -> term1722 Nt=2 TF=2 maxTF=1 @{0 5481 3}
# cemac -> term1217 Nt=1 TF=1 maxTF=1 @{0 5484 5}
# censor -> term3280 Nt=1 TF=1 maxTF=1 @{0 5486 7}
# censorship -> term4421 Nt=1 TF=1 maxTF=1 @{0 5489 5}
# center -> term2829 Nt=2 TF=2 maxTF=1 @{0 5492 5}
# centr -> term891 Nt=1 TF=1 maxTF=1 @{0 5498 1}
# central -> term501 Nt=19 TF=19 maxTF=1 @{0 5500 3}
# centric -> term575 Nt=2 TF=2 maxTF=1 @{0 5533 5}
# centuri -> term522 Nt=17 TF=20 maxTF=2 @{0 5535 7}
# ceram -> term4525 Nt=1 TF=1 maxTF=1 @{0 5565 6}
# cereal -> term2663 Nt=1 TF=1 maxTF=1 @{0 5568 6}
# cerebr -> term2454 Nt=66 TF=66 maxTF=1 @{0 5571 4}
# certainti -> term3830 Nt=1 TF=1 maxTF=1 @{0 5623 4}
# cessat -> term3518 Nt=1 TF=1 maxTF=1 @{0 5626 4}
# chain -> term984 Nt=8 TF=8 maxTF=1 @{0 5629 4}
# challeng -> term315 Nt=25 TF=25 maxTF=1 @{0 5645 2}
# chamber -> term2368 Nt=1 TF=1 maxTF=1 @{0 5685 2}
# chang -> term211 Nt=92 TF=96 maxTF=3 @{0 5688 0}
# channel -> term4880 Nt=2 TF=2 maxTF=1 @{0 5779 6}
# chao -> term2309 Nt=1 TF=1 maxTF=1 @{0 5783 0}
# chapter -> term4115 Nt=2 TF=3 maxTF=2 @{0 5785 6}
# charact -> term3417 Nt=6 TF=6 maxTF=1 @{0 5790 7}
# character -> term2946 Nt=22 TF=22 maxTF=1 @{0 5798 7}
# characteris -> term889 Nt=3 TF=3 maxTF=1 @{0 5821 1}
# characterist -> term1480 Nt=7 TF=7 maxTF=1 @{0 5828 1}
# charg -> term5166 Nt=1 TF=1 maxTF=1 @{0 5843 3}
# charli -> term1685 Nt=1 TF=1 maxTF=1 @{0 5846 3}
# chart -> term1417 Nt=1 TF=1 maxTF=1 @{0 5848 7}
# chatgpt -> term3789 Nt=1 TF=1 maxTF=1 @{0 5851 3}
# cheat -> term3859 Nt=1 TF=1 maxTF=1 @{0 5854 3}
# checklist -> term4847 Nt=1 TF=1 maxTF=1 @{0 5857 3}
# chef -> term1629 Nt=2 TF=2 maxTF=1 @{0 5860 3}
# chemic -> term316 Nt=4 TF=4 maxTF=1 @{0 5865 5}
# chemistri -> term4486 Nt=1 TF=1 maxTF=1 @{0 5873 5}
# chemoselect -> term3815 Nt=2 TF=2 maxTF=1 @{0 5876 5}
# chemospecif -> term3986 Nt=1 TF=1 maxTF=1 @{0 5881 5}
# cher -> term1564 Nt=1 TF=1 maxTF=1 @{0 5884 5}
# chicago -> term4976 Nt=1 TF=1 maxTF=1 @{0 5887 1}
# child -> term2562 Nt=4 TF=4 maxTF=1 @{0 5890 1}
# children -> term2512 Nt=51 TF=52 maxTF=2 @{0 5897 7}
# chile -> term13 Nt=1 TF=1 maxTF=1 @{0 5943 2}
# china -> term442 Nt=19 TF=19 maxTF=1 @{0 5944 0}
# chines -> term326 Nt=3 TF=3 maxTF=1 @{0 5973 4}
# chip -> term3535 Nt=1 TF=1 maxTF=1 @{0 5980 0}
# chlorid -> term3612 Nt=3 TF=3 maxTF=1 @{0 5983 0}
# chlorido -> term5033 Nt=1 TF=1 maxTF=1 @{0 5990 2}
# chloridoplatin -> term5046 Nt=1 TF=1 maxTF=1 @{0 5993 2}
# chloro -> term5051 Nt=1 TF=1 maxTF=1 @{0 5996 2}
# chloro2 -> term5050 Nt=1 TF=1 maxTF=1 @{0 5999 2}
# chlorobenzyliden -> term5082 Nt=1 TF=1 maxTF=1 @{0 6002 2}
# choic -> term388 Nt=3 TF=3 maxTF=1 @{0 6005 2}
# chot -> term4517 Nt=1 TF=1 maxTF=1 @{0 6012 0}
# christen -> term3694 Nt=1 TF=1 maxTF=1 @{0 6015 0}
# christendom -> term4855 Nt=1 TF=1 maxTF=1 @{0 6018 0}
# christentum -> term791 Nt=1 TF=1 maxTF=1 @{0 6021 0}
# christian -> term2300 Nt=15 TF=15 maxTF=1 @{0 6023 2}
# christl -> term4566 Nt=1 TF=1 maxTF=1 @{0 6047 0}
# christlich -> term4709 Nt=2 TF=2 maxTF=1 @{0 6050 0}
# christlichen -> term4378 Nt=3 TF=3 maxTF=1 @{0 6054 6}
# chromat -> term2843 Nt=1 TF=1 maxTF=1 @{0 6060 4}
# chromen -> term4306 Nt=1 TF=1 maxTF=1 @{0 6063 2}
# chronolog -> term4418 Nt=2 TF=2 maxTF=1 @{0 6066 2}
# chukchi -> term2819 Nt=1 TF=1 maxTF=1 @{0 6071 2}
# church -> term3392 Nt=3 TF=3 maxTF=1 @{0 6074 0}
# cia -> term3558 Nt=1 TF=1 maxTF=1 @{0 6080 4}
# cidad -> term4281 Nt=1 TF=1 maxTF=1 @{0 6083 4}
# cinema -> term1414 Nt=1 TF=1 maxTF=1 @{0 6086 4}
# circl -> term825 Nt=1 TF=1 maxTF=1 @{0 6089 0}
# circul -> term2421 Nt=8 TF=8 maxTF=1 @{0 6091 2}
# citat -> term2068 Nt=2 TF=2 maxTF=1 @{0 6106 2}
# cite -> term1327 Nt=1 TF=1 maxTF=1 @{0 6111 4}
# citespac -> term1360 Nt=3 TF=3 maxTF=1 @{0 6114 0}
# citi -> term1079 Nt=8 TF=11 maxTF=2 @{0 6119 0}
# citizen -> term514 Nt=4 TF=4 maxTF=1 @{0 6134 3}
# citric -> term3978 Nt=1 TF=1 maxTF=1 @{0 6140 7}
# citt -> term5186 Nt=1 TF=1 maxTF=1 @{0 6143 7}
# ciudad -> term4515 Nt=1 TF=1 maxTF=1 @{0 6146 7}
# civic -> term4882 Nt=2 TF=2 maxTF=1 @{0 6149 7}
# civil -> term335 Nt=12 TF=12 maxTF=1 @{0 6153 1}
# civilian -> term451 Nt=2 TF=2 maxTF=1 @{0 6174 5}
# ck -> term4389 Nt=2 TF=2 maxTF=1 @{0 6178 7}
# cken -> term4480 Nt=1 TF=1 maxTF=1 @{0 6183 7}
# ckkehr -> term4463 Nt=1 TF=1 maxTF=1 @{0 6186 7}
# cksichtigung -> term1821 Nt=4 TF=4 maxTF=1 @{0 6189 7}
# cl2 -> term5170 Nt=1 TF=1 maxTF=1 @{0 6199 1}
# clai -> term4299 Nt=2 TF=2 maxTF=1 @{0 6202 1}
# claim -> term3497 Nt=2 TF=2 maxTF=1 @{0 6206 7}
# clandestin -> term81 Nt=4 TF=4 maxTF=1 @{0 6212 1}
# clapeyron -> term3138 Nt=1 TF=1 maxTF=1 @{0 6219 3}
# clash -> term3406 Nt=2 TF=2 maxTF=1 @{0 6222 1}
# class -> term2348 Nt=4 TF=4 maxTF=1 @{0 6227 3}
# classic -> term3101 Nt=2 TF=2 maxTF=1 @{0 6235 5}
# classif -> term198 Nt=33 TF=33 maxTF=1 @{0 6240 1}
# classifi -> term1517 Nt=4 TF=4 maxTF=1 @{0 6287 5}
# clausewitz -> term1004 Nt=1 TF=1 maxTF=1 @{0 6296 7}
# clausiu -> term3137 Nt=1 TF=1 maxTF=1 @{0 6299 1}
# clean -> term1156 Nt=4 TF=4 maxTF=1 @{0 6301 7}
# click -> term3848 Nt=1 TF=1 maxTF=1 @{0 6309 3}
# client -> term885 Nt=1 TF=1 maxTF=1 @{0 6312 3}
# climat -> term1304 Nt=107 TF=115 maxTF=2 @{0 6314 5}
# climatolog -> term2372 Nt=7 TF=7 maxTF=1 @{0 6398 5}
# climb -> term2902 Nt=1 TF=1 maxTF=1 @{0 6410 3}
# clinic -> term899 Nt=5 TF=5 maxTF=1 @{0 6413 1}
# cloak -> term3652 Nt=1 TF=1 maxTF=1 @{0 6423 1}
# close -> term761 Nt=2 TF=2 maxTF=1 @{0 6426 1}
# cloth -> term1382 Nt=1 TF=1 maxTF=1 @{0 6430 7}
# cloud -> term728 Nt=3 TF=3 maxTF=1 @{0 6433 3}
# cluster -> term286 Nt=17 TF=17 maxTF=1 @{0 6439 3}
# clutch -> term3303 Nt=1 TF=1 maxTF=1 @{0 6467 3}
# cmip5 -> term2369 Nt=4 TF=4 maxTF=1 @{0 6470 1}
# cnii -> term847 Nt=2 TF=2 maxTF=1 @{0 6478 5}
# cnn -> term1696 Nt=1 TF=1 maxTF=1 @{0 6481 7}
# co2 -> term3139 Nt=2 TF=2 maxTF=1 @{0 6484 3}
# coast -> term3175 Nt=1 TF=1 maxTF=1 @{0 6489 1}
# coastal -> term1028 Nt=4 TF=5 maxTF=2 @{0 6491 7}
# cobalt -> term5106 Nt=5 TF=5 maxTF=1 @{0 6501 2}
# cobit5 -> term4113 Nt=1 TF=1 maxTF=1 @{0 6506 6}
# cocryst -> term5115 Nt=1 TF=1 maxTF=1 @{0 6509 6}
# code -> term1301 Nt=6 TF=7 maxTF=2 @{0 6512 6}
# codif -> term4193 Nt=1 TF=1 maxTF=1 @{0 6526 1}
# coffe -> term3354 Nt=1 TF=1 maxTF=1 @{0 6529 1}
# cognit -> term482 Nt=4 TF=4 maxTF=1 @{0 6531 7}
# cohes -> term1443 Nt=2 TF=2 maxTF=1 @{0 6541 1}
# coin -> term4419 Nt=1 TF=1 maxTF=1 @{0 6546 3}
# cointegr -> term1507 Nt=1 TF=1 maxTF=1 @{0 6549 3}
# cold -> term1133 Nt=4 TF=4 maxTF=1 @{0 6551 7}
# ...
# uniform -> term2876 Nt=3 TF=3 maxTF=1 @{0 34397 3}
# unimagin -> term1100 Nt=1 TF=1 maxTF=1 @{0 34403 7}
# unimem -> term2168 Nt=1 TF=1 maxTF=1 @{0 34406 1}
# union -> term2262 Nt=1 TF=1 maxTF=1 @{0 34408 5}
# unipolar -> term947 Nt=1 TF=1 maxTF=1 @{0 34411 1}
# unit -> term552 Nt=16 TF=16 maxTF=1 @{0 34413 3}
# unity3d -> term555 Nt=1 TF=1 maxTF=1 @{0 34440 7}
# univari -> term2576 Nt=1 TF=1 maxTF=1 @{0 34442 7}
# univers -> term3353 Nt=9 TF=9 maxTF=1 @{0 34445 5}
# universalismu -> term4332 Nt=1 TF=1 maxTF=1 @{0 34457 7}
# universita -> term3554 Nt=1 TF=1 maxTF=1 @{0 34460 7}
# unknown -> term3022 Nt=1 TF=1 maxTF=1 @{0 34463 7}
# unkonventionellen -> term4537 Nt=1 TF=1 maxTF=1 @{0 34466 5}
# unnachgiebigkeit -> term2002 Nt=1 TF=1 maxTF=1 @{0 34469 5}
# unpreced -> term2317 Nt=4 TF=4 maxTF=1 @{0 34472 1}
# unravel -> term1888 Nt=1 TF=1 maxTF=1 @{0 34481 1}
# unreason -> term2331 Nt=1 TF=1 maxTF=1 @{0 34483 5}
# unsolv -> term1305 Nt=2 TF=2 maxTF=1 @{0 34486 3}
# unspent -> term3661 Nt=2 TF=2 maxTF=1 @{0 34490 5}
# unstabl -> term2783 Nt=1 TF=1 maxTF=1 @{0 34494 5}
# unstructur -> term1164 Nt=1 TF=1 maxTF=1 @{0 34497 3}
# unsupervis -> term2474 Nt=2 TF=2 maxTF=1 @{0 34499 5}
# unsurpris -> term2605 Nt=1 TF=1 maxTF=1 @{0 34504 7}
# untag -> term1203 Nt=1 TF=1 maxTF=1 @{0 34507 5}
# unter -> term1820 Nt=4 TF=4 maxTF=1 @{0 34509 7}
# untersuchung -> term1453 Nt=6 TF=6 maxTF=1 @{0 34519 1}
# unterwandern -> term1547 Nt=1 TF=1 maxTF=1 @{0 34531 3}
# upbring -> term4137 Nt=1 TF=1 maxTF=1 @{0 34533 7}
# upcross -> term2879 Nt=1 TF=1 maxTF=1 @{0 34536 7}
# updat -> term2624 Nt=2 TF=2 maxTF=1 @{0 34539 5}
# upper -> term2431 Nt=102 TF=105 maxTF=2 @{0 34544 5}
# urbain -> term4512 Nt=1 TF=1 maxTF=1 @{0 34611 2}
# urban -> term307 Nt=14 TF=14 maxTF=1 @{0 34614 2}
# urbana -> term4509 Nt=1 TF=1 maxTF=1 @{0 34638 2}
# urbani -> term1121 Nt=1 TF=1 maxTF=1 @{0 34641 2}
# urbano -> term4280 Nt=1 TF=1 maxTF=1 @{0 34643 4}
# urea -> term3746 Nt=1 TF=1 maxTF=1 @{0 34646 4}
# urethan -> term4079 Nt=1 TF=1 maxTF=1 @{0 34649 4}
# urspr -> term3913 Nt=1 TF=1 maxTF=1 @{0 34652 4}
# us -> term236 Nt=146 TF=146 maxTF=1 @{0 34655 4}
# usa -> term1455 Nt=5 TF=5 maxTF=1 @{0 34801 2}
# usag -> term1744 Nt=2 TF=2 maxTF=1 @{0 34812 0}
# usain -> term3446 Nt=2 TF=2 maxTF=1 @{0 34815 2}
# usayn -> term4038 Nt=2 TF=2 maxTF=1 @{0 34820 4}
# user -> term1736 Nt=16 TF=16 maxTF=1 @{0 34825 6}
# utaut -> term4886 Nt=1 TF=1 maxTF=1 @{0 34852 2}
# util -> term835 Nt=6 TF=6 maxTF=1 @{0 34855 2}
# utopia -> term930 Nt=1 TF=1 maxTF=1 @{0 34868 0}
# uzbek -> term4951 Nt=1 TF=1 maxTF=1 @{0 34870 2}
# uzbekistan -> term3404 Nt=2 TF=2 maxTF=1 @{0 34873 2}
# v2 -> term3334 Nt=1 TF=1 maxTF=1 @{0 34878 2}
# vaccin -> term2235 Nt=2 TF=2 maxTF=1 @{0 34881 0}
# vadi -> term4550 Nt=1 TF=1 maxTF=1 @{0 34885 2}
# valid -> term2305 Nt=7 TF=7 maxTF=1 @{0 34888 2}
# vallei -> term3263 Nt=3 TF=3 maxTF=1 @{0 34902 4}
# valu -> term633 Nt=58 TF=58 maxTF=1 @{0 34909 6}
# valuat -> term400 Nt=1 TF=1 maxTF=1 @{0 34964 6}
# vandal -> term1150 Nt=1 TF=1 maxTF=1 @{0 34966 6}
# vandalismamong -> term3425 Nt=2 TF=2 maxTF=1 @{0 34969 0}
# vanet -> term3857 Nt=1 TF=1 maxTF=1 @{0 34972 2}
# vanguard -> term4197 Nt=1 TF=1 maxTF=1 @{0 34975 2}
# vanillinyl -> term3688 Nt=1 TF=1 maxTF=1 @{0 34978 2}
# vapor -> term3115 Nt=3 TF=3 maxTF=1 @{0 34981 2}
# vari -> term2745 Nt=10 TF=10 maxTF=1 @{0 34988 2}
# variabl -> term1509 Nt=16 TF=16 maxTF=1 @{0 35001 6}
# varianten -> term2239 Nt=1 TF=1 maxTF=1 @{0 35025 0}
# variat -> term2881 Nt=8 TF=8 maxTF=1 @{0 35027 4}
# vascular -> term2639 Nt=1 TF=1 maxTF=1 @{0 35038 2}
# vashem -> term2204 Nt=1 TF=1 maxTF=1 @{0 35041 0}
# vault -> term4123 Nt=2 TF=2 maxTF=1 @{0 35043 4}
# vccm -> term1159 Nt=1 TF=1 maxTF=1 @{0 35047 0}
# ve -> term1258 Nt=1 TF=1 maxTF=1 @{0 35049 2}
# vector -> term398 Nt=6 TF=6 maxTF=1 @{0 35051 4}
# vehicl -> term770 Nt=6 TF=6 maxTF=1 @{0 35063 6}
# veic -> term3765 Nt=1 TF=1 maxTF=1 @{0 35075 2}
# veil -> term4713 Nt=1 TF=1 maxTF=1 @{0 35078 2}
# venic -> term3803 Nt=1 TF=1 maxTF=1 @{0 35081 2}
# ver -> term3565 Nt=1 TF=1 maxTF=1 @{0 35084 2}
# vera -> term4646 Nt=1 TF=1 maxTF=1 @{0 35087 2}
# verbot -> term4674 Nt=1 TF=1 maxTF=1 @{0 35090 2}
# vereinigungen -> term1613 Nt=1 TF=1 maxTF=1 @{0 35093 2}
# verfassungsrecht -> term4983 Nt=1 TF=1 maxTF=1 @{0 35095 6}
# verfassungsschutz -> term1536 Nt=1 TF=1 maxTF=1 @{0 35098 6}
# verfassungsstaaten -> term3164 Nt=1 TF=1 maxTF=1 @{0 35101 2}
# vergleich -> term1395 Nt=4 TF=4 maxTF=1 @{0 35104 0}
# vergleichend -> term1956 Nt=2 TF=2 maxTF=1 @{0 35113 0}
# verhinderung -> term1221 Nt=1 TF=1 maxTF=1 @{0 35117 2}
# verif -> term2189 Nt=2 TF=2 maxTF=1 @{0 35119 4}
# vernacular -> term4404 Nt=2 TF=2 maxTF=1 @{0 35124 6}
# vernetzt -> term2489 Nt=1 TF=1 maxTF=1 @{0 35128 2}
# verreisten -> term1579 Nt=1 TF=1 maxTF=1 @{0 35131 0}
# vers -> term4968 Nt=1 TF=1 maxTF=1 @{0 35133 4}
# version -> term3771 Nt=4 TF=4 maxTF=1 @{0 35136 4}
# verskoj -> term3778 Nt=1 TF=1 maxTF=1 @{0 35145 2}
# versuch -> term1896 Nt=3 TF=3 maxTF=1 @{0 35148 2}
# vertrag -> term1825 Nt=1 TF=1 maxTF=1 @{0 35153 0}
# vertragsparamet -> term3899 Nt=1 TF=1 maxTF=1 @{0 35155 4}
# verwirklichung -> term4985 Nt=1 TF=1 maxTF=1 @{0 35158 4}
# viaggio -> term2078 Nt=1 TF=1 maxTF=1 @{0 35161 4}
# viciou -> term826 Nt=1 TF=1 maxTF=1 @{0 35164 0}
# victim -> term1347 Nt=2 TF=2 maxTF=1 @{0 35166 2}
# victori -> term1439 Nt=2 TF=2 maxTF=1 @{0 35171 0}
# video -> term694 Nt=12 TF=13 maxTF=2 @{0 35175 2}
# vienna -> term1907 Nt=2 TF=2 maxTF=1 @{0 35194 5}
# view -> term1363 Nt=7 TF=7 maxTF=1 @{0 35199 7}
# viii -> term3403 Nt=1 TF=1 maxTF=1 @{0 35214 5}
# vil -> term3527 Nt=1 TF=1 maxTF=1 @{0 35217 3}
# vill -> term4511 Nt=1 TF=1 maxTF=1 @{0 35220 3}
# villag -> term4625 Nt=2 TF=2 maxTF=1 @{0 35223 3}
# violenc -> term366 Nt=7 TF=8 maxTF=2 @{0 35228 1}
# violent -> term1927 Nt=7 TF=7 maxTF=1 @{0 35241 2}
# virgo -> term2550 Nt=1 TF=1 maxTF=1 @{0 35254 4}
# virtu -> term3832 Nt=1 TF=1 maxTF=1 @{0 35257 2}
# virtual -> term730 Nt=16 TF=17 maxTF=2 @{0 35260 2}
# virtualit -> term2146 Nt=1 TF=1 maxTF=1 @{0 35287 5}
# viru -> term908 Nt=1 TF=1 maxTF=1 @{0 35290 1}
# virus -> term619 Nt=1 TF=1 maxTF=1 @{0 35292 3}
# viscou -> term3047 Nt=1 TF=1 maxTF=1 @{0 35294 3}
# vision -> term1357 Nt=2 TF=2 maxTF=1 @{0 35297 1}
# visual -> term237 Nt=21 TF=21 maxTF=1 @{0 35302 3}
# visualis -> term545 Nt=2 TF=2 maxTF=1 @{0 35334 5}
# visuel -> term1915 Nt=1 TF=1 maxTF=1 @{0 35339 3}
# visuomotor -> term2964 Nt=1 TF=1 maxTF=1 @{0 35341 7}
# vital -> term1924 Nt=1 TF=1 maxTF=1 @{0 35344 5}
# viticultur -> term2152 Nt=1 TF=1 maxTF=1 @{0 35347 1}
# vjersk -> term3699 Nt=1 TF=1 maxTF=1 @{0 35349 5}
# vo -> term1063 Nt=2 TF=2 maxTF=1 @{0 35352 5}
# vocat -> term3498 Nt=1 TF=1 maxTF=1 @{0 35357 3}
# vol -> term1093 Nt=2 TF=2 maxTF=1 @{0 35360 3}
# volksmedizin -> term4912 Nt=1 TF=1 maxTF=1 @{0 35365 5}
# volkst -> term1611 Nt=1 TF=1 maxTF=1 @{0 35368 5}
# volum -> term90 Nt=6 TF=6 maxTF=1 @{0 35371 1}
# voluntari -> term2693 Nt=2 TF=2 maxTF=1 @{0 35381 7}
# vom -> term1633 Nt=6 TF=6 maxTF=1 @{0 35385 7}
# von -> term1077 Nt=26 TF=29 maxTF=2 @{0 35398 5}
# vor -> term1075 Nt=3 TF=3 maxTF=1 @{0 35434 0}
# vorgehen -> term1975 Nt=1 TF=1 maxTF=1 @{0 35440 0}
# vorgeschicht -> term4907 Nt=1 TF=1 maxTF=1 @{0 35442 4}
# vorrang -> term1179 Nt=1 TF=1 maxTF=1 @{0 35445 4}
# vote -> term2410 Nt=3 TF=3 maxTF=1 @{0 35447 6}
# vox -> term2231 Nt=1 TF=1 maxTF=1 @{0 35455 4}
# vulner -> term1745 Nt=7 TF=7 maxTF=1 @{0 35458 0}
# vy -> term3187 Nt=1 TF=1 maxTF=1 @{0 35470 6}
# w135 -> term4760 Nt=1 TF=1 maxTF=1 @{0 35473 4}
# wa -> term4108 Nt=2 TF=2 maxTF=1 @{0 35476 4}
# waffen -> term1765 Nt=1 TF=1 maxTF=1 @{0 35481 4}
# wage -> term3391 Nt=1 TF=1 maxTF=1 @{0 35484 0}
# wahdat -> term3826 Nt=1 TF=1 maxTF=1 @{0 35486 6}
# wahl -> term2794 Nt=1 TF=1 maxTF=1 @{0 35489 6}
# wahr -> term4635 Nt=1 TF=1 maxTF=1 @{0 35492 4}
# wahrnehmung -> term4547 Nt=2 TF=2 maxTF=1 @{0 35495 4}
# wai -> term3360 Nt=3 TF=3 maxTF=1 @{0 35500 0}
# wait -> term2090 Nt=1 TF=1 maxTF=1 @{0 35505 2}
# walter -> term1020 Nt=1 TF=1 maxTF=1 @{0 35507 6}
# wandel -> term4643 Nt=1 TF=1 maxTF=1 @{0 35510 0}
# waqf -> term4718 Nt=3 TF=3 maxTF=1 @{0 35513 0}
# war -> term40 Nt=24 TF=25 maxTF=2 @{0 35517 6}
# warfar -> term56 Nt=14 TF=14 maxTF=1 @{0 35552 5}
# warm -> term2443 Nt=14 TF=14 maxTF=1 @{0 35571 1}
# warmer -> term2581 Nt=3 TF=3 maxTF=1 @{0 35592 1}
# warn -> term871 Nt=7 TF=7 maxTF=1 @{0 35598 7}
# washington -> term1092 Nt=2 TF=2 maxTF=1 @{0 35612 5}
# wast -> term3581 Nt=2 TF=2 maxTF=1 @{0 35616 3}
# wastewat -> term4802 Nt=1 TF=1 maxTF=1 @{0 35619 5}
# water -> term2466 Nt=6 TF=6 maxTF=1 @{0 35622 5}
# wave -> term2509 Nt=10 TF=10 maxTF=1 @{0 35634 3}
# waz -> term4465 Nt=1 TF=1 maxTF=1 @{0 35650 3}
# weak -> term1786 Nt=1 TF=1 maxTF=1 @{0 35653 3}
# weakli -> term3200 Nt=2 TF=2 maxTF=1 @{0 35655 7}
# weapon -> term319 Nt=5 TF=5 maxTF=1 @{0 35659 7}
# wearabl -> term3031 Nt=2 TF=2 maxTF=1 @{0 35668 5}
# weather -> term2398 Nt=22 TF=22 maxTF=1 @{0 35673 3}
# web -> term440 Nt=51 TF=56 maxTF=2 @{0 35699 5}
# weblog -> term717 Nt=2 TF=2 maxTF=1 @{0 35765 6}
# websit -> term2151 Nt=2 TF=2 maxTF=1 @{0 35771 0}
# webster -> term2302 Nt=2 TF=2 maxTF=1 @{0 35776 2}
# weefim -> term2892 Nt=1 TF=1 maxTF=1 @{0 35779 4}
# weg -> term1462 Nt=1 TF=1 maxTF=1 @{0 35782 2}
# wege -> term2004 Nt=1 TF=1 maxTF=1 @{0 35784 6}
# weiblich -> term2131 Nt=1 TF=1 maxTF=1 @{0 35787 2}
# weight -> term1660 Nt=6 TF=6 maxTF=1 @{0 35789 6}
# welfar -> term2873 Nt=1 TF=1 maxTF=1 @{0 35803 0}
# well -> term894 Nt=4 TF=4 maxTF=1 @{0 35805 6}
# welt -> term3798 Nt=3 TF=3 maxTF=1 @{0 35813 4}
# weltentsagung -> term4230 Nt=1 TF=1 maxTF=1 @{0 35820 2}
# weltlich -> term4792 Nt=1 TF=1 maxTF=1 @{0 35823 2}
# weltordnungspolitik -> term1852 Nt=1 TF=1 maxTF=1 @{0 35826 2}
# wenig -> term2490 Nt=1 TF=1 maxTF=1 @{0 35828 6}
# wereld -> term927 Nt=1 TF=1 maxTF=1 @{0 35831 4}
# wertewandel -> term4911 Nt=1 TF=1 maxTF=1 @{0 35833 6}
# west -> term1047 Nt=7 TF=7 maxTF=1 @{0 35836 6}
# westen -> term1460 Nt=1 TF=1 maxTF=1 @{0 35850 0}
# western -> term963 Nt=8 TF=8 maxTF=1 @{0 35852 4}
# westeuropa -> term2003 Nt=1 TF=1 maxTF=1 @{0 35868 6}
# westgat -> term938 Nt=1 TF=1 maxTF=1 @{0 35871 2}
# westlich -> term4275 Nt=3 TF=3 maxTF=1 @{0 35873 4}
# westlichen -> term4444 Nt=1 TF=1 maxTF=1 @{0 35879 4}
# westsumatra -> term4921 Nt=2 TF=2 maxTF=1 @{0 35882 4}
# whale -> term1842 Nt=1 TF=1 maxTF=1 @{0 35886 0}
# wheelchair -> term3310 Nt=1 TF=1 maxTF=1 @{0 35888 4}
# white -> term2344 Nt=2 TF=2 maxTF=1 @{0 35891 2}
# who -> term942 Nt=4 TF=4 maxTF=1 @{0 35896 4}
# whole -> term1381 Nt=1 TF=1 maxTF=1 @{0 35906 0}
# wide -> term819 Nt=4 TF=4 maxTF=1 @{0 35908 4}
# widerspruch -> term1903 Nt=1 TF=1 maxTF=1 @{0 35915 4}
# wie -> term1546 Nt=2 TF=2 maxTF=1 @{0 35918 0}
# wieden -> term458 Nt=1 TF=1 maxTF=1 @{0 35921 0}
# wiggl -> term2936 Nt=1 TF=1 maxTF=1 @{0 35923 0}
# wikileak -> term1732 Nt=1 TF=1 maxTF=1 @{0 35925 6}
# wikipedia -> term205 Nt=3 TF=4 maxTF=2 @{0 35928 2}
# willamett -> term2685 Nt=1 TF=1 maxTF=1 @{0 35935 1}
# willibald -> term3477 Nt=1 TF=1 maxTF=1 @{0 35937 7}
# willing -> term526 Nt=1 TF=1 maxTF=1 @{0 35940 7}
# win -> term1014 Nt=2 TF=2 maxTF=1 @{0 35942 7}
# wind -> term2397 Nt=25 TF=27 maxTF=3 @{0 35947 5}
# windstorm -> term2972 Nt=3 TF=3 maxTF=1 @{0 35976 7}
# wing -> term36 Nt=16 TF=16 maxTF=1 @{0 35983 1}
# winter -> term2603 Nt=10 TF=10 maxTF=1 @{0 36001 5}
# wirklich -> term800 Nt=1 TF=1 maxTF=1 @{0 36016 7}
# wirkung -> term4958 Nt=1 TF=1 maxTF=1 @{0 36019 1}
# wirtschaftsethik -> term4235 Nt=1 TF=1 maxTF=1 @{0 36022 1}
# wirtschaftspolitik -> term4913 Nt=1 TF=1 maxTF=1 @{0 36025 1}
# wisconsin -> term3083 Nt=1 TF=1 maxTF=1 @{0 36028 1}
# wisdom -> term925 Nt=3 TF=3 maxTF=1 @{0 36030 7}
# wissenschaft -> term4750 Nt=1 TF=1 maxTF=1 @{0 36036 3}
# wissensordnungen -> term1866 Nt=2 TF=2 maxTF=1 @{0 36039 3}
# wlic -> term1194 Nt=1 TF=1 maxTF=1 @{0 36043 1}
# wmd -> term551 Nt=1 TF=1 maxTF=1 @{0 36045 3}
# wobbl -> term3315 Nt=1 TF=2 maxTF=2 @{0 36047 3}
# wochenmagazin -> term4095 Nt=1 TF=1 maxTF=1 @{0 36050 2}
# wolf -> term1445 Nt=2 TF=2 maxTF=1 @{0 36053 2}
# women -> term2658 Nt=8 TF=8 maxTF=1 @{0 36057 6}
# won -> term906 Nt=1 TF=1 maxTF=1 @{0 36071 6}
# word -> term329 Nt=6 TF=6 maxTF=1 @{0 36074 0}
# work -> term1235 Nt=9 TF=10 maxTF=2 @{0 36084 2}
# worker -> term3574 Nt=1 TF=1 maxTF=1 @{0 36101 7}
# workplac -> term2861 Nt=2 TF=2 maxTF=1 @{0 36104 7}
# workshop -> term352 Nt=2 TF=2 maxTF=1 @{0 36110 1}
# workspac -> term2897 Nt=1 TF=1 maxTF=1 @{0 36114 3}
# world -> term151 Nt=29 TF=36 maxTF=3 @{0 36117 1}
# worldview -> term3491 Nt=3 TF=3 maxTF=1 @{0 36160 4}
# worldwid -> term1774 Nt=2 TF=2 maxTF=1 @{0 36167 6}
# worsen -> term3013 Nt=1 TF=1 maxTF=1 @{0 36172 6}
# worship -> term1479 Nt=3 TF=3 maxTF=1 @{0 36175 4}
# write -> term3735 Nt=3 TF=3 maxTF=1 @{0 36182 0}
# wtc -> term1959 Nt=1 TF=1 maxTF=1 @{0 36188 6}
# wujud -> term3827 Nt=1 TF=1 maxTF=1 @{0 36191 2}
# x13 -> term4370 Nt=1 TF=1 maxTF=1 @{0 36194 2}
# xanthen -> term3614 Nt=1 TF=1 maxTF=1 @{0 36197 2}
# xanthenedion -> term3868 Nt=1 TF=1 maxTF=1 @{0 36200 2}
# xenophobia -> term1138 Nt=2 TF=2 maxTF=1 @{0 36203 2}
# xiv -> term1087 Nt=2 TF=2 maxTF=1 @{0 36208 0}
# xixth -> term4654 Nt=1 TF=1 maxTF=1 @{0 36213 0}
# xv -> term4279 Nt=2 TF=2 maxTF=1 @{0 36216 0}
# xw -> term3078 Nt=2 TF=2 maxTF=1 @{0 36221 0}
# xx -> term3738 Nt=1 TF=1 maxTF=1 @{0 36225 4}
# xxth -> term4655 Nt=1 TF=1 maxTF=1 @{0 36228 4}
# xylen -> term4824 Nt=1 TF=1 maxTF=1 @{0 36231 4}
# ya -> term4425 Nt=2 TF=3 maxTF=2 @{0 36234 4}
# yad -> term2211 Nt=1 TF=1 maxTF=1 @{0 36239 5}
# yam -> term1067 Nt=1 TF=1 maxTF=1 @{0 36242 1}
# yaneer -> term1064 Nt=1 TF=1 maxTF=1 @{0 36244 3}
# yangtz -> term2472 Nt=3 TF=3 maxTF=1 @{0 36246 5}
# yardstick -> term3515 Nt=1 TF=1 maxTF=1 @{0 36253 7}
# yasmina -> term2157 Nt=1 TF=1 maxTF=1 @{0 36256 7}
# year -> term2754 Nt=4 TF=5 maxTF=2 @{0 36259 3}
# yield -> term2835 Nt=1 TF=1 maxTF=1 @{0 36268 6}
# yl -> term3582 Nt=3 TF=3 maxTF=1 @{0 36271 4}
# yld -> term5191 Nt=1 TF=1 maxTF=1 @{0 36277 4}
# ylid -> term4077 Nt=1 TF=1 maxTF=1 @{0 36280 4}
# ylide -> term3649 Nt=15 TF=15 maxTF=1 @{0 36283 4}
# yorumlar -> term1259 Nt=1 TF=1 maxTF=1 @{0 36303 2}
# young -> term3408 Nt=1 TF=1 maxTF=1 @{0 36305 4}
# younger -> term4712 Nt=1 TF=1 maxTF=1 @{0 36308 2}
# yousri -> term1166 Nt=1 TF=1 maxTF=1 @{0 36311 2}
# youth -> term2781 Nt=5 TF=5 maxTF=1 @{0 36313 4}
# youtub -> term2339 Nt=4 TF=4 maxTF=1 @{0 36324 6}
# yusuf -> term4092 Nt=2 TF=2 maxTF=1 @{0 36331 4}
# zajednic -> term3708 Nt=1 TF=1 maxTF=1 @{0 36335 6}
# zajednici -> term3782 Nt=1 TF=1 maxTF=1 @{0 36338 6}
# zak -> term4720 Nt=1 TF=1 maxTF=1 @{0 36341 6}
# zakonodavstvo -> term3779 Nt=1 TF=1 maxTF=1 @{0 36344 6}
# zdf -> term2246 Nt=1 TF=1 maxTF=1 @{0 36347 6}
# zeal -> term4997 Nt=1 TF=1 maxTF=1 @{0 36350 2}
# zeiten -> term4667 Nt=1 TF=1 maxTF=1 @{0 36353 2}
# zeitgen -> term4491 Nt=1 TF=1 maxTF=1 @{0 36356 2}
# zellphysiologi -> term3470 Nt=1 TF=1 maxTF=1 @{0 36359 2}
# zeolit -> term4823 Nt=1 TF=1 maxTF=1 @{0 36362 2}
# zernik -> term4003 Nt=1 TF=1 maxTF=1 @{0 36365 2}
# zero -> term1310 Nt=1 TF=1 maxTF=1 @{0 36368 2}
# zhondor -> term3457 Nt=1 TF=1 maxTF=1 @{0 36370 6}
# ziel -> term790 Nt=1 TF=1 maxTF=1 @{0 36373 6}
# zinc -> term4256 Nt=5 TF=5 maxTF=1 @{0 36376 0}
# zirconium -> term3619 Nt=1 TF=1 maxTF=1 @{0 36384 6}
# zivilen -> term2112 Nt=1 TF=1 maxTF=1 @{0 36387 6}
# zivilgesellschaft -> term1459 Nt=1 TF=1 maxTF=1 @{0 36390 2}
# zivilrechtsdebatt -> term4863 Nt=1 TF=1 maxTF=1 @{0 36392 6}
# zn -> term5179 Nt=1 TF=2 maxTF=2 @{0 36395 6}
# zohreh -> term4338 Nt=1 TF=1 maxTF=1 @{0 36398 7}
# zone -> term2120 Nt=2 TF=2 maxTF=1 @{0 36401 7}
# zoom -> term2160 Nt=1 TF=1 maxTF=1 @{0 36406 7}
# zorn -> term4964 Nt=1 TF=1 maxTF=1 @{0 36409 3}
# zrocl2 -> term3869 Nt=1 TF=1 maxTF=1 @{0 36412 3}
# ztu -> term4426 Nt=1 TF=1 maxTF=1 @{0 36415 3}
# zu -> term1818 Nt=6 TF=6 maxTF=1 @{0 36418 3}
# zuge -> term1616 Nt=1 TF=1 maxTF=1 @{0 36429 5}
# zum -> term1630 Nt=11 TF=11 maxTF=1 @{0 36432 1}
# zur -> term1001 Nt=21 TF=22 maxTF=2 @{0 36449 5}
# zusammenarbeit -> term1972 Nt=1 TF=1 maxTF=1 @{0 36478 6}
# zusammenstellungen -> term2145 Nt=1 TF=1 maxTF=1 @{0 36481 2}
# zust -> term3000 Nt=1 TF=1 maxTF=1 @{0 36483 6}
# zustand -> term3110 Nt=1 TF=1 maxTF=1 @{0 36486 4}
# zwanzigsten -> term4620 Nt=1 TF=1 maxTF=1 @{0 36489 2}
# zweiten -> term4621 Nt=1 TF=1 maxTF=1 @{0 36492 2}
# zwischen -> term1993 Nt=11 TF=13 maxTF=2 @{0 36495 2}
# zwitterion -> term3689 Nt=2 TF=2 maxTF=1 @{0 36514 0}

# %%
term = "attack" 
index.getLexicon()[term].toString() #Gibt die Ergebnisse für einen einzigen Term aus
# Out:
# 'term177 Nt=94 TF=94 maxTF=1 @{0 3261 0}'

# %%
#Which term occur the most?

term_freq_dict = {}  #Erstellen eines Dict. Schlüssel=Term , Wert=Anzahl des Vorkommens

for kv in index.getLexicon():
    term_freq_dict[kv.getKey()] = kv.getValue().frequency

# %%
#sort all terms from the index in descending order
term_freq_dict_sorted = sorted(term_freq_dict.items(), key=lambda x: x[1], reverse=True) #Nicht nach alphabetisch sondern die nach Häufigkeit des Terms ordnen

# %%
top_k = 30 #gibt die 30 häufigstens Terme in gestemmter Form aus
term_freq_dict_sorted[:top_k]
# Out:
# [('extrem', 639),
#  ('islam', 415),
#  ('terror', 400),
#  ('terrorist', 358),
#  ('model', 234),
#  ('network', 204),
#  ('analysi', 173),
#  ('extremum', 168),
#  ('base', 155),
#  ('us', 146),
#  ('2', 137),
#  ('und', 131),
#  ('studi', 127),
#  ('seek', 120),
#  ('climat', 115),
#  ('system', 113),
#  ('der', 106),
#  ('upper', 105),
#  ('detect', 99),
#  ('social', 98),
#  ('chang', 96),
#  ('attack', 94),
#  ('de', 93),
#  ('synthesi', 93),
#  ('global', 90),
#  ('control', 88),
#  ('approach', 78),
#  ('effect', 74),
#  ('extremist', 73),
#  ('precipit', 71)]

# %%
#define our search engine
search_engine = pt.BatchRetrieve(index, wmodel="Tf") #erstellt ein Retriever Objekt, das für die Suche im Index zuständig ist
                                                     #wmodel (weigt model) --> Nach Welchem Modell soll die Relevanz gewichtet werden (TF, TF-IDF, BM25)
                                                     #bei TF: Je häufiger ein Term in einem Dokument vorkommt, desto höher soll das Dokument gewichtet sein
# Out:
# /tmp/ipykernel_18790/160129900.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine = pt.BatchRetrieve(index, wmodel="Tf") #erstellt ein Retriever Objekt, das für die Suche im Index zuständig ist

# %%
search_engine.search("terrorism") #jetzt is die Suchmaschine definiert und wir können nach bestimmten Termen suchen
# Out:
#     qid  docid                                              docno  rank  \
# 0     1     61  https://www.bibsonomy.org/bibtex/22ee56728eeba...     0
# 1     1     62  https://www.bibsonomy.org/bibtex/20b361a7cf25b...     1
# 2     1     73  https://www.bibsonomy.org/bibtex/212bb9d775607...     2
# 3     1     74  https://www.bibsonomy.org/bibtex/2b84b0f833814...     3
# 4     1     75  https://www.bibsonomy.org/bibtex/21ed633534dcb...     4
# ..   ..    ...                                                ...   ...
# 382   1   2074  https://www.bibsonomy.org/bibtex/2031f80c7f6ac...   382
# 383   1   2109  https://www.bibsonomy.org/bibtex/27271541d9248...   383
# 384   1   2294  https://www.bibsonomy.org/bibtex/276cb7ee3d22a...   384
# 385   1   2330  https://www.bibsonomy.org/bibtex/2c895142934fc...   385
# 386   1   2709  https://www.bibsonomy.org/bibtex/288338a237464...   386
#
#      score      query
# 0      2.0  terrorism
# 1      2.0  terrorism
# 2      2.0  terrorism
# 3      2.0  terrorism
# 4      2.0  terrorism
# ..     ...        ...
# 382    1.0  terrorism
# 383    1.0  terrorism
# 384    1.0  terrorism
# 385    1.0  terrorism
# 386    1.0  terrorism
#
# [387 rows x 6 columns]

# %%
search_engine.search("terrorism network")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1     99  https://www.bibsonomy.org/bibtex/262ecf348e821...     0
# 1     1    258  https://www.bibsonomy.org/bibtex/2f3d1899b5d58...     1
# 2     1    281  https://www.bibsonomy.org/bibtex/209e829188ea9...     2
# 3     1    287  https://www.bibsonomy.org/bibtex/2a474f8e526b6...     3
# 4     1    870  https://www.bibsonomy.org/bibtex/2651436f4ef07...     4
# ..   ..    ...                                                ...   ...
# 545   1   2609  https://www.bibsonomy.org/bibtex/23c46012e580a...   545
# 546   1   2643  https://www.bibsonomy.org/bibtex/2dda9498c0ff6...   546
# 547   1   2689  https://www.bibsonomy.org/bibtex/25526974e7c92...   547
# 548   1   2709  https://www.bibsonomy.org/bibtex/288338a237464...   548
# 549   1   2753  https://www.bibsonomy.org/bibtex/2df752ac3b1f4...   549
#
#      score              query
# 0      3.0  terrorism network
# 1      3.0  terrorism network
# 2      3.0  terrorism network
# 3      3.0  terrorism network
# 4      3.0  terrorism network
# ..     ...                ...
# 545    1.0  terrorism network
# 546    1.0  terrorism network
# 547    1.0  terrorism network
# 548    1.0  terrorism network
# 549    1.0  terrorism network
#
# [550 rows x 6 columns]

# %%
#what do we need for inverse document frequency? -->TF-IDF Gewichtung soll berücksichten dass seltene Terme stärker gewichtet werden 
#als weniger seltene wie "und, das, ist"

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
#stem the term its base form
stem = stemmer.stem("violence")
stem
# Out:
# 'violenc'

# %%
#wie oft kommt das gestemmte Wort vor?
lexicon = index.getLexicon()
lexicon[stem].getDocumentFrequency()
# Out:
# 7

# %%
index.getCollectionStatistics().numberOfDocuments
# Out:
# 2790

# %%
#Funktion zur BErechnung des IDF-Wertes

def get_idf_for_term(term, index):
    lex = index.getLexicon()
    stemmed_term = stemmer.stem(term)
    if not stemmed_term in lex:
        return

    lex_entry = lex[stemmed_term]
    
    df_term = lex_entry.getDocumentFrequency()
    N = index.getCollectionStatistics().numberOfDocuments
    
    #inverse Dokumentenfrequenz
    idf = N/df_term
    #logarithmus, damit die Relevanz nicht proportional berechnet wird
    log_idf = np.emath.logn(10, idf)
    
    return log_idf

# %%
get_idf_for_term("violence", index)
# Out:
# 2.6005061632593405

# %%
#define your own tf_idf method here:

def calc_tf_idf(query, docno, index):
    #remember that tfidf is the product of two components
    #hint: the tf model search result contains tf frequencies
    return 0

# %%
search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
# Out:
# /tmp/ipykernel_18790/2880449899.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")

# %%
search_engine_tfidf.search("terrorism network")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1     71  https://www.bibsonomy.org/bibtex/2eef4d4550137...     0
# 1     1     89  https://www.bibsonomy.org/bibtex/2a3adc83b2bc8...     1
# 2     1     99  https://www.bibsonomy.org/bibtex/262ecf348e821...     2
# 3     1    258  https://www.bibsonomy.org/bibtex/2f3d1899b5d58...     3
# 4     1    287  https://www.bibsonomy.org/bibtex/2a474f8e526b6...     4
# ..   ..    ...                                                ...   ...
# 545   1    401  https://www.bibsonomy.org/bibtex/261fb45117724...   545
# 546   1    375  https://www.bibsonomy.org/bibtex/240392690b924...   546
# 547   1    408  https://www.bibsonomy.org/bibtex/257d2fa5416e4...   547
# 548   1    411  https://www.bibsonomy.org/bibtex/2c8d1173d7e9d...   548
# 549   1    434  https://www.bibsonomy.org/bibtex/20a84e04dbfd6...   549
#
#         score              query
# 0    4.847838  terrorism network
# 1    4.847838  terrorism network
# 2    4.508004  terrorism network
# 3    4.508004  terrorism network
# 4    4.342190  terrorism network
# ..        ...                ...
# 545  1.160518  terrorism network
# 546  1.051743  terrorism network
# 547  1.051743  terrorism network
# 548  1.051743  terrorism network
# 549  0.989888  terrorism network
#
# [550 rows x 6 columns]

# %%
df_bibsonomy.columns
# Out:
# Index(['id', 'label', 'author', 'type', 'date', 'year', 'search_term', 'tags',
#        'description', 'changeDate', 'url', 'pub-type', 'publisher', 'docno',
#        'text'],
#       dtype='object')

# %%
#transform dataframe into list of dictionaries
ter_dict = df_bibsonomy.to_dict(orient='records')

# %%
ter_dict #Das ter_dict ist eine Liste [], in der jeder einzelne Eintrag ein Dictionary ist {}
# Out:
# [{'id': 'https://www.bibsonomy.org/bibtex/22e03edf1449f8bd34a2f6f8a13229bd5/ijtsrd',
#   'label': 'Food Terrorism',
#   'author': ['Matthew N. O. Sadiku | Sarhan M. Musa | Tolulope J. Ashaolu'],
#   'type': 'Publication',
#   'date': '2019-07-04 12:16:18',
#   'year': '2019',
#   'search_term': 'terrorism',
#   'tags': ['terrorism', 'biological', 'defense', 'food', 'agro'],
#   'description': '',
#   'changeDate': '2019-07-04 12:16:18',
#   'url': 'https://www.ijtsrd.com/other-scientific-research-area/other/23642/food-terrorism/matthew-n-o-sadiku',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/22e03edf1449f8bd34a2f6f8a13229bd5/ijtsrd',
#   'text': 'Food Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/26a182024b6dbd37445d219533eb5e87a/ijtsrd',
#   'label': 'How does Terrorism Effect on Business and Relation Between Countries',
#   'author': ['S. Raju Pooja Prof. Sidharth'],
#   'type': 'Publication',
#   'date': '2018-09-11 08:26:02',
#   'year': '2017',
#   'search_term': 'terrorism',
#   'tags': ['Business',
#    '(IB)',
#    'Terrorism',
#    'business',
#    'International',
#    'issues'],
#   'description': '',
#   'changeDate': '2018-10-02 11:01:26',
#   'url': 'http://www.ijtsrd.com/management/international-business-issues/4598/how-does-terrorism-effect-on-business-and-relation--between-countries/prof-sidharth-s-raju',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/26a182024b6dbd37445d219533eb5e87a/ijtsrd',
#   'text': 'How does Terrorism Effect on Business and Relation Between Countries'},
#  {'id': 'https://www.bibsonomy.org/bibtex/201c2fea8172ad598c18d7dd1c4754547/ijtsrd',
#   'label': 'Money Transfer Regulation and the Fight against Terrorism Related Activities in Cameroon',
#   'author': ['Lukong Alban Bongwong'],
#   'type': 'Publication',
#   'date': '2020-10-03 11:41:39',
#   'year': '2020',
#   'search_term': 'terrorism',
#   'tags': ['Other', 'transfer', 'terrorism', 'corruption', 'Funds'],
#   'description': '',
#   'changeDate': '2020-10-03 11:41:39',
#   'url': 'https://www.ijtsrd.com/other-scientific-research-area/other/33109/money-transfer-regulation-and-the-fight-against-terrorism-related-activities-in-cameroon/lukong-alban-bongwong',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/201c2fea8172ad598c18d7dd1c4754547/ijtsrd',
#   'text': 'Money Transfer Regulation and the Fight against Terrorism Related Activities in Cameroon'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2273978ed4446aad86fa30528e130388f/droessler',
#   'label': 'State terrorism in Latin America : Chile, Argentina, and international human rights',
#   'author': ['Thomas Wright'],
#   'type': 'Publication',
#   'date': '2015-07-23 15:15:26',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['außenpolitik',
#    'usa',
#    'menschenrechte',
#    'politik',
#    'lateinamerika',
#    'terrorismus'],
#   'description': 'State Terrorism in Latin America: Chile, Argentina, and International Human Rights Latin American Silhouettes: Amazon.de: Thomas Wright: Fremdsprachige Bücher',
#   'changeDate': '2020-11-20 13:41:20',
#   'url': 'http://www.amazon.de/State-Terrorism-Latin-America-International/dp/0742537218/ref=sr_1_4?ie=UTF8&qid=1437657198&sr=8-4&keywords=state-sponsored+terrorism',
#   'pub-type': 'book',
#   'publisher': 'Rowman & Littlefield',
#   'docno': 'https://www.bibsonomy.org/bibtex/2273978ed4446aad86fa30528e130388f/droessler',
#   'text': 'State terrorism in Latin America : Chile, Argentina, and international human rights'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2adba8d1854b2cd1775a9cf07c1dabf61/ijtsrd',
#   'label': 'The Role of Extradition Treaties in Crime Management and Combating Terrorism',
#   'author': ['AdishiEric OlukaNduka Lucas'],
#   'type': 'Publication',
#   'date': '2018-09-01 12:55:37',
#   'year': '2018',
#   'search_term': 'terrorism',
#   'tags': ['Extradition',
#    'Crime',
#    'Terrorism',
#    'treaties',
#    'challenges',
#    'Political',
#    'security',
#    'Science',
#    'Global'],
#   'description': '',
#   'changeDate': '2018-10-02 11:01:26',
#   'url': 'http://www.ijtsrd.com/humanities-and-the-arts/political-science/9475/the-role-of-extradition-treaties-in-crime-management-and-combating-terrorism/adishi-eric',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2adba8d1854b2cd1775a9cf07c1dabf61/ijtsrd',
#   'text': 'The Role of Extradition Treaties in Crime Management and Combating Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/262f7bd0bcaf8af43b17cbd6a410f3d9a/nosebrain',
#   'label': 'Introducing the global terrorism database',
#   'author': ['Gary LaFree', 'Laura Dugan'],
#   'type': 'Publication',
#   'date': '2020-03-25 11:58:40',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['dataset', 'database', 'killbert', 'terrorism'],
#   'description': '',
#   'changeDate': '2020-03-25 11:58:40',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': 'Taylor & Francis',
#   'docno': 'https://www.bibsonomy.org/bibtex/262f7bd0bcaf8af43b17cbd6a410f3d9a/nosebrain',
#   'text': 'Introducing the global terrorism database'},
#  {'id': 'https://www.bibsonomy.org/bibtex/218c8c359b1d6b04e2d84bdd0fb638471/fbw_hannover',
#   'label': 'What makes a terrorist',
#   'author': ['Alan B. Krueger'],
#   'type': 'Publication',
#   'date': '2009-08-21 12:22:28',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['Terrorismus',
#    'Economic_aspects',
#    'Wirtschaftssoziologie',
#    'Kriminalpolitik',
#    'Terrorism',
#    'Kriminalitätsökonomik',
#    'Wirtschaft',
#    'Terrorists',
#    'Wirtschaftspsychologie',
#    'Terrorist',
#    'Politische_Gewalt'],
#   'description': '',
#   'changeDate': '2009-08-21 12:23:09',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+529478641&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'publisher': 'Princeton Univ. Press',
#   'docno': 'https://www.bibsonomy.org/bibtex/218c8c359b1d6b04e2d84bdd0fb638471/fbw_hannover',
#   'text': 'What makes a terrorist'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2abaf760a38643b89e172a64f24587cf0/meneteqel',
#   'label': 'The "Moro Affair" - Left-Wing Terrorism and Conspiracy in Italy in the late 1970s',
#   'author': ['Tobias Hof'],
#   'type': 'Publication',
#   'date': '2019-04-26 00:41:22',
#   'year': '2013',
#   'search_term': 'terrorism',
#   'tags': ['Aldo_Moro',
#    'conspiracy',
#    'terrorism',
#    'Italy',
#    'secret_services',
#    'conspiracy_theories'],
#   'description': '',
#   'changeDate': '2019-04-26 00:41:22',
#   'url': 'http://www.ssoar.info/ssoar/handle/document/38769',
#   'pub-type': 'article',
#   'publisher': 'HSR (GESIS Leibniz Institute for the Social Sciences)',
#   'docno': 'https://www.bibsonomy.org/bibtex/2abaf760a38643b89e172a64f24587cf0/meneteqel',
#   'text': 'The "Moro Affair" - Left-Wing Terrorism and Conspiracy in Italy in the late 1970s'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29b576de17b6c47ba8e33cc00f963c412/mikaelbook',
#   'label': 'U.S. Libraries and the "War on Terrorism"',
#   'author': ['Mark Hudson'],
#   'type': 'Publication',
#   'date': '2021-08-25 12:31:13',
#   'year': '2004',
#   'search_term': 'terrorism',
#   'tags': ['library', 'usa', 'terrorism'],
#   'description': 'U.S. Libraries and the "War on Terrorism" - New Politics',
#   'changeDate': '2021-08-25 12:31:13',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/29b576de17b6c47ba8e33cc00f963c412/mikaelbook',
#   'text': 'U.S. Libraries and the "War on Terrorism"'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2cfb2db051d7715b8905549c219a58c42/ijtsrd',
#   'label': 'Terrorism Problems and Solutions With Special Reference to India',
#   'author': ['Dr. Deep Kumar Srivastava'],
#   'type': 'Publication',
#   'date': '2022-08-13 08:44:04',
#   'year': '2022',
#   'search_term': 'terrorism',
#   'tags': ['-'],
#   'description': '',
#   'changeDate': '2022-08-13 08:44:04',
#   'url': 'https://www.ijtsrd.com/other-scientific-research-area/other/50308/terrorism-problems-and-solutions--with-special-reference-to-india/dr-deep-kumar-srivastava',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2cfb2db051d7715b8905549c219a58c42/ijtsrd',
#   'text': 'Terrorism Problems and Solutions With Special Reference to India'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2797a8f734e34b0fa4307b88fdd4def99/fbw_hannover',
#   'label': 'Dealing with terrorism',
#   'author': ['Bruno S. Frey'],
#   'type': 'Publication',
#   'date': '2009-08-21 12:21:08',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['Sozioökonomisches_System',
#    'Terrorismus',
#    'Alternative',
#    'Bekämpfung',
#    'Economic_aspects',
#    'Prävention',
#    'Terrorism',
#    'Social_aspects',
#    'Politisches_System',
#    'Politische_Gewalt',
#    'Prevention'],
#   'description': '',
#   'changeDate': '2009-08-21 12:21:09',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+50305951X&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'publisher': 'Elgar',
#   'docno': 'https://www.bibsonomy.org/bibtex/2797a8f734e34b0fa4307b88fdd4def99/fbw_hannover',
#   'text': 'Dealing with terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/249f6ddb9b7697d7b3ea08deaa7ff4c98/tciarli',
#   'label': 'Another day, another dollar: Enterprise resilience under terrorism\n\tin developing countries',
#   'author': ['Oana Branzei', 'Samer Abdelnour'],
#   'type': 'Publication',
#   'date': '2013-01-08 19:41:52',
#   'year': '2010',
#   'search_term': 'terrorism',
#   'tags': ['imported', 'conflict'],
#   'description': '',
#   'changeDate': '2013-01-08 19:42:02',
#   'url': 'http://search.proquest.com/docview/356549598?accountid=14182',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/249f6ddb9b7697d7b3ea08deaa7ff4c98/tciarli',
#   'text': 'Another day, another dollar: Enterprise resilience under terrorism\n\tin developing countries'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21622559711a44e2bf997a0511f339952/oudman',
#   'label': 'Terrorism & Radicalization; an overview',
#   'author': ['Sergei Oudman'],
#   'type': 'Publication',
#   'date': '2021-01-08 14:50:56',
#   'year': '2020',
#   'search_term': 'terrorism',
#   'tags': ['myown'],
#   'description': '',
#   'changeDate': '2021-01-08 14:50:56',
#   'url': 'https://www.ciris.info/panoply-journal-volume-1/',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/21622559711a44e2bf997a0511f339952/oudman',
#   'text': 'Terrorism & Radicalization; an overview'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2b3c3a3d57f79c515488115f433d747ee/jrennstich',
#   'label': 'Terrorism and guerrilla warfare: Forecasts and remedies',
#   'author': ['Richard L. Clutterbuck'],
#   'type': 'Publication',
#   'date': '2010-03-02 17:25:53',
#   'year': '1990',
#   'search_term': 'terrorism',
#   'tags': ['drug', 'warfare', 'terrorism', 'trafficking', 'irregular'],
#   'description': '',
#   'changeDate': '2010-03-02 17:27:42',
#   'url': '',
#   'pub-type': 'book',
#   'publisher': 'Routledge',
#   'docno': 'https://www.bibsonomy.org/bibtex/2b3c3a3d57f79c515488115f433d747ee/jrennstich',
#   'text': 'Terrorism and guerrilla warfare: Forecasts and remedies'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29ecd0d91240756fb1370faffb6d21c43/smicha',
#   'label': 'Terrorist backlash, terrorism mitigation, and policy delegation',
#   'author': ['Kevin Siqueira', 'Todd Sandler'],
#   'type': 'Publication',
#   'date': '2008-04-28 13:05:01',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['Terrorism'],
#   'description': '',
#   'changeDate': '2008-04-28 13:05:27',
#   'url': 'http://www.sciencedirect.com/science/article/B6V76-4N25VRG-1/1/8dfaf3a8b15027f4c204f7ca1b1da44d',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/29ecd0d91240756fb1370faffb6d21c43/smicha',
#   'text': 'Terrorist backlash, terrorism mitigation, and policy delegation'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21622559711a44e2bf997a0511f339952/cirisorg',
#   'label': 'Terrorism & Radicalization; an overview',
#   'author': ['Sergei Oudman'],
#   'type': 'Publication',
#   'date': '2021-01-08 12:48:26',
#   'year': '2020',
#   'search_term': 'terrorism',
#   'tags': ['myown'],
#   'description': '',
#   'changeDate': '2024-01-10 12:35:45',
#   'url': 'https://www.ciris.info/panoply/index.php/journal/article/view/39',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/21622559711a44e2bf997a0511f339952/cirisorg',
#   'text': 'Terrorism & Radicalization; an overview'},
#  {'id': 'https://www.bibsonomy.org/bibtex/210f273d1867dbd5e0b171882349a62c5/ijtsrd',
#   'label': 'Prognosis of Theories of Intelligence in Counter Terrorism The Case of the Northwestern Nigeria',
#   'author': ['Jonjon Emmanuel'],
#   'type': 'Publication',
#   'date': '2021-06-08 12:45:25',
#   'year': '2021',
#   'search_term': 'terrorism',
#   'tags': ['Prognosis',
#    'Intelligence',
#    'Terrorism',
#    'insecurity',
#    'counter-terrorism'],
#   'description': '',
#   'changeDate': '2021-06-08 12:45:25',
#   'url': 'https://www.ijtsrd.com/humanities-and-the-arts/sociology/40057/prognosis-of-theories-of-intelligence-in-counterterrorism-the-case-of-the-northwestern-nigeria/jonjon-emmanuel',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/210f273d1867dbd5e0b171882349a62c5/ijtsrd',
#   'text': 'Prognosis of Theories of Intelligence in Counter Terrorism The Case of the Northwestern Nigeria'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2493d114a483004f9aa65dafc4f2a218d/kperezlopez',
#   'label': 'Preference Modification vs. Incentive Manipulation as Tools of Terrorist Recruitment: the Role of Cultures',
#   'author': ['Michael Munger'],
#   'type': 'Publication',
#   'date': '2006-04-29 21:40:47',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['club_goods', 'recruitment', 'culture', 'CSS739', 'terrorism'],
#   'description': 'Munger explores the role that culture plays in defining choices, as for example, those faced by one being recruited to terrorism.  He spends most of the paper defining culture, its meaning and origins, using game theory illustrations of his ideas.   He discusses the differences between “institutions,” which are long-lived and entrenched, regardless of whether or not they are optimal, and “organizations,” which are the always-optimal responses to the system embodied by the institutions.  At the end of the article, he shows how this explains why terrorism may be a rational organizational response to the one’s institutional situation, and how it shapes the incentives of the game we play with terrorists.',
#   'changeDate': '2006-04-29 21:40:47',
#   'url': 'http://psweb.sbs.ohio-state.edu/intranet/cppe/ ',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2493d114a483004f9aa65dafc4f2a218d/kperezlopez',
#   'text': 'Preference Modification vs. Incentive Manipulation as Tools of Terrorist Recruitment: the Role of Cultures'},
#  {'id': 'https://www.bibsonomy.org/bibtex/230ac0d748fd7378bf3a428058b7214f5/jbwolman',
#   'label': 'Shamir on Terrorism (1943)',
#   'author': ['Yitzhak Shamir'],
#   'type': 'Publication',
#   'date': '2010-06-28 00:43:21',
#   'year': '1988',
#   'search_term': 'terrorism',
#   'tags': ['Israeli', 'Shamir,', 'terrorism', 'Yitzhak'],
#   'description': '',
#   'changeDate': '2010-06-28 00:43:21',
#   'url': 'http://www.jstor.org/stable/3012112',
#   'pub-type': 'article',
#   'publisher': 'Middle East Research and Information Project',
#   'docno': 'https://www.bibsonomy.org/bibtex/230ac0d748fd7378bf3a428058b7214f5/jbwolman',
#   'text': 'Shamir on Terrorism (1943)'},
#  {'id': 'https://www.bibsonomy.org/bibtex/227631331c858099a071b55e558a0bffa/cmcneile',
#   'label': 'Global Physics: From Percolation to Terrorism, Guerilla Warfare and Clandestine Activities',
#   'author': ['Serge Galam'],
#   'type': 'Publication',
#   'date': '2019-02-23 22:09:48',
#   'year': '2004',
#   'search_term': 'terrorism',
#   'tags': ['percolation'],
#   'description': '',
#   'changeDate': '2019-02-23 22:15:27',
#   'url': 'http://dx.doi.org/10.1016/j.physa.2003.08.035',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/227631331c858099a071b55e558a0bffa/cmcneile',
#   'text': 'Global Physics: From Percolation to Terrorism, Guerilla Warfare and Clandestine Activities'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21669cd64c813ae2e3889e18d28bac97e/mhermans',
#   'label': 'The Media War on Terrorism',
#   'author': ['Philip Hammond'],
#   'type': 'Publication',
#   'date': '2007-04-06 10:50:16',
#   'year': '2003',
#   'search_term': 'terrorism',
#   'tags': ['terrorism', 'media'],
#   'description': '',
#   'changeDate': '2007-04-06 10:50:18',
#   'url': 'http://www.jc2m.co.uk/Issue1/Hammond.pdf',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/21669cd64c813ae2e3889e18d28bac97e/mhermans',
#   'text': 'The Media War on Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21e3feaf7dca7db42b448a16350b9e6a5/meneteqel',
#   'label': "Do NSA's Bulk Surveillance Programs Stop Terrorists?",
#   'author': ['Peter Bergen',
#    'David Sterman',
#    'Emily Schneider',
#    'Bailey Cahall'],
#   'type': 'Publication',
#   'date': '2014-01-19 12:31:57',
#   'year': '2014',
#   'search_term': 'terrorism',
#   'tags': ['usa',
#    'terrorism',
#    'surveillance',
#    'nsa',
#    'new_america_foundation'],
#   'description': '',
#   'changeDate': '2014-01-19 12:31:57',
#   'url': 'http://www.newamerica.net/publications/policy/do_nsas_bulk_surveillance_programs_stop_terrorists',
#   'pub-type': 'techreport',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/21e3feaf7dca7db42b448a16350b9e6a5/meneteqel',
#   'text': "Do NSA's Bulk Surveillance Programs Stop Terrorists?"},
#  {'id': 'https://www.bibsonomy.org/bibtex/289973c1e6879da420f7f66fac38a2a0f/spwilcox',
#   'label': 'Aptitude for Destruction, Volume 2: Case Studies of Organizational\r\n\tLearning in Five Terrorist Groups',
#   'author': ['Brian A. Jackson',
#    'John C. Baker',
#    'Peter Chalk',
#    'Kim Cragin',
#    'John V. Parachini',
#    'Horacio R. Trujillo'],
#   'type': 'Publication',
#   'date': '2006-04-05 05:44:05',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['CSS739', 'terrorism', 'organizational_learning'],
#   'description': '',
#   'changeDate': '2006-04-05 05:44:05',
#   'url': 'http://www.rand.org/pubs/monographs/2005/RAND_MG332.pdf',
#   'pub-type': 'book',
#   'publisher': 'RAND',
#   'docno': 'https://www.bibsonomy.org/bibtex/289973c1e6879da420f7f66fac38a2a0f/spwilcox',
#   'text': 'Aptitude for Destruction, Volume 2: Case Studies of Organizational\r\n\tLearning in Five Terrorist Groups'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e42188f114b199f644e8034c54471c57/spwilcox',
#   'label': 'On complex adaptive systems and terrorism',
#   'author': ['E. Ahmed1', 'A. S. Elgazzar', 'A. S. Hegazi1'],
#   'type': 'Publication',
#   'date': '2006-04-06 05:06:51',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['imported', 'CSS739', 'terrorism'],
#   'description': '',
#   'changeDate': '2006-04-06 05:06:51',
#   'url': 'http://www.citebase.org/cgi-bin/fulltext?format=application/pdf&identifier=oai:arXiv.org:nlin/0501032',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2e42188f114b199f644e8034c54471c57/spwilcox',
#   'text': 'On complex adaptive systems and terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2758537333834fa8482347d18616a93ac/jrennstich',
#   'label': 'Political terrorism: A new guide to actors, authors, concepts, data bases, theories, and literature',
#   'author': ['Alex Peter Schmid', 'A. J. Jongman', 'Michael Stohl'],
#   'type': 'Publication',
#   'date': '2010-03-02 17:25:53',
#   'year': '1988',
#   'search_term': 'terrorism',
#   'tags': ['terrorism'],
#   'description': '',
#   'changeDate': '2010-03-02 17:28:34',
#   'url': '',
#   'pub-type': 'book',
#   'publisher': 'North-Holland',
#   'docno': 'https://www.bibsonomy.org/bibtex/2758537333834fa8482347d18616a93ac/jrennstich',
#   'text': 'Political terrorism: A new guide to actors, authors, concepts, data bases, theories, and literature'},
#  {'id': 'https://www.bibsonomy.org/bibtex/256a7c434ed500cbc412bbaf8e782b8f8/spwilcox',
#   'label': 'Aptitude for Destruction, Volume 1: Organizational Learning in Terrorist\r\n\tGroups and Its Implications for Combating Terrorism',
#   'author': ['Brian A. Jackson',
#    'John C. Baker',
#    'Peter Chalk',
#    'Kim Cragin',
#    'John V. Parachini',
#    'Horacio R. Trujillo'],
#   'type': 'Publication',
#   'date': '2006-04-06 15:36:11',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['CSS739', 'terrorism', 'organizational_learning'],
#   'description': '',
#   'changeDate': '2006-04-06 15:36:11',
#   'url': 'http://www.rand.org/pubs/monographs/2005/RAND_MG331.pdf',
#   'pub-type': 'book',
#   'publisher': 'RAND',
#   'docno': 'https://www.bibsonomy.org/bibtex/256a7c434ed500cbc412bbaf8e782b8f8/spwilcox',
#   'text': 'Aptitude for Destruction, Volume 1: Organizational Learning in Terrorist\r\n\tGroups and Its Implications for Combating Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e23c05a38f70b2848071e681ed6971a1/maksim',
#   'label': 'Understanding the Terrorism Database',
#   'author': ['Brian Houghton'],
#   'type': 'Publication',
#   'date': '2006-03-28 18:27:22',
#   'year': '2002',
#   'search_term': 'terrorism',
#   'tags': ['imported'],
#   'description': '',
#   'changeDate': '2006-03-28 18:27:22',
#   'url': '',
#   'pub-type': 'misc',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2e23c05a38f70b2848071e681ed6971a1/maksim',
#   'text': 'Understanding the Terrorism Database'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27a5c663d4804054946fe5a9c304523fe/smicha',
#   'label': 'An empirical analysis of the economic impact of federal terrorism\r\n\treinsurance',
#   'author': ['Jeffrey R. Brown',
#    'J. David Cummins',
#    'Christopher M. Lewis',
#    'Ran Wei'],
#   'type': 'Publication',
#   'date': '2008-04-23 22:05:04',
#   'year': '2004',
#   'search_term': 'terrorism',
#   'tags': ['Terrorism'],
#   'description': '',
#   'changeDate': '2008-04-23 22:09:00',
#   'url': 'http://www.sciencedirect.com/science/article/B6VBW-4D0G1D0-2/1/74fe5d6d7d30049bf03ffc07daa14746',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/27a5c663d4804054946fe5a9c304523fe/smicha',
#   'text': 'An empirical analysis of the economic impact of federal terrorism\r\n\treinsurance'},
#  {'id': 'https://www.bibsonomy.org/bibtex/23312a034773833a3ae9f2832468525cc/smicha',
#   'label': 'Global physics: from percolation to terrorism, guerilla warfare and\r\n\tclandestine activities',
#   'author': ['Serge Galam'],
#   'type': 'Publication',
#   'date': '2008-04-22 10:36:30',
#   'year': '2003',
#   'search_term': 'terrorism',
#   'tags': ['Terrorism'],
#   'description': 'Physica A',
#   'changeDate': '2008-04-22 10:48:49',
#   'url': 'http://www.sciencedirect.com/science/article/B6TVG-49NX7G0-2/1/72ee04926a7e2bfa08e495d94bb26313',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/23312a034773833a3ae9f2832468525cc/smicha',
#   'text': 'Global physics: from percolation to terrorism, guerilla warfare and\r\n\tclandestine activities'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29b36d5d68beca44654f231a47e06064d/openaccess_20',
#   'label': 'The Anti-Terrorist Function of the State',
#   'author': ['Maksudov Sarvar Rustamovich | A. M. Mongush'],
#   'type': 'Publication',
#   'date': '2023-09-14 14:20:58',
#   'year': '2023',
#   'search_term': 'terrorism',
#   'tags': ['the',
#    'society,',
#    'functions',
#    'extremism,',
#    'of',
#    'state,',
#    'mechanisms,',
#    'terrorism,',
#    'protection',
#    'sovereignty,',
#    'governance'],
#   'description': '',
#   'changeDate': '2023-09-20 14:55:55',
#   'url': 'https://openaccessjournals.eu/index.php/ijdpp/article/view/2107/1997',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/29b36d5d68beca44654f231a47e06064d/openaccess_20',
#   'text': 'The Anti-Terrorist Function of the State'},
#  {'id': 'https://www.bibsonomy.org/bibtex/242831ba926f81d8ddba3784cc7551e13/dblp',
#   'label': 'Steganography in Support of the Global Terrorism.',
#   'author': ['Mitko Bogdanoski', 'Aleksandar Risteski', 'Marjan Bogdanoski'],
#   'type': 'Publication',
#   'date': '2016-05-11 00:00:00',
#   'year': '2015',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2016-05-12 11:38:12',
#   'url': 'http://dblp.uni-trier.de/db/series/natosec/natosec42.html#BogdanoskiRB15',
#   'pub-type': 'incollection',
#   'publisher': 'IOS Press',
#   'docno': 'https://www.bibsonomy.org/bibtex/242831ba926f81d8ddba3784cc7551e13/dblp',
#   'text': 'Steganography in Support of the Global Terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/260d3cd804a2f8223faa7b7a1eba147f5/spwilcox',
#   'label': 'Observing Al Qaeda Through the Lens of Complexity Theory: Recommendations\r\n\tfor the National Strategy to Defeat Terrorism',
#   'author': ['Michael F. Beech'],
#   'type': 'Publication',
#   'date': '2006-04-05 06:24:23',
#   'year': '2004',
#   'search_term': 'terrorism',
#   'tags': ['imported', 'complexity', 'CSS739', 'terror_interdiction'],
#   'description': '',
#   'changeDate': '2006-04-05 06:24:23',
#   'url': 'http://handle.dtic.mil/100.2/ADA423895',
#   'pub-type': 'techreport',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/260d3cd804a2f8223faa7b7a1eba147f5/spwilcox',
#   'text': 'Observing Al Qaeda Through the Lens of Complexity Theory: Recommendations\r\n\tfor the National Strategy to Defeat Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/262bc4ce33fad0b09c4cec3d523a613ea/marsianus',
#   'label': 'Estimating the historical and future probabilities of large terrorist events',
#   'author': ['Aaron Clauset', 'Ryan Woodard'],
#   'type': 'Publication',
#   'date': '2014-01-13 14:37:52',
#   'year': '2013',
#   'search_term': 'terrorism',
#   'tags': ['Extremes', 'Terrorism'],
#   'description': '',
#   'changeDate': '2014-01-13 14:37:52',
#   'url': 'http://projecteuclid.org/euclid.aoas/1387823295',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/262bc4ce33fad0b09c4cec3d523a613ea/marsianus',
#   'text': 'Estimating the historical and future probabilities of large terrorist events'},
#  {'id': 'https://www.bibsonomy.org/bibtex/250b48c9ddfe6db2ba6718f94b3d2e120/critzo',
#   'label': 'Patriot Act: Congress to Keep Law Intact',
#   'author': ['Debra Lau Whelan'],
#   'type': 'Publication',
#   'date': '2008-12-27 17:34:46',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['of;',
#    'legislation;',
#    'LIBRARY',
#    'users;',
#    'PRIVACY,',
#    'UNITED',
#    '--',
#    'Congress',
#    'Right',
#    'States.',
#    'Prevention;',
#    'TERRORISM'],
#   'description': 'test export from refworks',
#   'changeDate': '2008-12-27 17:34:56',
#   'url': 'http://search.ebscohost.com/login.aspx?direct=true&db=aph&AN=19170812&site=ehost-live',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/250b48c9ddfe6db2ba6718f94b3d2e120/critzo',
#   'text': 'Patriot Act: Congress to Keep Law Intact'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21350ff1f2d38dcf33334a44d552b9194/herberttsang',
#   'label': 'An agent-based model and computational framework for counter-terrorism and public safety based on swarm intelligence',
#   'author': ['Andrew J. Park',
#    'Herbert H. Tsang',
#    'Mengting Sun',
#    'Uwe Glässer'],
#   'type': 'Publication',
#   'date': '2021-09-21 08:20:54',
#   'year': '2012',
#   'search_term': 'terrorism',
#   'tags': ['imported', 'tsang_pub'],
#   'description': '',
#   'changeDate': '2021-09-21 08:22:40',
#   'url': 'http://dx.doi.org/10.1186/2190-8532-1-23',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/21350ff1f2d38dcf33334a44d552b9194/herberttsang',
#   'text': 'An agent-based model and computational framework for counter-terrorism and public safety based on swarm intelligence'},
#  {'id': 'https://www.bibsonomy.org/bibtex/288338a2374647c32fc7e3685483b88bc/jrennstich',
#   'label': 'Quantitative World System Studies Contradict Current Islamophobia: World Political Cycles, Global Terrorism, and World Development',
#   'author': ['A Tausch'],
#   'type': 'Publication',
#   'date': '2010-03-02 17:25:53',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['islam', 'world-system', 'impact', 'culture', 'religion', 'theory'],
#   'description': '',
#   'changeDate': '2010-03-02 17:27:12',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/288338a2374647c32fc7e3685483b88bc/jrennstich',
#   'text': 'Quantitative World System Studies Contradict Current Islamophobia: World Political Cycles, Global Terrorism, and World Development'},
#  {'id': 'https://www.bibsonomy.org/bibtex/26437bff0366bb7b208003ad41735ca2b/fbw_hannover',
#   'label': 'The political economy of terrorism',
#   'author': nan,
#   'type': 'Publication',
#   'date': '2009-08-21 12:22:28',
#   'year': '2006',
#   'search_term': 'terrorism',
#   'tags': ['Terrorismus', 'Politische_Ökonomie', 'Politische_Gewalt'],
#   'description': '',
#   'changeDate': '2009-08-21 12:22:38',
#   'url': 'http://gso.gbv.de/DB=2.1/CMD?ACT=SRCHA&SRT=YOP&IKT=1016&TRM=ppn+518712761&sourceid=fbw_bibsonomy',
#   'pub-type': 'book',
#   'publisher': 'Springer',
#   'docno': 'https://www.bibsonomy.org/bibtex/26437bff0366bb7b208003ad41735ca2b/fbw_hannover',
#   'text': 'The political economy of terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21036050db3493e30cd1afd94ce3795ef/dblp',
#   'label': 'Anticipatory Models for Counter-Terrorism.',
#   'author': ['Mark Lazaroff', 'David Snowden'],
#   'type': 'Publication',
#   'date': '2012-03-22 00:00:00',
#   'year': '2006',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2012-03-23 11:33:28',
#   'url': 'http://dblp.uni-trier.de/db/books/collections/Popp2006.html#LazaroffS06',
#   'pub-type': 'incollection',
#   'publisher': 'Wiley-IEEE Press',
#   'docno': 'https://www.bibsonomy.org/bibtex/21036050db3493e30cd1afd94ce3795ef/dblp',
#   'text': 'Anticipatory Models for Counter-Terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/26bb80196d059f04c752254b0085cbb62/mlbrodie',
#   'label': 'Protecting Individual Privacy in the Struggle Against Terrorism',
#   'author': [' Committee', 'Michael L Brodie'],
#   'type': 'Publication',
#   'date': '2015-05-15 03:20:57',
#   'year': '2008',
#   'search_term': 'terrorism',
#   'tags': ['Committee'],
#   'description': '',
#   'changeDate': '2015-05-15 03:20:57',
#   'url': 'http://www.nap.edu/catalog/12452/protecting-individual-privacy-in-the-struggle-against-terrorists-a-framework %> http://www.nap.edu/catalog/12452/protecting-individual-privacy-in-the-struggle-against-terrorists-a-framework',
#   'pub-type': 'book',
#   'publisher': 'The National Academies Press',
#   'docno': 'https://www.bibsonomy.org/bibtex/26bb80196d059f04c752254b0085cbb62/mlbrodie',
#   'text': 'Protecting Individual Privacy in the Struggle Against Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2ffa085face6b5f520861cd1ec718be5e/dblp',
#   'label': 'Cyber Terrorism: Terrorists go hi-tech.',
#   'author': ['Atul Kamboj', 'Mukhdeep Singh'],
#   'type': 'Publication',
#   'date': '2020-12-21 00:00:00',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-04-08 13:39:25',
#   'url': 'http://dblp.uni-trier.de/db/journals/ecs/ecs29.html#KambojS07',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2ffa085face6b5f520861cd1ec718be5e/dblp',
#   'text': 'Cyber Terrorism: Terrorists go hi-tech.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/26d893f4513053d84ac58fa0007adf196/spwilcox',
#   'label': "Financing terror: An analysis and simulation for affecting Al Qaeda's\r\n\tfinancial infrastructure",
#   'author': ['Stephen D. Kiser'],
#   'type': 'Publication',
#   'date': '2006-04-05 06:57:03',
#   'year': '2004',
#   'search_term': 'terrorism',
#   'tags': ['imported', 'CSS739', 'terrorism', 'financing'],
#   'description': '',
#   'changeDate': '2006-04-05 06:57:03',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/26d893f4513053d84ac58fa0007adf196/spwilcox',
#   'text': "Financing terror: An analysis and simulation for affecting Al Qaeda's\r\n\tfinancial infrastructure"},
#  {'id': 'https://www.bibsonomy.org/bibtex/2de8d58a82fe47c9a01d6333b366edadc/dblp',
#   'label': 'Countering terrorism.',
#   'author': ['Jarret Brachman'],
#   'type': 'Publication',
#   'date': '2009-01-08 00:00:00',
#   'year': '2008',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2015-06-18 12:41:26',
#   'url': 'http://dblp.uni-trier.de/db/conf/isi/isi2008.html#Brachman08',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/2de8d58a82fe47c9a01d6333b366edadc/dblp',
#   'text': 'Countering terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/265219db873a1b5fbd6ffe5b90d71d609/dblp',
#   'label': 'Modelling Terrorism.',
#   'author': ['Timothy Hackworth', 'Philip C. Treleaven'],
#   'type': 'Publication',
#   'date': '2011-01-17 00:00:00',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2015-06-19 15:21:21',
#   'url': 'http://dblp.uni-trier.de/db/conf/icnsc/icnsc2007.html#HackworthT07',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/265219db873a1b5fbd6ffe5b90d71d609/dblp',
#   'text': 'Modelling Terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2358098da2868f35ae9dd4abe24877531/dblp',
#   'label': 'Modelling Terrorism.',
#   'author': ['Timothy William Hackworth', 'Philip C. Treleaven'],
#   'type': 'Publication',
#   'date': '2016-09-14 00:00:00',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2016-09-15 11:34:28',
#   'url': 'http://dblp.uni-trier.de/db/conf/icnsc/icnsc2007.html#HackworthT07',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/2358098da2868f35ae9dd4abe24877531/dblp',
#   'text': 'Modelling Terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/255e83c983fa47e805cca61021b5e95c9/dblp',
#   'label': 'Terrorism in Distance Bounding: Modeling Terrorist-Fraud Resistance.',
#   'author': ['Marc Fischlin', 'Cristina Onete'],
#   'type': 'Publication',
#   'date': '2019-08-20 00:00:00',
#   'year': '2013',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2019-08-21 12:19:13',
#   'url': 'http://dblp.uni-trier.de/db/conf/acns/acns2013.html#FischlinO13',
#   'pub-type': 'inproceedings',
#   'publisher': 'Springer',
#   'docno': 'https://www.bibsonomy.org/bibtex/255e83c983fa47e805cca61021b5e95c9/dblp',
#   'text': 'Terrorism in Distance Bounding: Modeling Terrorist-Fraud Resistance.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/27f82fcaf21366ffa58a116693ab6df60/fsahito',
#   'label': 'Interrogational Neuroimaging: The Missing Element in Counter-Terrorism',
#   'author': ['Farhan Hyder Sahito'],
#   'type': 'Publication',
#   'date': '2013-08-05 05:13:06',
#   'year': '2013',
#   'search_term': 'terrorism',
#   'tags': ['myown'],
#   'description': '',
#   'changeDate': '2013-08-05 05:13:06',
#   'url': 'http://www.issr-journals.org/xplore/ijias/IJIAS-13-145-02.pdf',
#   'pub-type': 'book',
#   'publisher': 'International Journal of Innovation and Applied Studies',
#   'docno': 'https://www.bibsonomy.org/bibtex/27f82fcaf21366ffa58a116693ab6df60/fsahito',
#   'text': 'Interrogational Neuroimaging: The Missing Element in Counter-Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/280808e0b525ec4f3194d7efc7236bc84/dblp',
#   'label': 'Terrorist Organizations and Effects of Terrorism in Bangladesh.',
#   'author': ['Abu Md. Zafor Alam', 'Abu Md. Siddique Alam', 'Mahjabeen Khan'],
#   'type': 'Publication',
#   'date': '2017-05-26 00:00:00',
#   'year': '2006',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-04-10 00:22:55',
#   'url': 'http://dblp.uni-trier.de/db/conf/isi/isi2006.html#AlamAK06',
#   'pub-type': 'inproceedings',
#   'publisher': 'Springer',
#   'docno': 'https://www.bibsonomy.org/bibtex/280808e0b525ec4f3194d7efc7236bc84/dblp',
#   'text': 'Terrorist Organizations and Effects of Terrorism in Bangladesh.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2d3c83620ed60d880f32dbccf895f9034/ijtsrd',
#   'label': 'Socio Economic Trend of Bangladeshi Militants after the Holey Artisan Attack',
#   'author': ['Abdullah Al Mahmud | Sakin Tanvir'],
#   'type': 'Publication',
#   'date': '2021-01-29 07:14:22',
#   'year': '2020',
#   'search_term': 'terrorism',
#   'tags': ['Bangladesh',
#    'background',
#    'terrorism',
#    'attack',
#    'Militants',
#    'operation',
#    'trends'],
#   'description': '',
#   'changeDate': '2021-01-29 07:14:22',
#   'url': 'https://www.ijtsrd.com/economics/other/38142/socioeconomic-trend-of-bangladeshi-militants-after-the-holeyartisan-attack/abdullah-al-mahmud',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2d3c83620ed60d880f32dbccf895f9034/ijtsrd',
#   'text': 'Socio Economic Trend of Bangladeshi Militants after the Holey Artisan Attack'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21db4d67cba3f42c0d3b457314634c971/dblp',
#   'label': 'Automated Counter-Terrorism.',
#   'author': ['Leslie Ball', 'Matthew J. Craven'],
#   'type': 'Publication',
#   'date': '2021-06-11 00:00:00',
#   'year': '2013',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-04-10 11:59:45',
#   'url': 'http://dblp.uni-trier.de/db/conf/eisic/eisic2013.html#BallC13',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/21db4d67cba3f42c0d3b457314634c971/dblp',
#   'text': 'Automated Counter-Terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2af20387a32ea79228e7b76fa8cc36a51/dblp',
#   'label': 'Terrorism and Bluetooth.',
#   'author': ['Steve Gold'],
#   'type': 'Publication',
#   'date': '2020-02-22 00:00:00',
#   'year': '2011',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2020-02-25 11:46:27',
#   'url': 'http://dblp.uni-trier.de/db/journals/ns/ns2011.html#Gold11f',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2af20387a32ea79228e7b76fa8cc36a51/dblp',
#   'text': 'Terrorism and Bluetooth.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/282e1be7896e3dd9752212825dadd60d8/gdmcbain',
#   'label': 'Bayesian Inferences for Counterterrorism Policy: A Retrospective Case Study of the U.S. War in Afghanistan',
#   'author': ['Kevin D. Dayaratna',
#    'Chandler Hubbard',
#    'Mary Catherine Legreid'],
#   'type': 'Publication',
#   'date': '2024-11-25 05:12:24',
#   'year': '2024',
#   'search_term': 'terrorism',
#   'tags': ['62f15-bayesian-inference',
#    '91f10-history-political-science',
#    'polemology'],
#   'description': '',
#   'changeDate': '2024-11-25 11:17:13',
#   'url': 'https://www.tandfonline.com/doi/full/10.1080/09546553.2022.2156044',
#   'pub-type': 'article',
#   'publisher': 'Routledge',
#   'docno': 'https://www.bibsonomy.org/bibtex/282e1be7896e3dd9752212825dadd60d8/gdmcbain',
#   'text': 'Bayesian Inferences for Counterterrorism Policy: A Retrospective Case Study of the U.S. War in Afghanistan'},
#  {'id': 'https://www.bibsonomy.org/bibtex/21d8c36406c3f4c9bcaa0cf3251e2beb6/spwilcox',
#   'label': 'Destabilizing Terrorist Networks',
#   'author': ['Kathleen M.Carley', 'Jeffrey Reminga', 'Natasha Kamneva'],
#   'type': 'Publication',
#   'date': '2006-04-05 06:01:27',
#   'year': '2003',
#   'search_term': 'terrorism',
#   'tags': ['imported', 'CSS739', 'terror_interdiction', 'terrorism'],
#   'description': '',
#   'changeDate': '2006-04-05 06:01:27',
#   'url': '',
#   'pub-type': 'inproceedings',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/21d8c36406c3f4c9bcaa0cf3251e2beb6/spwilcox',
#   'text': 'Destabilizing Terrorist Networks'},
#  {'id': 'https://www.bibsonomy.org/bibtex/25a635d4450ff7c284888a58ce44fdac8/dblp',
#   'label': 'Hidden Markov Models and Bayesian Networks for Counter-Terrorism.',
#   'author': ['Krishna R. Pattipati',
#    'Peter Willett',
#    'Jefferey Allanach',
#    'Haiying Tu',
#    'Satnam Singh'],
#   'type': 'Publication',
#   'date': '2012-03-22 00:00:00',
#   'year': '2006',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2012-03-23 11:33:28',
#   'url': 'http://dblp.uni-trier.de/db/books/collections/Popp2006.html#PattipatiWATS06',
#   'pub-type': 'incollection',
#   'publisher': 'Wiley-IEEE Press',
#   'docno': 'https://www.bibsonomy.org/bibtex/25a635d4450ff7c284888a58ce44fdac8/dblp',
#   'text': 'Hidden Markov Models and Bayesian Networks for Counter-Terrorism.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2970c6fdd59a2f7f8a7a95667fddbde85/mbinotto',
#   'label': 'Logica del terrorismo',
#   'author': ['Michel Bounan'],
#   'type': 'Publication',
#   'date': '2009-05-16 18:18:56',
#   'year': '2006',
#   'search_term': 'terrorism',
#   'tags': ['logica', 'filosofia', 'terrorismo', 'estetica'],
#   'description': '',
#   'changeDate': '2009-05-16 18:18:56',
#   'url': '',
#   'pub-type': 'book',
#   'publisher': 'duepunti edizioni',
#   'docno': 'https://www.bibsonomy.org/bibtex/2970c6fdd59a2f7f8a7a95667fddbde85/mbinotto',
#   'text': 'Logica del terrorismo'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20b3118a697de4f7f0725c5360acc5a14/dblp',
#   'label': 'Terrorist Group Classification of Historic Terrorist Attacks from The Global Terrorism Database.',
#   'author': ['Ralph Laite',
#    'Miguel Lozano Gonzalez',
#    'Karthik Sankaranarayanan'],
#   'type': 'Publication',
#   'date': '2024-10-15 00:00:00',
#   'year': '2019',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-10-21 07:22:38',
#   'url': 'http://dblp.uni-trier.de/db/conf/iccse2/iccse2019.html#LaiteLS19',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/20b3118a697de4f7f0725c5360acc5a14/dblp',
#   'text': 'Terrorist Group Classification of Historic Terrorist Attacks from The Global Terrorism Database.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e39abe221f4cf65da8b47c67def6bf15/dblp',
#   'label': 'Does Terrorism Affect Acquisitions?',
#   'author': ['Tung Nguyen', 'Dimitris Petmezas', 'Nikolaos Karampatsas'],
#   'type': 'Publication',
#   'date': '2024-10-06 00:00:00',
#   'year': '2023',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-10-07 07:43:24',
#   'url': 'http://dblp.uni-trier.de/db/journals/mansci/mansci69.html#NguyenPK23',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2e39abe221f4cf65da8b47c67def6bf15/dblp',
#   'text': 'Does Terrorism Affect Acquisitions?'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20d29be75e6dc72cc963671e0c9a1d549/hoffrath',
#   'label': 'Terrorism and communism <engl.>',
#   'author': ['Karl Kautsky'],
#   'type': 'Publication',
#   'date': '2012-07-19 19:58:56',
#   'year': '2011',
#   'search_term': 'terrorism',
#   'tags': ['kautsky', 'terror', 'frrevengl', 'kommunismus'],
#   'description': 'KUG Recherche-Portal',
#   'changeDate': '2012-07-19 19:58:56',
#   'url': '',
#   'pub-type': 'book',
#   'publisher': 'Routledge',
#   'docno': 'https://www.bibsonomy.org/bibtex/20d29be75e6dc72cc963671e0c9a1d549/hoffrath',
#   'text': 'Terrorism and communism <engl.>'},
#  {'id': 'https://www.bibsonomy.org/bibtex/23ebad142a6fde3bf5c02a9dfdf646c2a/giedenbacher',
#   'label': 'Globalisation, democracy and terrorism',
#   'author': ['Eric Hobsbawm'],
#   'type': 'Publication',
#   'date': '2014-08-12 16:44:19',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['21.;change;Demokratie;Geschichte;Globalization;DEMOCRACY;Terrorism;SOCIAL;Jh;Internationale;Politik;Globalisierung'],
#   'description': '',
#   'changeDate': '2014-08-12 16:44:19',
#   'url': 'http://www.gbv.de/dms/sub-hamburg/527857734.pdf',
#   'pub-type': 'book',
#   'publisher': 'Little, Brown',
#   'docno': 'https://www.bibsonomy.org/bibtex/23ebad142a6fde3bf5c02a9dfdf646c2a/giedenbacher',
#   'text': 'Globalisation, democracy and terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2e6ae48acc63ba811515d39c2d89beeb4/dblp',
#   'label': 'Building Terrorist Knowledge Graph from Global Terrorism Database and Wikipedia.',
#   'author': ['Tian Xia', 'Yijun Gu'],
#   'type': 'Publication',
#   'date': '2020-05-30 00:00:00',
#   'year': '2019',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2020-06-02 12:39:39',
#   'url': 'http://dblp.uni-trier.de/db/conf/isi/isi2019.html#XiaG19',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/2e6ae48acc63ba811515d39c2d89beeb4/dblp',
#   'text': 'Building Terrorist Knowledge Graph from Global Terrorism Database and Wikipedia.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2367d86aa6a6dc85fde66b425305e9e41/maksim',
#   'label': 'The Definition of Terrorism',
#   'author': ['C. Ruby'],
#   'type': 'Publication',
#   'date': '2006-03-28 18:27:22',
#   'year': '2002',
#   'search_term': 'terrorism',
#   'tags': ['imported'],
#   'description': '',
#   'changeDate': '2006-03-28 18:27:22',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2367d86aa6a6dc85fde66b425305e9e41/maksim',
#   'text': 'The Definition of Terrorism'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2fdc25f32bfca0a7723cd5dcb7f97edd0/dblp',
#   'label': 'Cyber-terrorism in context.',
#   'author': ['Stephen Hinde'],
#   'type': 'Publication',
#   'date': '2023-08-28 00:00:00',
#   'year': '2003',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-04-09 03:27:04',
#   'url': 'http://dblp.uni-trier.de/db/journals/compsec/compsec22.html#Hinde03b',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2fdc25f32bfca0a7723cd5dcb7f97edd0/dblp',
#   'text': 'Cyber-terrorism in context.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/22ee56728eeba34cecfe31fa8b708bcf9/dblp',
#   'label': 'Changes of Cyber-Terrorism: Autonomous Terrors and Counter-Measures.',
#   'author': ['InJung Kim', 'Cheol Won Lee', 'Eul-Gyu Im'],
#   'type': 'Publication',
#   'date': '2024-09-02 00:00:00',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-09-09 07:23:19',
#   'url': 'http://dblp.uni-trier.de/db/conf/iccsa/iccsa2007-2.html#KimLI07',
#   'pub-type': 'inproceedings',
#   'publisher': 'Springer',
#   'docno': 'https://www.bibsonomy.org/bibtex/22ee56728eeba34cecfe31fa8b708bcf9/dblp',
#   'text': 'Changes of Cyber-Terrorism: Autonomous Terrors and Counter-Measures.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20b361a7cf25b5cdc0a80099452ef12a6/dblp',
#   'label': 'The Application of PROACT® RCA to Terrorism/Counter Terrorism Related Events.',
#   'author': ['Robert J. Latino'],
#   'type': 'Publication',
#   'date': '2017-05-26 00:00:00',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2019-10-19 11:38:56',
#   'url': 'http://dblp.uni-trier.de/db/conf/isi/isi2005.html#Latino05',
#   'pub-type': 'inproceedings',
#   'publisher': 'Springer',
#   'docno': 'https://www.bibsonomy.org/bibtex/20b361a7cf25b5cdc0a80099452ef12a6/dblp',
#   'text': 'The Application of PROACT® RCA to Terrorism/Counter Terrorism Related Events.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2b322185d5ba0d2acdd7462d8cb3c424e/giedenbacher',
#   'label': 'The Intensification of surveillance: crime, terrorism and warfare in the information age',
#   'author': ['Kirstie Ball', 'Frank Webster'],
#   'type': 'Publication',
#   'date': '2014-08-12 16:44:19',
#   'year': '2003',
#   'search_term': 'terrorism',
#   'tags': ['aspects.;Social',
#    'surveillance;Social',
#    'of.;Electronic',
#    '2001-',
#    'control.;War',
#    'Terrorism,',
#    'Privacy,',
#    'on',
#    'Right'],
#   'description': '',
#   'changeDate': '2014-08-12 16:44:19',
#   'url': '',
#   'pub-type': 'book',
#   'publisher': 'Pluto Press',
#   'docno': 'https://www.bibsonomy.org/bibtex/2b322185d5ba0d2acdd7462d8cb3c424e/giedenbacher',
# ...
#   'author': ['Wolfgang Aschauer'],
#   'type': 'Publication',
#   'date': '2016-05-31 14:08:26',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['Sozialwissenschaften', 'Soziologie', 'Anthropologie', 'dnb'],
#   'description': '',
#   'changeDate': '2016-05-31 14:08:26',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2ed9a7dd6b4b6bc224fea1f4e9650b357/genealogie',
#   'text': 'Tourismus im Schatten des Terrors: eine vergleichende Analyse der Auswirkungen von Terroranschlägen (Bali, Sinai, Spanien)'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2a73e99a3bd07a9a1fc245b3c982584d2/affitz',
#   'label': 'Location verification using secure distance bounding protocols',
#   'author': ['D. Singelee', 'B. Preneel'],
#   'type': 'Publication',
#   'date': '2014-11-10 15:26:37',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['wireless', 'location', 'security', 'verification'],
#   'description': 'IEEE Xplore Abstract - Location verification using secure distance bounding protocols',
#   'changeDate': '2014-11-10 15:26:37',
#   'url': 'http://ieeexplore.ieee.org/xpl/login.jsp?tp=&arnumber=1542879&url=http%3A%2F%2Fieeexplore.ieee.org%2Fxpls%2Fabs_all.jsp%3Farnumber%3D1542879',
#   'pub-type': 'inproceedings',
#   'publisher': 'IEEE',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a73e99a3bd07a9a1fc245b3c982584d2/affitz',
#   'text': 'Location verification using secure distance bounding protocols'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20e06b96aff6241bfe36843818d0cd14a/nonancourt',
#   'label': 'Mitigation of malicious attacks on networks',
#   'author': ['Christian M. Schneider',
#    'André A. Moreira',
#    'José S. Andrade',
#    'Shlomo Havlin',
#    'Hans J. Herrmann'],
#   'type': 'Publication',
#   'date': '2019-06-10 14:53:09',
#   'year': '2011',
#   'search_term': 'terrorism',
#   'tags': ['percolation', 'power\\_grids,', 'attack,', 'transport-networks'],
#   'description': '',
#   'changeDate': '2019-06-10 14:53:09',
#   'url': 'http://dx.doi.org/10.1073/pnas.1009440108',
#   'pub-type': 'article',
#   'publisher': 'National Academy of Sciences',
#   'docno': 'https://www.bibsonomy.org/bibtex/20e06b96aff6241bfe36843818d0cd14a/nonancourt',
#   'text': 'Mitigation of malicious attacks on networks'},
#  {'id': 'https://www.bibsonomy.org/bibtex/29fedd0668a74a27ddbdb3abd5646d916/dblp',
#   'label': 'BusWorld: An Analog Pilot Test of a Virtual Environment Designed to Treat Posttraumatic Stress Disorder Originating from a Terrorist Suicide Bomb Attack.',
#   'author': ['Naomi Josman',
#    'Ayelet Reisberg',
#    'Patrice L. Weiss',
#    'Azucena García-Palacios',
#    'Hunter G. Hoffman'],
#   'type': 'Publication',
#   'date': '2020-03-12 00:00:00',
#   'year': '2008',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2020-03-13 12:08:47',
#   'url': 'http://dblp.uni-trier.de/db/journals/cbsn/cbsn11.html#JosmanRWGH08',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/29fedd0668a74a27ddbdb3abd5646d916/dblp',
#   'text': 'BusWorld: An Analog Pilot Test of a Virtual Environment Designed to Treat Posttraumatic Stress Disorder Originating from a Terrorist Suicide Bomb Attack.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2455632a0cd4785940ba5dc322fdf477a/genealogie',
#   'label': 'Die Strafsenate des Reichsgerichts von 1933 bis 1945: Hüter der Gerechtigkeit oder Handlanger des Terrors?',
#   'author': ['Heiko Weidenthaler'],
#   'type': 'Publication',
#   'date': '2015-09-09 17:25:44',
#   'year': '1999',
#   'search_term': 'terrorism',
#   'tags': ['Sozialdienste',
#    'Versicherungen',
#    'dnb',
#    'Soziale_Probleme',
#    'Recht'],
#   'description': '',
#   'changeDate': '2015-09-09 17:25:44',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2455632a0cd4785940ba5dc322fdf477a/genealogie',
#   'text': 'Die Strafsenate des Reichsgerichts von 1933 bis 1945: Hüter der Gerechtigkeit oder Handlanger des Terrors?'},
#  {'id': 'https://www.bibsonomy.org/bibtex/289e44bc0700d745ec75f2e9649f410b0/genealogie',
#   'label': 'Gestaltetes Gedenken: Yad Vashem, das U.S. Holocaust Memorial Museum und die Stiftung Topographie des Terrors',
#   'author': ['Matthias Haß'],
#   'type': 'Publication',
#   'date': '2015-09-09 19:30:35',
#   'year': '2001',
#   'search_term': 'terrorism',
#   'tags': ['Bibliothek',
#    'Geschichte_Afrikas',
#    'Buch',
#    'Geschichte_Deutschlands',
#    'Archäologie',
#    'Geschichte_Europas',
#    'Geschichte_und_Historische_Hilfswissenschaften',
#    'Alte_Geschichte',
#    'Information_und_Dokumentation',
#    'Genealogie',
#    'Geschichte_der_übrigen_Welt',
#    'dnb',
#    'Geschichte',
#    'Geschichte_Nordamerikas',
#    'Biografie',
#    'Geschichte_Südamerikas',
#    'Geschichte_Asiens',
#    'Heraldik',
#    'Schrift'],
#   'description': '',
#   'changeDate': '2015-09-09 19:30:35',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/289e44bc0700d745ec75f2e9649f410b0/genealogie',
#   'text': 'Gestaltetes Gedenken: Yad Vashem, das U.S. Holocaust Memorial Museum und die Stiftung Topographie des Terrors'},
#  {'id': 'https://www.bibsonomy.org/bibtex/227700e3284a37cdc723f5676ccaea491/jabreftest',
#   'label': 'Multicriterial Analysis of Explosives in the THz Range',
#   'author': ['R. Ryniec', 'M. Piszczek', 'M. Szustakowski'],
#   'type': 'Publication',
#   'date': '2011-10-24 23:19:16',
#   'year': '2010',
#   'search_term': 'terrorism',
#   'tags': [],
#   'description': '',
#   'changeDate': '2011-10-24 23:19:16',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/227700e3284a37cdc723f5676ccaea491/jabreftest',
#   'text': 'Multicriterial Analysis of Explosives in the THz Range'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20b9164fdd3cdbaba2e36b4b876c12b0c/jrennstich',
#   'label': 'Nuclear Stability in South Asia',
#   'author': ['Sumit Ganguly'],
#   'type': 'Publication',
#   'date': '2010-03-02 17:25:53',
#   'year': '2008',
#   'search_term': 'terrorism',
#   'tags': ['deterrence', 'war', 'security', 'nuclear', 'rivalry'],
#   'description': '',
#   'changeDate': '2010-03-02 17:26:51',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/20b9164fdd3cdbaba2e36b4b876c12b0c/jrennstich',
#   'text': 'Nuclear Stability in South Asia'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20b9164fdd3cdbaba2e36b4b876c12b0c/darn0103',
#   'label': 'Nuclear Stability in South Asia',
#   'author': ['Sumit Ganguly'],
#   'type': 'Publication',
#   'date': '2013-01-25 06:21:49',
#   'year': '2008',
#   'search_term': 'terrorism',
#   'tags': ['conflict'],
#   'description': '',
#   'changeDate': '2013-01-25 06:28:36',
#   'url': '',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/20b9164fdd3cdbaba2e36b4b876c12b0c/darn0103',
#   'text': 'Nuclear Stability in South Asia'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2ab6d191c3ba9f415d673cfdc42e8bf71/brainmachine',
#   'label': 'ARGUS: Rete + DBMS = Efficient Persistent Profile Matching on Large-Volume Data Streams',
#   'author': ['Chun Jin', 'Jaime Carbonell', 'Phil Hayes'],
#   'type': 'Publication',
#   'date': '2008-02-20 17:11:32',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['rete', 'dbms'],
#   'description': 'SpringerLink - Buchkapitel',
#   'changeDate': '2008-02-20 17:11:35',
#   'url': 'http://dx.doi.org/10.1007/11425274_15',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2ab6d191c3ba9f415d673cfdc42e8bf71/brainmachine',
#   'text': 'ARGUS: Rete + DBMS = Efficient Persistent Profile Matching on Large-Volume Data Streams'},
#  {'id': 'https://www.bibsonomy.org/bibtex/210bd7814281575274e6b9fac9903d5db/acf',
#   'label': 'China Businesscast: Olympics Marketing Part 4',
#   'author': ['Robert Ness'],
#   'type': 'Publication',
#   'date': '2008-06-01 16:51:41',
#   'year': '2007-09-03',
#   'search_term': 'terrorism',
#   'tags': ['public_relations', 'Lenovo', 'PR', 'Olympics', 'danwei', 'blog'],
#   'description': 'May08',
#   'changeDate': '2008-06-01 16:52:31',
#   'url': 'http://www.danwei.org/public_relations/',
#   'pub-type': 'article',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/210bd7814281575274e6b9fac9903d5db/acf',
#   'text': 'China Businesscast: Olympics Marketing Part 4'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2fa39de33f1c23331bdaecdcfe239a969/jabreftest',
#   'label': 'Spectral sampling method for identification explosives',
#   'author': ['Radoslaw Ryniec', 'Marek Piszczek', 'Mieczyslaw Szustakowski'],
#   'type': 'Publication',
#   'date': '2011-10-24 23:19:17',
#   'year': '2010',
#   'search_term': 'terrorism',
#   'tags': [],
#   'description': '',
#   'changeDate': '2011-10-24 23:19:17',
#   'url': '',
#   'pub-type': 'inproceedings',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2fa39de33f1c23331bdaecdcfe239a969/jabreftest',
#   'text': 'Spectral sampling method for identification explosives'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2475874031dd9b517518538cd15da81cd/dblp',
#   'label': 'Is There a Need for Enhancing National Security Against Terrorists Conducting Information Warfare? A Confident Performance for Australia Context.',
#   'author': ['Ken Webb'],
#   'type': 'Publication',
#   'date': '2005-09-16 00:00:00',
#   'year': '2005',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2016-06-24 12:41:21',
#   'url': 'http://dblp.uni-trier.de/db/conf/eciw/eciw2005.html#Webb05',
#   'pub-type': 'inproceedings',
#   'publisher': 'Academic Conferences Limited, Reading, UK',
#   'docno': 'https://www.bibsonomy.org/bibtex/2475874031dd9b517518538cd15da81cd/dblp',
#   'text': 'Is There a Need for Enhancing National Security Against Terrorists Conducting Information Warfare? A Confident Performance for Australia Context.'},
#  {'id': 'https://www.bibsonomy.org/bibtex/23c74decd47e8ce7d28ddac99dc49f2b3/jrvosse',
#   'label': 'VOX POPULI: Automatic Generation of Biased Video Sequences',
#   'author': ['Stefano Bocconi'],
#   'type': 'Publication',
#   'date': '2007-09-25 14:30:17',
#   'year': '2004',
#   'search_term': 'terrorism',
#   'tags': ['imported'],
#   'description': 'Semantic Media Interfaces - publications',
#   'changeDate': '2007-09-25 14:30:23',
#   'url': 'http://www.cwi.nl/~media/publications/srmc04-workshop.pdf',
#   'pub-type': 'inproceedings',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/23c74decd47e8ce7d28ddac99dc49f2b3/jrvosse',
#   'text': 'VOX POPULI: Automatic Generation of Biased Video Sequences'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2f3d947d4daa31aab20a90f84dc10addd/3lli3',
#   'label': 'Evaluation of 21st-Century Risks of Smallpox Vaccination and Policy Options',
#   'author': ['J. Michael Lane', 'Joel Goldstein'],
#   'type': 'Publication',
#   'date': '2021-07-22 00:13:07',
#   'year': '2003',
#   'search_term': 'terrorism',
#   'tags': ['public-policy', 'vaccine', 'smallpox'],
#   'description': 'PDF full text \r\nhttps://www.acpjournals.org/doi/pdf/10.7326/0003-4819-138-6-200303180-00014',
#   'changeDate': '2021-07-22 00:13:07',
#   'url': 'https://www.acpjournals.org/doi/abs/10.7326/0003-4819-138-6-200303180-00014',
#   'pub-type': 'article',
#   'publisher': 'American College of Physicians',
#   'docno': 'https://www.bibsonomy.org/bibtex/2f3d947d4daa31aab20a90f84dc10addd/3lli3',
#   'text': 'Evaluation of 21st-Century Risks of Smallpox Vaccination and Policy Options'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2112fb092fd70c60207f8bef9d7bd2510/genealogie',
#   'label': 'Varianten des Terrors: ein Vergleich zwischen der deutschen und rumänischen Besatzungsverwaltung in der Sowjetunion 1941 - 1944',
#   'author': ['Herwig Baum'],
#   'type': 'Publication',
#   'date': '2015-09-07 22:10:44',
#   'year': '2009',
#   'search_term': 'terrorism',
#   'tags': ['dnb', 'Geschichte_Europas'],
#   'description': '',
#   'changeDate': '2015-09-07 22:10:44',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2112fb092fd70c60207f8bef9d7bd2510/genealogie',
#   'text': 'Varianten des Terrors: ein Vergleich zwischen der deutschen und rumänischen Besatzungsverwaltung in der Sowjetunion 1941 - 1944'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2da763f13613fbff1a023ea8fd154e79e/genealogie',
#   'label': 'Aspekte des internationalen Terrorismus als transnationales Problem: dargest. am Beispiel der terroristischen Geiselnahmen von 1968 bis 1977 ; Versuch e. Bestandsaufnahme',
#   'author': ['Ulrike Pesch'],
#   'type': 'Publication',
#   'date': '2015-09-09 02:35:55',
#   'year': '1977',
#   'search_term': 'terrorism',
#   'tags': ['Wehrwesen', 'Politik', 'dnb'],
#   'description': '',
#   'changeDate': '2016-05-31 05:28:40',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2da763f13613fbff1a023ea8fd154e79e/genealogie',
#   'text': 'Aspekte des internationalen Terrorismus als transnationales Problem: dargest. am Beispiel der terroristischen Geiselnahmen von 1968 bis 1977 ; Versuch e. Bestandsaufnahme'},
#  {'id': 'https://www.bibsonomy.org/bibtex/2085f132d0dcfc6a96eb3a36ef6dca39e/edna_foobar',
#   'label': 'Das Gewalt- und Konfliktbild des Islam bei ARD und ZDF - Eine Untersuchung öffentlich-rechtlicher Magazin- und Talksendungen',
#   'author': ['Carola Richter Kai Hafez'],
#   'type': 'Publication',
#   'date': '2008-07-27 23:51:17',
#   'year': '2007',
#   'search_term': 'terrorism',
#   'tags': ['image',
#    'islam',
#    'ARD',
#    'gewalt',
#    'ZDF',
#    'berichterstattung',
#    'medien',
#    'studie',
#    'religion',
#    'negativ'],
#   'description': '',
#   'changeDate': '2008-07-27 23:51:17',
#   'url': 'http://www2.kommunikationswissenschaft-erfurt.de/uploads/bericht_islam_in_ard_und_zdf_2005_2006.pdf',
#   'pub-type': 'unpublished',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/2085f132d0dcfc6a96eb3a36ef6dca39e/edna_foobar',
#   'text': 'Das Gewalt- und Konfliktbild des Islam bei ARD und ZDF - Eine Untersuchung öffentlich-rechtlicher Magazin- und Talksendungen'},
#  {'id': 'https://www.bibsonomy.org/bibtex/20d18c890a1d5ce08f0706695d9d91f9c/orcival',
#   'label': 'La sottile linea nera. Neofascismo e servizi segreti da Piazza Fontana a Piazza della Loggia',
#   'author': ['Mimmo Franzinelli'],
#   'type': 'Publication',
#   'date': '2009-11-07 13:06:35',
#   'year': '2008',
#   'search_term': 'terrorism',
#   'tags': ['{1969-12-12(Piazza\\_Fontana),}',
#    '{Geschichte-Italien-20.\\_Jhd.-1943-1993-1960er-70er\\_Jahre,}',
#    '{Geschichte\\_der\\_Rechten-Italien-Neue\\_Rechte,}',
#    '{Strategie\\_der\\_Spannung}',
#    'Mailand,',
#    'Geheimdienste,',
#    '{Geschichte\\_der\\_Rechten-Italien-Parteien-MSI,}',
#    'Besorgen',
#    'Geschichte-Italien-20._Jhd.-1943-1993',
#    'Brescia,',
#    '{1974-05-28(Piazza\\_della\\_Loggia),}'],
#   'description': '',
#   'changeDate': '2009-11-07 13:06:46',
#   'url': '',
#   'pub-type': 'book',
#   'publisher': 'Rizzoli',
#   'docno': 'https://www.bibsonomy.org/bibtex/20d18c890a1d5ce08f0706695d9d91f9c/orcival',
#   'text': 'La sottile linea nera. Neofascismo e servizi segreti da Piazza Fontana a Piazza della Loggia'},
#  {'id': 'https://www.bibsonomy.org/bibtex/26cedffcbfd3a04706c7cb179ca3ee816/dblp',
#   'label': "The UK's legal response to terrorist communication in the 21st century: striking the right balance between individual privacy and collective security in the digital age.",
#   'author': ['S. A. Hale-Ross'],
#   'type': 'Publication',
#   'date': '2022-04-05 00:00:00',
#   'year': '2017',
#   'search_term': 'terrorism',
#   'tags': ['dblp'],
#   'description': '',
#   'changeDate': '2024-04-09 08:50:58',
#   'url': '',
#   'pub-type': 'phdthesis',
#   'publisher': nan,
#   'docno': 'https://www.bibsonomy.org/bibtex/26cedffcbfd3a04706c7cb179ca3ee816/dblp',
#   'text': "The UK's legal response to terrorist communication in the 21st century: striking the right balance between individual privacy and collective security in the digital age."},
#  ...]

# %%
index_folder_mult = "/home/tim/Schreibtisch/2024-25-Data_Librarian-Reschop_Tim/Modul_2-1/violece_index_mult"

fields=['docno', 'text', 'tags', 'description'] #fields: Eine Liste von Feldern, die indiziert werden sollen (Dokumentnummer, Text, Tags, Beschreibung).


indexer_mult = pt.IterDictIndexer(index_folder_mult, meta={'docno': 200, 'text': 4096}, fields=True, text_attrs=fields, overwrite=True) #Ein Indexer, der mit einem Dictionary von Dokumenten arbeitet. 
                                                                                                        #Die Dokumente in diesem Fall sind wahrscheinlich als Dictionary gespeichert (z. B. 
                                                                                                        #Eine Metainformation, in der die maximale Länge für die Felder docno und text angegeben wird, 
                                                                                                        #(z. B. dass docno maximal 200 Zeichen und text maximal 4096 Zeichen lang sein darf).
index_ref_mult = indexer_mult.index(ter_dict) #Hier wird auf ein Dictionary oder eine Sammlung von Dokumenten verwiesen, die indiziert werden sollen. 
                                                             #Es wird angenommen, dass es ein Dictionary ist, in dem jedes Dokument die Felder docno, text, tags und description enthält.

print(f"path to our index: {index_ref_mult.toString()}")
# Out:
# path to our index: /home/tim/Schreibtisch/2024-25-Data_Librarian-Reschop_Tim/Modul_2-1/violece_index_mult/data.properties

# %%
index_mult = pt.IndexFactory.of(index_ref_mult) #erstellen des neunen Indexes

# %%
print(index_mult.getCollectionStatistics().toString())
# Out:
# Number of documents: 2790
# Number of terms: 7148
# Number of postings: 48116
# Number of fields: 4
# Number of tokens: 54845
# Field names: [docno, text, tags, description]
# Positions:   false

# %%
search_engine_mult = pt.BatchRetrieve(index_mult, wmodel="TF_IDF")
# Out:
# /tmp/ipykernel_18790/495383578.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine_mult = pt.BatchRetrieve(index_mult, wmodel="TF_IDF")

# %%
res = search_engine_mult.search("terrorism")
res
# Out:
#     qid  docid                                              docno  rank  \
# 0     1    110  https://www.bibsonomy.org/bibtex/23a9422bcfa97...     0
# 1     1      8  https://www.bibsonomy.org/bibtex/29b576de17b6c...     1
# 2     1     20  https://www.bibsonomy.org/bibtex/21669cd64c813...     2
# 3     1     16  https://www.bibsonomy.org/bibtex/210f273d1867d...     3
# 4     1      0  https://www.bibsonomy.org/bibtex/22e03edf1449f...     4
# ..   ..    ...                                                ...   ...
# 448   1    461  https://www.bibsonomy.org/bibtex/2dfa9f402760d...   448
# 449   1    879  https://www.bibsonomy.org/bibtex/24099898410e6...   449
# 450   1    434  https://www.bibsonomy.org/bibtex/20a84e04dbfd6...   450
# 451   1    318  https://www.bibsonomy.org/bibtex/2c3fcb19c7e91...   451
# 452   1    985  https://www.bibsonomy.org/bibtex/289e44bc0700d...   452
#
#         score      query
# 0    2.624543  terrorism
# 1    2.506690  terrorism
# 2    2.430926  terrorism
# 3    2.425020  terrorism
# 4    2.354042  terrorism
# ..        ...        ...
# 448  0.987215  terrorism
# 449  0.987215  terrorism
# 450  0.974292  terrorism
# 451  0.937478  terrorism
# 452  0.903344  terrorism
#
# [453 rows x 6 columns]

# %%
#Daten Speichern
pickle.dump(df_bibsonomy, open("/home/tim/Schreibtisch/2024-25-Data_Librarian-Reschop_Tim/Modul_2-1/violence_pubs.pkl", "wb"))

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/tim/anaconda3/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /home/tim/anaconda3/lib/python3.12/site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in /home/tim/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /home/tim/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tim/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/tim/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tim/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tim/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tim/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/tim/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tim/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/tim/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /home/tim/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /home/tim/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
